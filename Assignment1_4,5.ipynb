# %%
import os
import re
from glob import glob
from pprint import pprint
from collections import defaultdict

# %%
play_files = glob("play_files/*.txt")
play_files
# Out:
# ['play_files/shakespeare-antony-23.txt',
#  'play_files/shakespeare-comedy-7.txt',
#  'play_files/shakespeare-as-12.txt',
#  'play_files/shakespeare-coriolanus-24.txt',
#  'play_files/shakespeare-alls-11.txt']

# %%
lines = []
for play_file in play_files:
    with open(play_file, "r") as fp:
        lines.append(fp.read().split("\n\n"))

# %%
for line_list in lines:
    print(len(line_list))
# Out:
# 1630
# 740
# 1045
# 1458
# 1180

# %%
def get_start_line(play_lines):
    scene_1_line = -1
    start_line = -1
    line_counter = 0
    
    while start_line == -1:
        # Loop to search for line containing "SCENE I"
        # Will only be executed for the first iteration
        # of the parent while loop
        while scene_1_line == -1:
            line = play_lines[line_counter]
            if line.startswith("SCENE I\t"):
                scene_1_line = line_counter
            line_counter += 1
        
        # Search for the chunk for the first dialogue
        line = play_lines[line_counter]
        if line[0].isalpha():
            start_line = line_counter
            
        line_counter += 1
    
    return start_line

# %% [markdown]
# ### Get the index of the chunk containing the first dialogue

# %%
start_lines = [get_start_line(play_lines) for play_lines in lines]
start_lines
# Out:
# [23, 22, 24, 23, 20]

# %%
for line_num, play_lines in zip(start_lines, lines):
    pprint(play_lines[line_num])
    print("="*100)

# %%
lines_with_starting_point = [
    play_lines[start_line_num:] for start_line_num, play_lines in zip(start_lines, lines)
]

# %% [markdown]
# ### Verify the starting point by printing first few dialogues of each play

# %%
for play_lines in lines_with_starting_point:
    pprint(("\n" + "<=>"*5 + "\n").join(play_lines[:2]))
    print("="*100)
# Out:
# ("PHILO\tNay, but this dotage of our general's\n"
#  "\tO'erflows the measure: those his goodly eyes,\n"
#  "\tThat o'er the files and musters of the war\n"
#  "\tHave glow'd like plated Mars, now bend, now turn,\n"
#  '\tThe office and devotion of their view\n'
#  "\tUpon a tawny front: his captain's heart,\n"
#  '\tWhich in the scuffles of great fights hath burst\n'
#  '\tThe buckles on his breast, reneges all temper,\n'
#  '\tAnd is become the bellows and the fan\n'
#  "\tTo cool a gipsy's lust.\n"
#  '<=><=><=><=><=>\n'
#  '\t[Flourish. Enter ANTONY, CLEOPATRA, her Ladies,\n'
#  '\tthe Train, with Eunuchs fanning her]')
# ====================================================================================================
# ('AEGEON\tProceed, Solinus, to procure my fall\n'
#  '\tAnd by the doom of death end woes and all.\n'
#  '<=><=><=><=><=>\n'
#  'DUKE SOLINUS\tMerchant of Syracuse, plead no more;\n'
#  '\tI am not partial to infringe our laws:\n'
#  '\tThe enmity and discord which of late\n'
#  '\tSprung from the rancorous outrage of your duke\n'
#  '\tTo merchants, our well-dealing countrymen,\n'
#  '\tWho wanting guilders to redeem their lives\n'
#  "\tHave seal'd his rigorous statutes with their bloods,\n"
#  '\tExcludes all pity from our threatening looks.\n'
#  '\tFor, since the mortal and intestine jars\n'
#  "\t'Twixt thy seditious countrymen and us,\n"
#  '\tIt hath in solemn synods been decreed\n'
#  '\tBoth by the Syracusians and ourselves,\n'
#  '\tTo admit no traffic to our adverse towns Nay, more,\n'
#  '\tIf any born at Ephesus be seen\n'
#  '\tAt any Syracusian marts and fairs;\n'
#  '\tAgain: if any Syracusian born\n'
#  '\tCome to the bay of Ephesus, he dies,\n'
#  "\tHis goods confiscate to the duke's dispose,\n"
#  '\tUnless a thousand marks be levied,\n'
#  '\tTo quit the penalty and to ransom him.\n'
#  '\tThy substance, valued at the highest rate,\n'
#  '\tCannot amount unto a hundred marks;\n'
#  '\tTherefore by law thou art condemned to die.')
# ====================================================================================================
# ('ORLANDO\tAs I remember, Adam, it was upon this fashion\n'
#  '\tbequeathed me by will but poor a thousand crowns,\n'
#  '\tand, as thou sayest, charged my brother, on his\n'
#  '\tblessing, to breed me well: and there begins my\n'
#  '\tsadness. My brother Jaques he keeps at school, and\n'
#  '\treport speaks goldenly of his profit: for my part,\n'
#  '\the keeps me rustically at home, or, to speak more\n'
#  '\tproperly, stays me here at home unkept; for call you\n'
#  '\tthat keeping for a gentleman of my birth, that\n'
#  '\tdiffers not from the stalling of an ox? His horses\n'
#  '\tare bred better; for, besides that they are fair\n'
#  '\twith their feeding, they are taught their manage,\n'
#  '\tand to that end riders dearly hired: but I, his\n'
#  '\tbrother, gain nothing under him but growth; for the\n'
#  '\twhich his animals on his dunghills are as much\n'
#  '\tbound to him as I. Besides this nothing that he so\n'
#  '\tplentifully gives me, the something that nature gave\n'
#  '\tme his countenance seems to take from me: he lets\n'
#  '\tme feed with his hinds, bars me the place of a\n'
#  '\tbrother, and, as much as in him lies, mines my\n'
#  '\tgentility with my education. This is it, Adam, that\n'
#  '\tgrieves me; and the spirit of my father, which I\n'
#  '\tthink is within me, begins to mutiny against this\n'
#  '\tservitude: I will no longer endure it, though yet I\n'
#  '\tknow no wise remedy how to avoid it.\n'
#  '<=><=><=><=><=>\n'
#  'ADAM\tYonder comes my master, your brother.')
# ====================================================================================================
# ('First Citizen\tBefore we proceed any further, hear me speak.\n'
#  '<=><=><=><=><=>\n'
#  'All\tSpeak, speak.')
# ====================================================================================================
# ('COUNTESS\tIn delivering my son from me, I bury a second husband.\n'
#  '<=><=><=><=><=>\n'
#  "BERTRAM\tAnd I in going, madam, weep o'er my father's death\n"
#  "\tanew: but I must attend his majesty's command, to\n"
#  '\twhom I am now in ward, evermore in subjection.')
# ====================================================================================================

# %% [markdown]
# ### Remove chunks containing terms like ACT I, ACT II, SCENE I, SCENE II, etc

# %%
def filter_act_and_scene_lines(play_lines):
    filtered_lines = []
    
    for line in play_lines:
        if line.startswith("ACT"):
            continue
        elif line.startswith("SCENE"):
            continue
        else:
            filtered_lines.append(line)
            
    return filtered_lines

# %%
lines_without_act_and_scene_lines = [
    filter_act_and_scene_lines(play_lines) 
    for play_lines in lines_with_starting_point
]

# %%
# Verify that the number of chunks have reduced after removal of ACT and SCENE chunks
for play_lines in lines_without_act_and_scene_lines:
    print(len(play_lines))
# Out:
# 1525
# 698
# 979
# 1379
# 1116

# %% [markdown]
# ### Print lines not starting with alphabetical characters to see different cases

# %%
for play_idx, play_lines in enumerate(lines_without_act_and_scene_lines):
    print(play_idx)
    for line in play_lines:
        if not line[0].isalpha():
            pprint(line)
            print("-"*25)
    print("="*500)
# Out:
# 0
# ('\t[Flourish. Enter ANTONY, CLEOPATRA, her Ladies,\n'
#  '\tthe Train, with Eunuchs fanning her]')
# -------------------------
# ('\t\t  Look, where they come:\n'
#  '\tTake but good note, and you shall see in him.\n'
#  "\tThe triple pillar of the world transform'd\n"
#  "\tInto a strumpet's fool: behold and see.")
# -------------------------
# '\t[Enter an Attendant]'
# -------------------------
# '\t[Embracing]'
# -------------------------
# ("\tAnd such a twain can do't, in which I bind,\n"
#  '\tOn pain of punishment, the world to weet\n'
#  '\tWe stand up peerless.')
# -------------------------
# '\t[Exeunt MARK ANTONY and CLEOPATRA with\n\ttheir train]'
# -------------------------
# '\t[Exeunt]'
# -------------------------
# '\tANTONY AND CLEOPATRA'
# -------------------------
# '\t[Enter CHARMIAN, IRAS, ALEXAS, and a Soothsayer]'
# -------------------------
# '\t[Enter DOMITIUS ENOBARBUS]'
# -------------------------
# '\t[Enter CLEOPATRA]'
# -------------------------
# '\t[Exeunt]'
# -------------------------
# '\t[Enter MARK ANTONY with a Messenger and Attendants]'
# -------------------------
# '\t[Exit]'
# -------------------------
# '\t[Enter another Messenger]'
# -------------------------
# '\t\t    What are you?'
# -------------------------
# '\t[Gives a letter]'
# -------------------------
# '\t[Exit Second Messenger]'
# -------------------------
# ("\tThere's a great spirit gone! Thus did I desire it:\n"
#  '\tWhat our contempt doth often hurl from us,\n'
#  '\tWe wish it ours again; the present pleasure,\n'
#  '\tBy revolution lowering, does become\n'
#  "\tThe opposite of itself: she's good, being gone;\n"
#  '\tThe hand could pluck her back that shoved her on.\n'
#  '\tI must from this enchanting queen break off:\n'
#  '\tTen thousand harms, more than the ills I know,\n'
#  '\tMy idleness doth hatch. How now! Enobarbus!')
# -------------------------
# '\t[Re-enter DOMITIUS ENOBARBUS]'
# -------------------------
# '\t[Exit ALEXAS]'
# -------------------------
# '\t[Exeunt]'
# -------------------------
# '\tANTONY AND CLEOPATRA'
# -------------------------
# '\t[Enter CLEOPATRA, CHARMIAN, IRAS, and ALEXAS]'
# -------------------------
# '\t[Exit ALEXAS]'
# -------------------------
# '\t[Enter MARK ANTONY]'
# -------------------------
# '\t[Exeunt]'
# -------------------------
# '\tANTONY AND CLEOPATRA'
# -------------------------
# '\t[Enter OCTAVIUS CAESAR, reading a letter, LEPIDUS,\n\tand their Train]'
# -------------------------
# '\t[Enter a Messenger]'
# -------------------------
# '\t[Exeunt]'
# -------------------------
# '\tANTONY AND CLEOPATRA'
# -------------------------
# '\t[Enter CLEOPATRA, CHARMIAN, IRAS, and MARDIAN]'
# -------------------------
# '\t[Enter ALEXAS, from OCTAVIUS CAESAR]'
# -------------------------
# '\t[Exeunt]'
# -------------------------
# '\tANTONY AND CLEOPATRA'
# -------------------------
# '\t[Enter POMPEY, MENECRATES, and MENAS, in\n\twarlike manner]'
# -------------------------
# '\t[Enter VARRIUS]'
# -------------------------
# '\t\t       How now, Varrius!'
# -------------------------
# '\t[Exeunt]'
# -------------------------
# '\tANTONY AND CLEOPATRA'
# -------------------------
# '\t[Enter DOMITIUS ENOBARBUS and LEPIDUS]'
# -------------------------
# '\t[Enter MARK ANTONY and VENTIDIUS]'
# -------------------------
# '\t[Enter OCTAVIUS CAESAR, MECAENAS, and AGRIPPA]'
# -------------------------
# '\t[Flourish]'
# -------------------------
# '\t[Flourish. Exeunt OCTAVIUS CAESAR, MARK ANTONY,\n\tand LEPIDUS]'
# -------------------------
# '\t[Exeunt]'
# -------------------------
# '\tANTONY AND CLEOPATRA'
# -------------------------
# ('\t[Enter MARK ANTONY, OCTAVIUS CAESAR, OCTAVIA between\n'
#  '\tthem, and Attendants]')
# -------------------------
# '\t[Exeunt OCTAVIUS CAESAR and OCTAVIA]'
# -------------------------
# '\t[Enter Soothsayer]'
# -------------------------
# '\t[Exit Soothsayer]'
# -------------------------
# ('\tHe shall to Parthia. Be it art or hap,\n'
#  '\tHe hath spoken true: the very dice obey him;\n'
#  '\tAnd in our sports my better cunning faints\n'
#  '\tUnder his chance: if we draw lots, he speeds;\n'
#  '\tHis cocks do win the battle still of mine,\n'
#  '\tWhen it is all to nought; and his quails ever\n'
#  "\tBeat mine, inhoop'd, at odds. I will to Egypt:\n"
#  '\tAnd though I make this marriage for my peace,\n'
#  "\tI' the east my pleasure lies.")
# -------------------------
# '\t[Enter VENTIDIUS]'
# -------------------------
# ('\t\t        O, come, Ventidius,\n'
#  "\tYou must to Parthia: your commission's ready;\n"
#  "\tFollow me, and receive't.")
# -------------------------
# '\t[Exeunt]'
# -------------------------
# '\tANTONY AND CLEOPATRA'
# -------------------------
# '\t[Enter LEPIDUS, MECAENAS, and AGRIPPA]'
# -------------------------
# '\t[Exeunt]'
# -------------------------
# '\tANTONY AND CLEOPATRA'
# -------------------------
# '\t[Enter CLEOPATRA, CHARMIAN, IRAS, and ALEXAS]'
# -------------------------
# '\t[Enter MARDIAN]'
# -------------------------
# '\t[Enter a Messenger]'
# -------------------------
# ('\t\t      O, from Italy\n'
#  '\tRam thou thy fruitful tidings in mine ears,\n'
#  '\tThat long time have been barren.')
# -------------------------
# '\t[Strikes him down]'
# -------------------------
# '\t[Strikes him again]'
# -------------------------
# ("\tHorrible villain! or I'll spurn thine eyes\n"
#  "\tLike balls before me; I'll unhair thy head:")
# -------------------------
# '\t[She hales him up and down]'
# -------------------------
# ("\tThou shalt be whipp'd with wire, and stew'd in brine,\n"
#  '\tSmarting in lingering pickle.')
# -------------------------
# '\t[Draws a knife]'
# -------------------------
# '\t[Exit]'
# -------------------------
# '\t[Exit CHARMIAN]'
# -------------------------
# ('\tThese hands do lack nobility, that they strike\n'
#  '\tA meaner than myself; since I myself\n'
#  '\tHave given myself the cause.')
# -------------------------
# '\t[Re-enter CHARMIAN and Messenger]'
# -------------------------
# ('\t\t       Come hither, sir.\n'
#  '\tThough it be honest, it is never good\n'
#  '\tTo bring bad news: give to a gracious message.\n'
#  '\tAn host of tongues; but let ill tidings tell\n'
#  '\tThemselves when they be felt.')
# -------------------------
# '\t[Exit Messenger]'
# -------------------------
# '\t[Exit ALEXAS]'
# -------------------------
# ('\tLet him for ever go:--let him not--Charmian,\n'
#  '\tThough he be painted one way like a Gorgon,\n'
#  "\tThe other way's a Mars. Bid you Alexas")
# -------------------------
# '\t[To MARDIAN]'
# -------------------------
# ('\tBring me word how tall she is. Pity me, Charmian,\n'
#  '\tBut do not speak to me. Lead me to my chamber.')
# -------------------------
# '\t[Exeunt]'
# -------------------------
# '\tANTONY AND CLEOPATRA'
# -------------------------
# ('\t[Flourish. Enter POMPEY and MENAS at one door,\n'
#  '\twith drum and trumpet: at another, OCTAVIUS CAESAR,\n'
#  '\tMARK ANTONY, LEPIDUS, DOMITIUS ENOBARBUS, MECAENAS,\n'
#  '\twith Soldiers marching]')
# -------------------------
# '\t[Exeunt all but MENAS and ENOBARBUS]'
# -------------------------
# '\t[Exeunt]'
# -------------------------
# '\tANTONY AND CLEOPATRA'
# -------------------------
# '\t[Music plays. Enter two or three Servants with\n\ta banquet]'
# -------------------------
# ('\t[A sennet sounded. Enter OCTAVIUS CAESAR, MARK\n'
#  '\tANTONY, LEPIDUS, POMPEY, AGRIPPA, MECAENAS,\n'
#  '\tDOMITIUS ENOBARBUS, MENAS, with other captains]')
# -------------------------
# '\t[Rises, and walks aside]'
# -------------------------
# '\t[Pointing to the Attendant who carries off LEPIDUS]'
# -------------------------
# '\t[To MARK ANTONY]'
# -------------------------
# '\tShall we dance now the Egyptian Bacchanals,\n\tAnd celebrate our drink?'
# -------------------------
# '\t[Music plays. DOMITIUS ENOBARBUS places them\n\thand in hand]\n\tTHE SONG.'
# -------------------------
# ('\tCome, thou monarch of the vine,\n'
#  '\tPlumpy Bacchus with pink eyne!\n'
#  "\tIn thy fats our cares be drown'd,\n"
#  "\tWith thy grapes our hairs be crown'd:\n"
#  '\tCup us, till the world go round,\n'
#  '\tCup us, till the world go round!')
# -------------------------
# '\t[Exeunt all but DOMITIUS ENOBARBUS and MENAS]'
# -------------------------
# "\tMenas, I'll not on shore."
# -------------------------
# '\t[Sound a flourish, with drums]'
# -------------------------
# '\t[Exeunt]'
# -------------------------
# '\tANTONY AND CLEOPATRA'
# -------------------------
# ('\t[Enter VENTIDIUS as it were in triumph, with SILIUS,\n'
#  '\tand other Romans, Officers, and Soldiers; the dead\n'
#  '\tbody of PACORUS borne before him]')
# -------------------------
# '\t[Exeunt]'
# -------------------------
# '\tANTONY AND CLEOPATRA'
# -------------------------
# '\t[Enter AGRIPPA at one door, DOMITIUS ENOBARBUS\n\tat another]'
# -------------------------
# '\t[Trumpets within]\n\t\t\tSo;\n\tThis is to horse. Adieu, noble Agrippa.'
# -------------------------
# '\t[Enter OCTAVIUS CAESAR, MARK ANTONY, LEPIDUS, and OCTAVIA]'
# -------------------------
# '\t[Kisses OCTAVIA]'
# -------------------------
# '\t[Trumpets sound. Exeunt]'
# -------------------------
# '\tANTONY AND CLEOPATRA'
# -------------------------
# '\t[Enter CLEOPATRA, CHARMIAN, IRAS, and ALEXAS]'
# -------------------------
# '\t[Enter the Messenger as before]'
# -------------------------
# '\tCome hither, sir.'
# -------------------------
# '\t[Exit Messenger]'
# -------------------------
# '\t[Exeunt]'
# -------------------------
# '\tANTONY AND CLEOPATRA'
# -------------------------
# '\t[Enter MARK ANTONY and OCTAVIA]'
# -------------------------
# '\t[Exeunt]'
# -------------------------
# '\tANTONY AND CLEOPATRA'
# -------------------------
# '\t[Enter DOMITIUS ENOBARBUS and EROS, meeting]'
# -------------------------
# '\t[Exeunt]'
# -------------------------
# '\tANTONY AND CLEOPATRA'
# -------------------------
# '\t[Enter OCTAVIUS CAESAR, AGRIPPA, and MECAENAS]'
# -------------------------
# '\t[Enter OCTAVIA with her train]'
# -------------------------
# '\t[Exeunt]'
# -------------------------
# '\tANTONY AND CLEOPATRA'
# -------------------------
# '\t[Enter CLEOPATRA and DOMITIUS ENOBARBUS]'
# -------------------------
# '\t[Enter MARK ANTONY and CANIDIUS]'
# -------------------------
# '\t[Enter a Messenger]'
# -------------------------
# '\t\t    Thy business?'
# -------------------------
# '\t[Enter a Soldier]'
# -------------------------
# '\tHow now, worthy soldier?'
# -------------------------
# '\t[Exeunt MARK ANTONY, QUEEN CLEOPATRA, and DOMITIUS\n\tENOBARBUS]'
# -------------------------
# '\t[Enter a Messenger]'
# -------------------------
# '\t[Exeunt]'
# -------------------------
# '\tANTONY AND CLEOPATRA'
# -------------------------
# '\t[Enter OCTAVIUS CAESAR, and TAURUS, with his army, marching]'
# -------------------------
# '\t[Exeunt]'
# -------------------------
# '\tANTONY AND CLEOPATRA'
# -------------------------
# '\t[Enter MARK ANTONY and DOMITIUS ENOBARBUS]'
# -------------------------
# '\t[Exeunt]'
# -------------------------
# '\tANTONY AND CLEOPATRA'
# -------------------------
# ('\t[CANIDIUS marcheth with his land army one way over\n'
#  '\tthe stage; and TAURUS, the lieutenant of OCTAVIUS\n'
#  '\tCAESAR, the other way. After their going in, is\n'
#  '\theard the noise of a sea-fight]')
# -------------------------
# '\t[Alarum. Enter DOMITIUS ENOBARBUS]'
# -------------------------
# '\t[Enter SCARUS]'
# -------------------------
# '\t[Enter CANIDIUS]'
# -------------------------
# '\t[Exeunt]'
# -------------------------
# '\tANTONY AND CLEOPATRA'
# -------------------------
# '\t[Enter MARK ANTONY with Attendants]'
# -------------------------
# '\t[Sits down]'
# -------------------------
# '\t[Enter CLEOPATRA led by CHARMIAN and IRAS; EROS\n\tfollowing]'
# -------------------------
# '\t[Exeunt]'
# -------------------------
# '\tANTONY AND CLEOPATRA'
# -------------------------
# '\t[Enter OCTAVIUS CAESAR, DOLABELLA, THYREUS, with others]'
# -------------------------
# '\t[Enter EUPHRONIUS, ambassador from MARK ANTONY]'
# -------------------------
# '\t[Exit EUPHRONIUS]'
# -------------------------
# ("\t[To THYREUS]  To try eloquence, now 'tis time: dispatch;\n"
#  '\tFrom Antony win Cleopatra: promise,\n'
#  '\tAnd in our name, what she requires; add more,\n'
#  '\tFrom thine invention, offers: women are not\n'
#  '\tIn their best fortunes strong; but want will perjure\n'
#  "\tThe ne'er touch'd vestal: try thy cunning, Thyreus;\n"
#  '\tMake thine own edict for thy pains, which we\n'
#  '\tWill answer as a law.')
# -------------------------
# '\t[Exeunt]'
# -------------------------
# '\tANTONY AND CLEOPATRA'
# -------------------------
# '\t[Enter CLEOPATRA, DOMITIUS ENOBARBUS, CHARMIAN, and IRAS]'
# -------------------------
# '\t[Enter MARK ANTONY with EUPHRONIUS, the Ambassador]'
# -------------------------
# '\t[Exeunt MARK ANTONY and EUPHRONIUS]'
# -------------------------
# '\t[Enter an Attendant]'
# -------------------------
# '\t[Exit Attendant]'
# -------------------------
# '\t[Enter THYREUS]'
# -------------------------
# '\t[Exit]'
# -------------------------
# '\t[Re-enter MARK ANTONY and DOMITIUS ENOBARBUS]'
# -------------------------
# '\t[Enter Attendants]'
# -------------------------
# '\tTake hence this Jack, and whip him.'
# -------------------------
# '\t[Exeunt Attendants with THYREUS]'
# -------------------------
# ('\tYou were half blasted ere I knew you: ha!\n'
#  "\tHave I my pillow left unpress'd in Rome,\n"
#  '\tForborne the getting of a lawful race,\n'
#  '\tAnd by a gem of women, to be abused\n'
#  '\tBy one that looks on feeders?')
# -------------------------
# '\t[Re-enter Attendants with THYREUS]'
# -------------------------
# "\t\t    Is he whipp'd?"
# -------------------------
# '\t[Exit THYREUS]'
# -------------------------
# '\t[Exeunt all but DOMITIUS ENOBARBUS]'
# -------------------------
# '\t[Exit]'
# -------------------------
# '\tANTONY AND CLEOPATRA'
# -------------------------
# ('\t[Enter OCTAVIUS CAESAR, AGRIPPA, and MECAENAS, with\n'
#  '\this Army; OCTAVIUS CAESAR reading a letter]')
# -------------------------
# '\t[Exeunt]'
# -------------------------
# '\tANTONY AND CLEOPATRA'
# -------------------------
# ('\t[Enter MARK ANTONY, CLEOPATRA, DOMITIUS ENOBARBUS,\n'
#  '\tCHARMIAN, IRAS, ALEXAS, with others]')
# -------------------------
# '\t[Enter three or four Servitors]'
# -------------------------
# ('\t\t    Give me thy hand,\n'
#  '\tThou hast been rightly honest;--so hast thou;--\n'
#  '\tThou,--and thou,--and thou:--you have served me well,\n'
#  '\tAnd kings have been your fellows.')
# -------------------------
# '\t[Exeunt]'
# -------------------------
# '\tANTONY AND CLEOPATRA'
# -------------------------
# '\t[Enter two Soldiers to their guard]'
# -------------------------
# '\t[Enter two other Soldiers]'
# -------------------------
# '\t[They place themselves in every corner of the stage]'
# -------------------------
# '\t[Music of the hautboys as under the stage]'
# -------------------------
# '\t[They advance to another post]'
# -------------------------
# '\t[Exeunt]'
# -------------------------
# '\tANTONY AND CLEOPATRA'
# -------------------------
# '\t[Enter MARK ANTONY and CLEOPATRA, CHARMIAN, and\n\tothers attending]'
# -------------------------
# '\t[Enter EROS with armour]'
# -------------------------
# ('\tCome good fellow, put mine iron on:\n'
#  '\tIf fortune be not ours to-day, it is\n'
#  '\tBecause we brave her: come.')
# -------------------------
# '\t[Enter an armed Soldier]'
# -------------------------
# ('\tGood morrow to thee; welcome:\n'
#  "\tThou look'st like him that knows a warlike charge:\n"
#  '\tTo business that we love we rise betime,\n'
#  "\tAnd go to't with delight.")
# -------------------------
# '\t[Shout. Trumpets flourish]'
# -------------------------
# '\t[Enter Captains and Soldiers]'
# -------------------------
# '\t[Kisses her]'
# -------------------------
# ('\tAnd worthy shameful cheque it were, to stand\n'
#  "\tOn more mechanic compliment; I'll leave thee\n"
#  '\tNow, like a man of steel. You that will fight,\n'
#  "\tFollow me close; I'll bring you to't. Adieu.")
# -------------------------
# '\t[Exeunt MARK ANTONY, EROS, Captains, and Soldiers]'
# -------------------------
# '\t[Exeunt]'
# -------------------------
# '\tANTONY AND CLEOPATRA'
# -------------------------
# '\t[Trumpets sound. Enter MARK ANTONY and EROS; a\n\tSoldier meeting them]'
# -------------------------
# '\t[Exeunt]'
# -------------------------
# '\tANTONY AND CLEOPATRA'
# -------------------------
# ('\t[Flourish. Enter OCTAVIUS CAESAR, AGRIPPA, with\n'
#  '\tDOMITIUS ENOBARBUS, and others]')
# -------------------------
# '\t[Exit]'
# -------------------------
# '\t[Enter a Messenger]'
# -------------------------
# '\t[Exeunt all but DOMITIUS ENOBARBUS]'
# -------------------------
# "\t[Enter a Soldier of CAESAR's]"
# -------------------------
# '\t[Exit]'
# -------------------------
# '\t[Exit]'
# -------------------------
# '\tANTONY AND CLEOPATRA'
# -------------------------
# '\t[Alarum. Drums and trumpets. Enter AGRIPPA\n\tand others]'
# -------------------------
# '\t[Exeunt]'
# -------------------------
# '\t[Alarums. Enter MARK ANTONY and SCARUS wounded]'
# -------------------------
# '\t[Enter EROS]'
# -------------------------
# '\t[Exeunt]'
# -------------------------
# '\tANTONY AND CLEOPATRA'
# -------------------------
# '\t[Alarum. Enter MARK ANTONY, in a march; SCARUS,\n\twith others]'
# -------------------------
# '\t[To SCARUS]'
# -------------------------
# '\t\t    Give me thy hand'
# -------------------------
# '\t[Enter CLEOPATRA, attended]'
# -------------------------
# "\tTo this great fairy I'll commend thy acts,\n\tMake her thanks bless thee."
# -------------------------
# '\t[To CLEOPATRA]'
# -------------------------
# ("\t\t      O thou day o' the world,\n"
#  "\tChain mine arm'd neck; leap thou, attire and all,\n"
#  '\tThrough proof of harness to my heart, and there\n'
#  '\tRide on the pants triumphing!')
# -------------------------
# '\t[Exeunt]'
# -------------------------
# '\tANTONY AND CLEOPATRA'
# -------------------------
# '\t[Sentinels at their post]'
# -------------------------
# '\t[Enter DOMITIUS ENOBARBUS]'
# -------------------------
# '\t[Dies]'
# -------------------------
# '\t[Drums afar off]'
# -------------------------
# ('\t\t                  Hark! the drums\n'
#  '\tDemurely wake the sleepers. Let us bear him\n'
#  '\tTo the court of guard; he is of note: our hour\n'
#  '\tIs fully out.')
# -------------------------
# '\t[Exeunt with the body]'
# -------------------------
# '\tANTONY AND CLEOPATRA'
# -------------------------
# '\t[Enter MARK ANTONY and SCARUS, with their Army]'
# -------------------------
# '\t[Exeunt]'
# -------------------------
# '\tANTONY AND CLEOPATRA'
# -------------------------
# '\t[Enter OCTAVIUS CAESAR, and his Army]'
# -------------------------
# '\t[Exeunt]'
# -------------------------
# '\tANTONY AND CLEOPATRA'
# -------------------------
# '\t[Enter MARK ANTONY and SCARUS]'
# -------------------------
# '\t[Exit]'
# -------------------------
# '\t[Alarum afar off, as at a sea-fight]'
# -------------------------
# '\t[Re-enter MARK ANTONY]'
# -------------------------
# '\t[Exit SCARUS]'
# -------------------------
# ('\tO sun, thy uprise shall I see no more:\n'
#  '\tFortune and Antony part here; even here\n'
#  '\tDo we shake hands. All come to this? The hearts\n'
#  "\tThat spaniel'd me at heels, to whom I gave\n"
#  '\tTheir wishes, do discandy, melt their sweets\n'
#  "\tOn blossoming Caesar; and this pine is bark'd,\n"
#  "\tThat overtopp'd them all. Betray'd I am:\n"
#  '\tO this false soul of Egypt! this grave charm,--\n'
#  "\tWhose eye beck'd forth my wars, and call'd them home;\n"
#  '\tWhose bosom was my crownet, my chief end,--\n'
#  '\tLike a right gipsy, hath, at fast and loose,\n'
#  '\tBeguiled me to the very heart of loss.\n'
#  '\tWhat, Eros, Eros!')
# -------------------------
# '\t[Enter CLEOPATRA]'
# -------------------------
# '\tAh, thou spell! Avaunt!'
# -------------------------
# '\t[Exit CLEOPATRA]'
# -------------------------
# ("\t\t'Tis well thou'rt gone,\n"
#  "\tIf it be well to live; but better 'twere\n"
#  "\tThou fell'st into my fury, for one death\n"
#  '\tMight have prevented many. Eros, ho!\n'
#  '\tThe shirt of Nessus is upon me: teach me,\n'
#  '\tAlcides, thou mine ancestor, thy rage:\n'
#  "\tLet me lodge Lichas on the horns o' the moon;\n"
#  "\tAnd with those hands, that grasp'd the heaviest club,\n"
#  '\tSubdue my worthiest self. The witch shall die:\n'
#  '\tTo the young Roman boy she hath sold me, and I fall\n'
#  "\tUnder this plot; she dies for't. Eros, ho!")
# -------------------------
# '\t[Exit]'
# -------------------------
# '\tANTONY AND CLEOPATRA'
# -------------------------
# '\t[Enter CLEOPATRA, CHARMIAN, IRAS, and MARDIAN]'
# -------------------------
# '\t[Exeunt]'
# -------------------------
# '\tANTONY AND CLEOPATRA'
# -------------------------
# '\t[Enter MARK ANTONY and EROS]'
# -------------------------
# '\t[Enter MARDIAN]'
# -------------------------
# "\t\t      O! thy vile lady!\n\tShe has robb'd me of my sword."
# -------------------------
# '\t[To MARDIAN]'
# -------------------------
# "\tThat thou depart'st hence safe,\n\tDoes pay thy labour richly; go."
# -------------------------
# '\t[Exit MARDIAN]'
# -------------------------
# ('\t\t         Off, pluck off:\n'
#  '\tThe seven-fold shield of Ajax cannot keep\n'
#  '\tThe battery from my heart. O, cleave, my sides!\n'
#  '\tHeart, once be stronger than thy continent,\n'
#  '\tCrack thy frail case! Apace, Eros, apace.\n'
#  '\tNo more a soldier: bruised pieces, go;\n'
#  '\tYou have been nobly borne. From me awhile.')
# -------------------------
# '\t[Exit EROS]'
# -------------------------
# ("\tI will o'ertake thee, Cleopatra, and\n"
#  '\tWeep for my pardon. So it must be, for now\n'
#  '\tAll length is torture: since the torch is out,\n'
#  '\tLie down, and stray no farther: now all labour\n'
#  '\tMars what it does; yea, very force entangles\n'
#  '\tItself with strength: seal then, and all is done.\n'
#  '\tEros!--I come, my queen:--Eros!--Stay for me:\n'
#  "\tWhere souls do couch on flowers, we'll hand in hand,\n"
#  '\tAnd with our sprightly port make the ghosts gaze:\n'
#  '\tDido and her AEneas shall want troops,\n'
#  '\tAnd all the haunt be ours. Come, Eros, Eros!')
# -------------------------
# '\t[Re-enter EROS]'
# -------------------------
# '\t[Turning from him]'
# -------------------------
# '\t[Kills himself]'
# -------------------------
# '\t[Falling on his sword]'
# -------------------------
# ("\tI learn'd of thee. How! not dead? not dead?\n"
#  '\tThe guard, ho! O, dispatch me!')
# -------------------------
# '\t[Enter DERCETAS and Guard]'
# -------------------------
# '\t[Exeunt Guard]'
# -------------------------
# '\t[Enter DIOMEDES]'
# -------------------------
# '\t[Exit DERCETAS]'
# -------------------------
# '\t[Enter four or five of the Guard of MARK ANTONY]'
# -------------------------
# '\t[Exeunt, bearing MARK ANTONY]'
# -------------------------
# '\tANTONY AND CLEOPATRA'
# -------------------------
# '\t[Enter CLEOPATRA and her maids aloft, with\n\tCHARMIAN and IRAS]'
# -------------------------
# '\t[Enter, below, DIOMEDES]'
# -------------------------
# '\t\t  How now! is he dead?'
# -------------------------
# '\t[Enter, below, MARK ANTONY, borne by the Guard]'
# -------------------------
# '\t[They heave MARK ANTONY aloft to CLEOPATRA]'
# -------------------------
# ('\tAnd welcome, welcome! die where thou hast lived:\n'
#  '\tQuicken with kissing: had my lips that power,\n'
#  '\tThus would I wear them out.')
# -------------------------
# '\t[MARK ANTONY dies]'
# -------------------------
# ("\tThe crown o' the earth doth melt. My lord!\n"
#  "\tO, wither'd is the garland of the war,\n"
#  "\tThe soldier's pole is fall'n: young boys and girls\n"
#  '\tAre level now with men; the odds is gone,\n'
#  '\tAnd there is nothing left remarkable\n'
#  '\tBeneath the visiting moon.')
# -------------------------
# '\t[Faints]'
# -------------------------
# "\t[Exeunt; those above bearing off MARK ANTONY's body]"
# -------------------------
# '\tANTONY AND CLEOPATRA'
# -------------------------
# ('\t[Enter OCTAVIUS CAESAR, AGRIPPA, DOLABELLA, MECAENAS,\n'
#  '\tGALLUS, PROCULEIUS, and others, his council of war]')
# -------------------------
# '\t[Exit]'
# -------------------------
# '\t[Enter DERCETAS, with the sword of MARK ANTONY]'
# -------------------------
# '\t[Enter an Egyptian]'
# -------------------------
# ('\tThe business of this man looks out of him;\n'
#  "\tWe'll hear him what he says. Whence are you?")
# -------------------------
# '\t[Exit]'
# -------------------------
# '\t[Exit]'
# -------------------------
# '\t[Exit GALLUS]'
# -------------------------
# "\t\tWhere's Dolabella,\n\tTo second Proculeius?"
# -------------------------
# '\t[Exeunt]'
# -------------------------
# '\tANTONY AND CLEOPATRA'
# -------------------------
# '\t[Enter CLEOPATRA, CHARMIAN, and IRAS]'
# -------------------------
# '\t[Enter, to the gates of the monument, PROCULEIUS,\n\tGALLUS and Soldiers]'
# -------------------------
# ('\t[Here PROCULEIUS and two of the Guard ascend the\n'
#  '\tmonument by a ladder placed against a window, and,\n'
#  '\thaving descended, come behind CLEOPATRA. Some of\n'
#  '\tthe Guard unbar and open the gates]')
# -------------------------
# '\t[To PROCULEIUS and the Guard]'
# -------------------------
# '\tGuard her till Caesar come.'
# -------------------------
# '\t[Exit]'
# -------------------------
# '\t[Drawing a dagger]'
# -------------------------
# '\t[Seizes and disarms her]'
# -------------------------
# "\tDo not yourself such wrong, who are in this\n\tRelieved, but not betray'd."
# -------------------------
# '\t[Enter DOLABELLA]'
# -------------------------
# '\t[To CLEOPATRA]'
# -------------------------
# "\tTo Caesar I will speak what you shall please,\n\tIf you'll employ me to him."
# -------------------------
# '\t[Exeunt PROCULEIUS and Soldiers]'
# -------------------------
# "\t[Flourish, and shout within, 'Make way there:\n\tOctavius Caesar!']"
# -------------------------
# ('\t[Enter OCTAVIUS CAESAR, GALLUS, PROCULEIUS,\n'
#  '\tMECAENAS, SELEUCUS, and others of his Train]')
# -------------------------
# '\t[CLEOPATRA kneels]'
# -------------------------
# '\t[To SELEUCUS]'
# -------------------------
# ('\t\t   Prithee, go hence;\n'
#  '\tOr I shall show the cinders of my spirits\n'
#  '\tThrough the ashes of my chance: wert thou a man,\n'
#  '\tThou wouldst have mercy on me.')
# -------------------------
# '\t[Exit SELEUCUS]'
# -------------------------
# '\t[Flourish. Exeunt OCTAVIUS CAESAR and his train]'
# -------------------------
# '\t[Whispers CHARMIAN]'
# -------------------------
# '\t[Re-enter DOLABELLA]'
# -------------------------
# '\t[Exit]'
# -------------------------
# '\t[Exit DOLABELLA]'
# -------------------------
# ("\t\tNow, Iras, what think'st thou?\n"
#  '\tThou, an Egyptian puppet, shalt be shown\n'
#  '\tIn Rome, as well as I\tmechanic slaves\n'
#  '\tWith greasy aprons, rules, and hammers, shall\n'
#  '\tUplift us to the view; in their thick breaths,\n'
#  '\tRank of gross diet, shall be enclouded,\n'
#  '\tAnd forced to drink their vapour.')
# -------------------------
# '\t[Re-enter CHARMIAN]'
# -------------------------
# ('\t\t     Now, Charmian!\n'
#  '\tShow me, my women, like a queen: go fetch\n'
#  '\tMy best attires: I am again for Cydnus,\n'
#  '\tTo meet Mark Antony: sirrah Iras, go.\n'
#  "\tNow, noble Charmian, we'll dispatch indeed;\n"
#  "\tAnd, when thou hast done this chare, I'll give thee leave\n"
#  '\tTo play till doomsday. Bring our crown and all.\n'
#  "\tWherefore's this noise?")
# -------------------------
# '\t[Exit IRAS. A noise within]'
# -------------------------
# '\t[Enter a Guardsman]'
# -------------------------
# '\t[Exit Guardsman]'
# -------------------------
# ('\tWhat poor an instrument\n'
#  '\tMay do a noble deed! he brings me liberty.\n'
#  "\tMy resolution's placed, and I have nothing\n"
#  '\tOf woman in me: now from head to foot\n'
#  '\tI am marble-constant; now the fleeting moon\n'
#  '\tNo planet is of mine.')
# -------------------------
# '\t[Re-enter Guardsman, with Clown bringing in a basket]'
# -------------------------
# '\t[Exit Guardsman]'
# -------------------------
# '\tHast thou the pretty worm of Nilus there,\n\tThat kills and pains not?'
# -------------------------
# '\t[Setting down his basket]'
# -------------------------
# '\t[Exit]'
# -------------------------
# '\t[Re-enter IRAS with a robe, crown, &c]'
# -------------------------
# '\t[Kisses them. IRAS falls and dies]'
# -------------------------
# ('\tHave I the aspic in my lips? Dost fall?\n'
#  '\tIf thou and nature can so gently part,\n'
#  "\tThe stroke of death is as a lover's pinch,\n"
#  '\tWhich hurts, and is desired. Dost thou lie still?\n'
#  "\tIf thus thou vanishest, thou tell'st the world\n"
#  '\tIt is not worth leave-taking.')
# -------------------------
# '\t[To an asp, which she applies to her breast]'
# -------------------------
# ('\tWith thy sharp teeth this knot intrinsicate\n'
#  '\tOf life at once untie: poor venomous fool\n'
#  '\tBe angry, and dispatch. O, couldst thou speak,\n'
#  '\tThat I might hear thee call great Caesar ass\n'
#  '\tUnpolicied!')
# -------------------------
# '\t[Applying another asp to her arm]'
# -------------------------
# '\tWhat should I stay--'
# -------------------------
# '\t[Dies]'
# -------------------------
# '\t[Enter the Guard, rushing in]'
# -------------------------
# '\t[Applies an asp]'
# -------------------------
# '\tO, come apace, dispatch! I partly feel thee.'
# -------------------------
# '\t[Dies]'
# -------------------------
# '\t[Re-enter DOLABELLA]'
# -------------------------
# "\t[Within  'A way there, a way for Caesar!']"
# -------------------------
# '\t[Re-enter OCTAVIUS CAESAR and all his train marching]'
# -------------------------
# '\t[Exeunt]\n'
# -------------------------
# ====================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================
# 1
# '\t[Exeunt]'
# -------------------------
# '\tTHE COMEDY OF ERRORS'
# -------------------------
# '\t[Enter ANTIPHOLUS of Syracuse, DROMIO of Syracuse,\n\tand First Merchant]'
# -------------------------
# '\t[Exit]'
# -------------------------
# '\t[Exit]'
# -------------------------
# '\t[Enter DROMIO of Ephesus]'
# -------------------------
# ('\tHere comes the almanac of my true date.\n'
#  "\tWhat now? how chance thou art return'd so soon?")
# -------------------------
# '\t[Exit]'
# -------------------------
# '\t[Exit]'
# -------------------------
# '\tTHE COMEDY OF ERRORS'
# -------------------------
# '\t[Enter ADRIANA and LUCIANA]'
# -------------------------
# '\t[Enter DROMIO of Ephesus]'
# -------------------------
# '\t[Exit]'
# -------------------------
# '\t[Exeunt]'
# -------------------------
# '\tTHE COMEDY OF ERRORS'
# -------------------------
# '\t[Enter ANTIPHOLUS of Syracuse]'
# -------------------------
# '\t[Enter DROMIO of Syracuse]'
# -------------------------
# ("\tHow now sir! is your merry humour alter'd?\n"
#  '\tAs you love strokes, so jest with me again.\n'
#  '\tYou know no Centaur? you received no gold?\n'
#  '\tYour mistress sent to have me home to dinner?\n'
#  '\tMy house was at the Phoenix? Wast thou mad,\n'
#  '\tThat thus so madly thou didst answer me?')
# -------------------------
# '\t[Beating him]'
# -------------------------
# '\t[Enter ADRIANA and LUCIANA]'
# -------------------------
# '\t[Exeunt]'
# -------------------------
# '\tTHE COMEDY OF ERRORS'
# -------------------------
# '\t[Enter ANTIPHOLUS of Ephesus, DROMIO of Ephesus,\n\tANGELO, and BALTHAZAR]'
# -------------------------
# '\t[To Angelo]'
# -------------------------
# ('\t\t    Get you home\n'
#  "\tAnd fetch the chain; by this I know 'tis made:\n"
#  '\tBring it, I pray you, to the Porpentine;\n'
#  "\tFor there's the house: that chain will I bestow--\n"
#  '\tBe it for nothing but to spite my wife--\n'
#  '\tUpon mine hostess there: good sir, make haste.\n'
#  '\tSince mine own doors refuse to entertain me,\n'
#  "\tI'll knock elsewhere, to see if they'll disdain me.")
# -------------------------
# '\t[Exeunt]'
# -------------------------
# '\tTHE COMEDY OF ERRORS'
# -------------------------
# '\t[Enter LUCIANA and ANTIPHOLUS of Syracuse]'
# -------------------------
# '\t[Exit]'
# -------------------------
# '\t[Enter DROMIO of Syracuse]'
# -------------------------
# '\t[Exit]'
# -------------------------
# '\t[Enter ANGELO with the chain]'
# -------------------------
# '\t[Exit]'
# -------------------------
# '\t[Exit]'
# -------------------------
# '\tTHE COMEDY OF ERRORS'
# -------------------------
# '\t[Enter Second Merchant, ANGELO, and an Officer]'
# -------------------------
# "\t[Enter ANTIPHOLUS of Ephesus and DROMIO of Ephesus\n\tfrom the courtezan's]"
# -------------------------
# '\t[Exit]'
# -------------------------
# '\t[Enter DROMIO of Syracuse, from the bay]'
# -------------------------
# '\t[Exeunt Second Merchant, Angelo, Officer, and\n\tAntipholus of Ephesus]'
# -------------------------
# '\t[Exit]'
# -------------------------
# '\tTHE COMEDY OF ERRORS'
# -------------------------
# '\t[Enter ADRIANA and LUCIANA]'
# -------------------------
# '\t[Enter DROMIO of Syracuse]'
# -------------------------
# '\t[Exit Luciana]'
# -------------------------
# ('\t\tThis I wonder at,\n'
#  '\tThat he, unknown to me, should be in debt.\n'
#  '\tTell me, was he arrested on a band?')
# -------------------------
# '\t[Re-enter LUCIANA with a purse]'
# -------------------------
# '\t[Exeunt]'
# -------------------------
# '\tTHE COMEDY OF ERRORS'
# -------------------------
# '\t[Enter ANTIPHOLUS of Syracuse]'
# -------------------------
# '\t[Enter DROMIO OF SYRACUSE]'
# -------------------------
# '\t[Enter a Courtezan]'
# -------------------------
# '\t[Exeunt Antipholus of Syracuse and Dromio of Syracuse]'
# -------------------------
# '\t[Exit]'
# -------------------------
# '\tTHE COMEDY OF ERRORS'
# -------------------------
# '\t[Enter ANTIPHOLUS of Ephesus and the Officer]'
# -------------------------
# "\t[Enter DROMIO of Ephesus with a rope's-end]"
# -------------------------
# ('\tHere comes my man; I think he brings the money.\n'
#  '\tHow now, sir! have you that I sent you for?')
# -------------------------
# '\t[Beating him]'
# -------------------------
# '\t[Enter ADRIANA, LUCIANA, the Courtezan, and PINCH]'
# -------------------------
# '\t[Beating him]'
# -------------------------
# '\t[Striking him]'
# -------------------------
# '\t[Enter three or four, and offer to bind him.\n\tHe strives]'
# -------------------------
# '\t[They offer to bind Dromio of Ephesus]'
# -------------------------
# '\t[Exeunt all but Adriana, Luciana, Officer and\n\tCourtezan]'
# -------------------------
# '\tSay now, whose suit is he arrested at?'
# -------------------------
# ('\t[Enter ANTIPHOLUS of Syracuse with his rapier drawn,\n'
#  '\tand DROMIO of Syracuse]')
# -------------------------
# '\t[Exeunt all but Antipholus of Syracuse and Dromio\n\tof Syracuse]'
# -------------------------
# '\t[Exeunt]'
# -------------------------
# '\tTHE COMEDY OF ERRORS'
# -------------------------
# '\t[Enter Second Merchant and ANGELO]'
# -------------------------
# '\t[Enter ANTIPHOLUS of Syracuse and DROMIO of Syracuse]'
# -------------------------
# '\t[They draw]'
# -------------------------
# '\t[Enter ADRIANA, LUCIANA, the Courtezan, and others]'
# -------------------------
# '\t[Exeunt Antipholus of Syracuse and Dromio of Syracuse\n\tto the Priory]'
# -------------------------
# '\t[Enter the Lady Abbess, AEMILIA]'
# -------------------------
# '\t[Exit]'
# -------------------------
# ('\t[Enter DUKE SOLINUS, attended; AEGEON bareheaded; with the\n'
#  '\tHeadsman and other Officers]')
# -------------------------
# '\t[Enter a Servant]'
# -------------------------
# '\t[Cry within]'
# -------------------------
# '\tHark, hark! I hear him, mistress. fly, be gone!'
# -------------------------
# '\t[Enter ANTIPHOLUS of Ephesus and DROMIO of Ephesus]'
# -------------------------
# '\t[Exit one to Abbess]'
# -------------------------
# '\t[Re-enter AEMILIA, with ANTIPHOLUS of Syracuse and\n\tDROMIO of Syracuse]'
# -------------------------
# '\t[All gather to see them]'
# -------------------------
# '\t[To Luciana]'
# -------------------------
# ('\t\tWhat I told you then,\n'
#  '\tI hope I shall have leisure to make good;\n'
#  '\tIf this be not a dream I see and hear.')
# -------------------------
# ('\t[Exeunt all but Antipholus of Syracuse, Antipholus\n'
#  '\tof Ephesus, Dromio of Syracuse and Dromio of Ephesus]')
# -------------------------
# '\t[Exeunt Antipholus of Syracuse and Antipholus of Ephesus]'
# -------------------------
# '\t[Exeunt]\n'
# -------------------------
# ====================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================
# 2
# '\t[Enter OLIVER]'
# -------------------------
# '\t[Exeunt ORLANDO and ADAM]'
# -------------------------
# '\t[Enter DENNIS]'
# -------------------------
# '\t[Exit DENNIS]'
# -------------------------
# "\t'Twill be a good way; and to-morrow the wrestling is."
# -------------------------
# '\t[Enter CHARLES]'
# -------------------------
# '\t[Exit CHARLES]'
# -------------------------
# ('\tNow will I stir this gamester: I hope I shall see\n'
#  '\tan end of him; for my soul, yet I know not why,\n'
#  "\thates nothing more than he. Yet he's gentle, never\n"
#  '\tschooled and yet learned, full of noble device, of\n'
#  '\tall sorts enchantingly beloved, and indeed so much\n'
#  '\tin the heart of the world, and especially of my own\n'
#  '\tpeople, who best know him, that I am altogether\n'
#  '\tmisprised: but it shall not be so long; this\n'
#  '\twrestler shall clear all: nothing remains but that\n'
#  "\tI kindle the boy thither; which now I'll go about.")
# -------------------------
# '\t[Exit]'
# -------------------------
# '\tAS YOU LIKE IT'
# -------------------------
# '\t[Enter CELIA and ROSALIND]'
# -------------------------
# '\t[Enter TOUCHSTONE]'
# -------------------------
# '\t[Enter LE BEAU]'
# -------------------------
# "\tBon jour, Monsieur Le Beau: what's the news?"
# -------------------------
# '\t[Flourish. Enter DUKE FREDERICK, Lords, ORLANDO,\n\tCHARLES, and Attendants]'
# -------------------------
# '\t[They wrestle]'
# -------------------------
# '\t[Shout. CHARLES is thrown]'
# -------------------------
# '\t[Exeunt DUKE FREDERICK, train, and LE BEAU]'
# -------------------------
# '\t[Giving him a chain from her neck]'
# -------------------------
# ('\tWear this for me, one out of suits with fortune,\n'
#  '\tThat could give more, but that her hand lacks means.\n'
#  '\tShall we go, coz?')
# -------------------------
# '\t[Exeunt ROSALIND and CELIA]'
# -------------------------
# '\t[Re-enter LE BEAU]'
# -------------------------
# '\t[Exit LE BEAU]'
# -------------------------
# ('\tThus must I from the smoke into the smother;\n'
#  '\tFrom tyrant duke unto a tyrant brother:\n'
#  '\tBut heavenly Rosalind!')
# -------------------------
# '\t[Exit]'
# -------------------------
# '\tAS YOU LIKE IT'
# -------------------------
# '\t[Enter CELIA and ROSALIND]'
# -------------------------
# '\t[Enter DUKE FREDERICK, with Lords]'
# -------------------------
# '\t[Exeunt DUKE FREDERICK and Lords]'
# -------------------------
# '\t[Exeunt]'
# -------------------------
# '\tAS YOU LIKE IT'
# -------------------------
# '\t[Enter DUKE SENIOR, AMIENS, and two or three Lords,\n\tlike foresters]'
# -------------------------
# '\t[Exeunt]'
# -------------------------
# '\tAS YOU LIKE IT'
# -------------------------
# '\t[Enter DUKE FREDERICK, with Lords]'
# -------------------------
# '\t[Exeunt]'
# -------------------------
# '\tAS YOU LIKE IT'
# -------------------------
# '\t[Enter ORLANDO and ADAM, meeting]'
# -------------------------
# '\t[Exeunt]'
# -------------------------
# '\tAS YOU LIKE IT'
# -------------------------
# '\t[Enter ROSALIND for Ganymede, CELIA for Aliena,\n\tand TOUCHSTONE]'
# -------------------------
# '\t[Enter CORIN and SILVIUS]'
# -------------------------
# '\tLook you, who comes here; a young man and an old in\n\tsolemn talk.'
# -------------------------
# '\t[Exit]'
# -------------------------
# '\t[Exeunt]'
# -------------------------
# '\tAS YOU LIKE IT'
# -------------------------
# ('\t[Enter AMIENS, JAQUES, and others]\n'
#  '\t\n'
#  '\tSONG.\n'
#  'AMIENS\tUnder the greenwood tree\n'
#  '\tWho loves to lie with me,\n'
#  '\tAnd turn his merry note\n'
#  "\tUnto the sweet bird's throat,\n"
#  '\tCome hither, come hither, come hither:\n'
#  '\tHere shall he see No enemy\n'
#  '\tBut winter and rough weather.')
# -------------------------
# '\t[All together here]'
# -------------------------
# ("\tAnd loves to live i' the sun,\n"
#  '\tSeeking the food he eats\n'
#  '\tAnd pleased with what he gets,\n'
#  '\tCome hither, come hither, come hither:\n'
#  '\tHere shall he see No enemy\n'
#  '\tBut winter and rough weather.')
# -------------------------
# ('\tIf it do come to pass\n'
#  '\tThat any man turn ass,\n'
#  '\tLeaving his wealth and ease,\n'
#  '\tA stubborn will to please,\n'
#  '\tDucdame, ducdame, ducdame:\n'
#  '\tHere shall he see\n'
#  '\tGross fools as he,\n'
#  '\tAn if he will come to me.')
# -------------------------
# '\t[Exeunt severally]'
# -------------------------
# '\tAS YOU LIKE IT'
# -------------------------
# '\t[Enter ORLANDO and ADAM]'
# -------------------------
# '\t[Exeunt]'
# -------------------------
# '\tAS YOU LIKE IT'
# -------------------------
# '\t[A table set out. Enter DUKE SENIOR, AMIENS, and\n\tLords like outlaws]'
# -------------------------
# '\t[Enter JAQUES]'
# -------------------------
# '\t[Enter ORLANDO, with his sword drawn]'
# -------------------------
# '\t[Exit]'
# -------------------------
# '\t[Re-enter ORLANDO, with ADAM]'
# -------------------------
# '\t[Exeunt]'
# -------------------------
# '\tAS YOU LIKE IT'
# -------------------------
# '\t[Enter DUKE FREDERICK, Lords, and OLIVER]'
# -------------------------
# '\t[Exeunt]'
# -------------------------
# '\tAS YOU LIKE IT'
# -------------------------
# '\t[Enter ORLANDO, with a paper]'
# -------------------------
# '\t[Exit]'
# -------------------------
# '\t[Enter CORIN and TOUCHSTONE]'
# -------------------------
# '\t[Enter ROSALIND, with a paper, reading]'
# -------------------------
# '\t[Enter CELIA, with a writing]'
# -------------------------
# ('\tWhy should this a desert be?\n'
#  '\tFor it is unpeopled? No:\n'
#  "\tTongues I'll hang on every tree,\n"
#  '\tThat shall civil sayings show:\n'
#  '\tSome, how brief the life of man\n'
#  '\tRuns his erring pilgrimage,\n'
#  '\tThat the stretching of a span\n'
#  '\tBuckles in his sum of age;\n'
#  '\tSome, of violated vows\n'
#  "\t'Twixt the souls of friend and friend:\n"
#  '\tBut upon the fairest boughs,\n'
#  '\tOr at every sentence end,\n'
#  '\tWill I Rosalinda write,\n'
#  '\tTeaching all that read to know\n'
#  '\tThe quintessence of every sprite\n'
#  '\tHeaven would in little show.\n'
#  '\tTherefore Heaven Nature charged\n'
#  "\tThat one body should be fill'd\n"
#  '\tWith all graces wide-enlarged:\n'
#  "\tNature presently distill'd\n"
#  "\tHelen's cheek, but not her heart,\n"
#  "\tCleopatra's majesty,\n"
#  "\tAtalanta's better part,\n"
#  "\tSad Lucretia's modesty.\n"
#  '\tThus Rosalind of many parts\n'
#  '\tBy heavenly synod was devised,\n'
#  '\tOf many faces, eyes and hearts,\n'
#  '\tTo have the touches dearest prized.\n'
#  '\tHeaven would that she these gifts should have,\n'
#  '\tAnd I to live and die her slave.')
# -------------------------
# '\t[Exeunt CORIN and TOUCHSTONE]'
# -------------------------
# '\t[Enter ORLANDO and JAQUES]'
# -------------------------
# '\t[Exit JAQUES]'
# -------------------------
# '\t[Exeunt]'
# -------------------------
# '\tAS YOU LIKE IT'
# -------------------------
# '\t[Enter TOUCHSTONE and AUDREY; JAQUES behind]'
# -------------------------
# '\t[Enter SIR OLIVER MARTEXT]'
# -------------------------
# ('\tSir Oliver Martext, you are well met: will you\n'
#  '\tdispatch us here under this tree, or shall we go\n'
#  '\twith you to your chapel?')
# -------------------------
# "\tProceed, proceed\tI'll give her."
# -------------------------
# '\t[Exeunt JAQUES, TOUCHSTONE and AUDREY]'
# -------------------------
# '\t[Exit]'
# -------------------------
# '\tAS YOU LIKE IT'
# -------------------------
# '\t[Enter ROSALIND and CELIA]'
# -------------------------
# '\t[Enter CORIN]'
# -------------------------
# '\t[Exeunt]'
# -------------------------
# '\tAS YOU LIKE IT'
# -------------------------
# '\t[Enter SILVIUS and PHEBE]'
# -------------------------
# '\t[Enter ROSALIND, CELIA, and CORIN, behind]'
# -------------------------
# '\t[Exeunt ROSALIND, CELIA and CORIN]'
# -------------------------
# '\t[Exeunt]'
# -------------------------
# '\tAS YOU LIKE IT'
# -------------------------
# '\t[Enter ROSALIND, CELIA, and JAQUES]'
# -------------------------
# '\t[Enter ORLANDO]'
# -------------------------
# '\t[Exit]'
# -------------------------
# '\t[Exit ORLANDO]'
# -------------------------
# '\t[Exeunt]'
# -------------------------
# '\tAS YOU LIKE IT'
# -------------------------
# '\t[Enter JAQUES, Lords, and Foresters]'
# -------------------------
# '\t[The rest shall bear this burden]'
# -------------------------
# ('\tTake thou no scorn to wear the horn;\n'
#  '\tIt was a crest ere thou wast born:\n'
#  "\tThy father's father wore it,\n"
#  '\tAnd thy father bore it:\n'
#  '\tThe horn, the horn, the lusty horn\n'
#  '\tIs not a thing to laugh to scorn.')
# -------------------------
# '\t[Exeunt]'
# -------------------------
# '\tAS YOU LIKE IT'
# -------------------------
# '\t[Enter ROSALIND and CELIA]'
# -------------------------
# '\t[Enter SILVIUS]'
# -------------------------
# '\t[Reads]'
# -------------------------
# ("\tArt thou god to shepherd turn'd,\n"
#  "\tThat a maiden's heart hath burn'd?\n"
#  '\tCan a woman rail thus?')
# -------------------------
# ('\tWhy, thy godhead laid apart,\n'
#  "\tWarr'st thou with a woman's heart?\n"
#  '\tDid you ever hear such railing?\n'
#  '\tWhiles the eye of man did woo me,\n'
#  '\tThat could do no vengeance to me.\n'
#  '\tMeaning me a beast.\n'
#  '\tIf the scorn of your bright eyne\n'
#  '\tHave power to raise such love in mine,\n'
#  '\tAlack, in me what strange effect\n'
#  '\tWould they work in mild aspect!\n'
#  '\tWhiles you chid me, I did love;\n'
#  '\tHow then might your prayers move!\n'
#  '\tHe that brings this love to thee\n'
#  '\tLittle knows this love in me:\n'
#  '\tAnd by him seal up thy mind;\n'
#  '\tWhether that thy youth and kind\n'
#  '\tWill the faithful offer take\n'
#  '\tOf me and all that I can make;\n'
#  '\tOr else by him my love deny,\n'
#  "\tAnd then I'll study how to die.")
# -------------------------
# '\t[Exit SILVIUS]'
# -------------------------
# '\t[Enter OLIVER]'
# -------------------------
# '\t[ROSALIND swoons]'
# -------------------------
# '\t[Exeunt]'
# -------------------------
# '\tAS YOU LIKE IT'
# -------------------------
# '\t[Enter TOUCHSTONE and AUDREY]'
# -------------------------
# '\t[Enter WILLIAM]'
# -------------------------
# '\t[Exit]'
# -------------------------
# '\t[Enter CORIN]'
# -------------------------
# '\t[Exeunt]'
# -------------------------
# '\tAS YOU LIKE IT'
# -------------------------
# '\t[Enter ORLANDO and OLIVER]'
# -------------------------
# '\t[Enter ROSALIND]'
# -------------------------
# '\t[Exit]'
# -------------------------
# '\t[Enter SILVIUS and PHEBE]'
# -------------------------
# '\tLook, here comes a lover of mine and a lover of hers.'
# -------------------------
# '\t[To SILVIUS]'
# -------------------------
# '\tI will help you, if I can:'
# -------------------------
# '\t[To PHEBE]'
# -------------------------
# '\tI would love you, if I could. To-morrow meet me all together.'
# -------------------------
# '\t[To PHEBE]'
# -------------------------
# "\tI will marry you, if ever I marry woman, and I'll be\n\tmarried to-morrow:"
# -------------------------
# '\t[To ORLANDO]'
# -------------------------
# ('\tI will satisfy you, if ever I satisfied man, and you\n'
#  '\tshall be married to-morrow:')
# -------------------------
# '\t[To SILVIUS]'
# -------------------------
# ('\tI will content you, if what pleases you contents\n'
#  '\tyou, and you shall be married to-morrow.')
# -------------------------
# '\t[To ORLANDO]'
# -------------------------
# '\tAs you love Rosalind, meet:'
# -------------------------
# '\t[To SILVIUS]'
# -------------------------
# ('\tas you love Phebe, meet: and as I love no woman,\n'
#  "\tI'll meet. So fare you well: I have left you commands.")
# -------------------------
# '\t[Exeunt]'
# -------------------------
# '\tAS YOU LIKE IT'
# -------------------------
# '\t[Enter TOUCHSTONE and AUDREY]'
# -------------------------
# '\t[Enter two Pages]'
# -------------------------
# ('\tBetween the acres of the rye,\n'
#  '\tWith a hey, and a ho, and a hey nonino\n'
#  '\tThese pretty country folks would lie,\n'
#  '\tIn spring time, &c.')
# -------------------------
# ('\tThis carol they began that hour,\n'
#  '\tWith a hey, and a ho, and a hey nonino,\n'
#  '\tHow that a life was but a flower\n'
#  '\tIn spring time, &c.')
# -------------------------
# ('\tAnd therefore take the present time,\n'
# ...
#  '\tcolours; commoners being with him]')
# -------------------------
# '\t[The Conspirators draw, and kill CORIOLANUS:\n\tAUFIDIUS stands on his body]'
# -------------------------
# '\t[Exeunt, bearing the body of CORIOLANUS. A dead\n\tmarch sounded]\n'
# -------------------------
# ====================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================
# 4
# '\t[Exit]'
# -------------------------
# '\t[Exeunt BERTRAM and LAFEU]'
# -------------------------
# '\t[Enter PAROLLES]'
# -------------------------
# '\t[Aside]'
# -------------------------
# ('\tOne that goes with him: I love him for his sake;\n'
#  '\tAnd yet I know him a notorious liar,\n'
#  '\tThink him a great way fool, solely a coward;\n'
#  '\tYet these fixed evils sit so fit in him,\n'
#  "\tThat they take place, when virtue's steely bones\n"
#  "\tLook bleak i' the cold wind: withal, full oft we see\n"
#  '\tCold wisdom waiting on superfluous folly.')
# -------------------------
# '\t[Enter Page]'
# -------------------------
# '\t[Exit]'
# -------------------------
# '\t[Exit]'
# -------------------------
# '\t[Exit]'
# -------------------------
# "\tALL'S WELL THAT ENDS WELL"
# -------------------------
# ('\t[Flourish of cornets. Enter the KING of France,\n'
#  '\twith letters, and divers Attendants]')
# -------------------------
# '\t[Enter BERTRAM, LAFEU, and PAROLLES]'
# -------------------------
# '\t[Exeunt. Flourish]'
# -------------------------
# "\tALL'S WELL THAT ENDS WELL"
# -------------------------
# '\t[Enter COUNTESS, Steward, and Clown]'
# -------------------------
# '\t[Exit]'
# -------------------------
# '\t[Exit Steward]'
# -------------------------
# '\t[Enter HELENA]'
# -------------------------
# ('\tEven so it was with me when I was young:\n'
#  "\tIf ever we are nature's, these are ours; this thorn\n"
#  '\tDoth to our rose of youth rightly belong;\n'
#  '\tOur blood to us, this to our blood is born;\n'
#  "\tIt is the show and seal of nature's truth,\n"
#  "\tWhere love's strong passion is impress'd in youth:\n"
#  '\tBy our remembrances of days foregone,\n'
#  '\tSuch were our faults, or then we thought them none.\n'
#  "\tHer eye is sick on't: I observe her now.")
# -------------------------
# '\t[Exeunt]'
# -------------------------
# "\tALL'S WELL THAT ENDS WELL"
# -------------------------
# ('\t[Flourish of cornets. Enter the KING, attended\n'
#  '\twith divers young Lords taking leave for the\n'
#  '\tFlorentine war; BERTRAM, and PAROLLES]')
# -------------------------
# '\t[Exit, attended]'
# -------------------------
# '\t[Exeunt Lords]'
# -------------------------
# '\t[Re-enter KING. BERTRAM and PAROLLES retire]'
# -------------------------
# '\t[Exeunt BERTRAM and PAROLLES]'
# -------------------------
# '\t[Enter LAFEU]'
# -------------------------
# '\t[Exit]'
# -------------------------
# '\t[Re-enter LAFEU, with HELENA]'
# -------------------------
# '\t[Exit]'
# -------------------------
# '\t[Flourish. Exeunt]'
# -------------------------
# "\tALL'S WELL THAT ENDS WELL"
# -------------------------
# '\t[Enter COUNTESS and Clown]'
# -------------------------
# '\t[Exeunt severally]'
# -------------------------
# "\tALL'S WELL THAT ENDS WELL"
# -------------------------
# '\t[Enter BERTRAM, LAFEU, and PAROLLES]'
# -------------------------
# '\t[pausing]'
# -------------------------
# ('\tand debile minister, great power, great\n'
#  '\ttranscendence: which should, indeed, give us a\n'
#  '\tfurther use to be made than alone the recovery of\n'
#  '\tthe king, as to be--')
# -------------------------
# '\t[pausing]'
# -------------------------
# '\tgenerally thankful.'
# -------------------------
# '\t[Enter KING, HELENA, and Attendants. LAFEU and\n\tPAROLLES retire]'
# -------------------------
# '\t[Enter three or four Lords]'
# -------------------------
# ('\tFair maid, send forth thine eye: this youthful parcel\n'
#  '\tOf noble bachelors stand at my bestowing,\n'
#  "\tO'er whom both sovereign power and father's voice\n"
#  '\tI have to use: thy frank election make;\n'
#  '\tThou hast power to choose, and they none to forsake.')
# -------------------------
# '\t[Exeunt all but LAFEU and PAROLLES]'
# -------------------------
# '\t[Exit]'
# -------------------------
# '\t[Re-enter LAFEU]'
# -------------------------
# '\t[Exit]'
# -------------------------
# '\t[Re-enter BERTRAM]'
# -------------------------
# '\t[Exeunt]'
# -------------------------
# "\tALL'S WELL THAT ENDS WELL"
# -------------------------
# '\t[Enter HELENA and Clown]'
# -------------------------
# '\t[Enter PAROLLES]'
# -------------------------
# '\t[Exit PAROLLES]'
# -------------------------
# '\tCome, sirrah.'
# -------------------------
# '\t[Exeunt]'
# -------------------------
# "\tALL'S WELL THAT ENDS WELL"
# -------------------------
# '\t[Enter LAFEU and BERTRAM]'
# -------------------------
# '\t[Enter PAROLLES]'
# -------------------------
# '\t[Exit]'
# -------------------------
# '\t[Enter HELENA]'
# -------------------------
# '\t[Giving a letter]'
# -------------------------
# "\t'Twill be two days ere I shall see you, so\n\tI leave you to your wisdom."
# -------------------------
# '\t[Exit HELENA]'
# -------------------------
# ('\tGo thou toward home; where I will never come\n'
#  '\tWhilst I can shake my sword or hear the drum.\n'
#  '\tAway, and for our flight.')
# -------------------------
# '\t[Exeunt]'
# -------------------------
# "\tALL'S WELL THAT ENDS WELL"
# -------------------------
# ('\t[Flourish. Enter the DUKE of Florence attended;\n'
#  '\tthe two Frenchmen, with a troop of soldiers.')
# -------------------------
# '\t[Flourish. Exeunt]'
# -------------------------
# "\tALL'S WELL THAT ENDS WELL"
# -------------------------
# '\t[Enter COUNTESS and Clown]'
# -------------------------
# '\t[Opening a letter]'
# -------------------------
# '\t[Exit]'
# -------------------------
# '\t[Re-enter Clown]'
# -------------------------
# '\t[Exit]'
# -------------------------
# '\t[Enter HELENA, and two Gentlemen]'
# -------------------------
# '\t[Reads]'
# -------------------------
# ('\tWhen thou canst get the ring upon my finger which\n'
#  '\tnever shall come off, and show me a child begotten\n'
#  '\tof thy body that I am father to, then call me\n'
#  "\thusband: but in such a 'then' I write a 'never.'\n"
#  '\tThis is a dreadful sentence.')
# -------------------------
# '\t[Exeunt COUNTESS and Gentlemen]'
# -------------------------
# '\t[Exit]'
# -------------------------
# "\tALL'S WELL THAT ENDS WELL"
# -------------------------
# ('\t[Flourish. Enter the DUKE of Florence, BERTRAM,\n'
#  '\tPAROLLES, Soldiers, Drum, and Trumpets]')
# -------------------------
# '\t[Exeunt]'
# -------------------------
# "\tALL'S WELL THAT ENDS WELL"
# -------------------------
# '\t[Enter COUNTESS and Steward]'
# -------------------------
# ("\tI am Saint Jaques' pilgrim, thither gone:\n"
#  '\tAmbitious love hath so in me offended,\n'
#  '\tThat barefoot plod I the cold ground upon,\n'
#  '\tWith sainted vow my faults to have amended.\n'
#  '\tWrite, write, that from the bloody course of war\n'
#  '\tMy dearest master, your dear son, may hie:\n'
#  '\tBless him at home in peace, whilst I from far\n'
#  '\tHis name with zealous fervor sanctify:\n'
#  '\tHis taken labours bid him me forgive;\n'
#  '\tI, his despiteful Juno, sent him forth\n'
#  '\tFrom courtly friends, with camping foes to live,\n'
#  '\tWhere death and danger dogs the heels of worth:\n'
#  '\tHe is too good and fair for death and me:\n'
#  '\tWhom I myself embrace, to set him free.')
# -------------------------
# '\t[Exeunt]'
# -------------------------
# "\tALL'S WELL THAT ENDS WELL"
# -------------------------
# ('\t[Enter an old Widow of Florence, DIANA, VIOLENTA,\n'
#  '\tand MARIANA, with other Citizens]')
# -------------------------
# '\t[Tucket]'
# -------------------------
# ('\tWe have lost our labour; they are gone a contrary\n'
#  '\tway: hark! you may know by their trumpets.')
# -------------------------
# '\t[Enter HELENA, disguised like a Pilgrim]'
# -------------------------
# ('\tLook, here comes a pilgrim: I know she will lie at\n'
#  "\tmy house; thither they send one another: I'll\n"
#  '\tquestion her. God save you, pilgrim! whither are you bound?')
# -------------------------
# '\t[A march afar]'
# -------------------------
# ('\tHark you! they come this way.\n'
#  '\tIf you will tarry, holy pilgrim,\n'
#  '\tBut till the troops come by,\n'
#  '\tI will conduct you where you shall be lodged;\n'
#  '\tThe rather, for I think I know your hostess\n'
#  '\tAs ample as myself.')
# -------------------------
# '\t[Drum and Colours]'
# -------------------------
# '\t[Enter BERTRAM, PAROLLES, and the whole army]'
# -------------------------
# "\tThat is Antonio, the duke's eldest son;\n\tThat, Escalus."
# -------------------------
# '\t[Exeunt BERTRAM, PAROLLES, and army]'
# -------------------------
# '\t[Exeunt]'
# -------------------------
# "\tALL'S WELL THAT ENDS WELL"
# -------------------------
# '\t[Enter BERTRAM and the two French Lords]'
# -------------------------
# '\t[Enter PAROLLES]'
# -------------------------
# '\t[Exit]'
# -------------------------
# '\t[Exit]'
# -------------------------
# '\t[Exeunt]'
# -------------------------
# "\tALL'S WELL THAT ENDS WELL"
# -------------------------
# '\t[Enter HELENA and Widow]'
# -------------------------
# '\t[Exeunt]'
# -------------------------
# "\tALL'S WELL THAT ENDS WELL"
# -------------------------
# '\t[Enter Second French Lord, with five or six other\n\tSoldiers in ambush]'
# -------------------------
# '\t[Enter PAROLLES]'
# -------------------------
# '\t[Alarum within]'
# -------------------------
# '\t[They seize and blindfold him]'
# -------------------------
# '\t[Exit, with PAROLLES guarded. A short alarum within]'
# -------------------------
# '\t[Exeunt]'
# -------------------------
# "\tALL'S WELL THAT ENDS WELL"
# -------------------------
# '\t[Enter BERTRAM and DIANA]'
# -------------------------
# '\t[Exit]'
# -------------------------
# '\t[Exit]'
# -------------------------
# "\tALL'S WELL THAT ENDS WELL"
# -------------------------
# '\t[Enter the two French Lords and some two or three Soldiers]'
# -------------------------
# '\t[Enter a Messenger]'
# -------------------------
# "\tHow now! where's your master?"
# -------------------------
# '\t[Enter BERTRAM]'
# -------------------------
# "\tHow now, my lord! is't not after midnight?"
# -------------------------
# '\t[Enter PAROLLES guarded, and First Soldier]'
# -------------------------
# '\t[Reads]'
# -------------------------
# ("\t'You shall demand of him, whether one Captain Dumain\n"
#  "\tbe i' the camp, a Frenchman; what his reputation is\n"
#  '\twith the duke; what his valour, honesty, and\n'
#  '\texpertness in wars; or whether he thinks it were not\n'
#  '\tpossible, with well-weighing sums of gold, to\n'
#  "\tcorrupt him to revolt.' What say you to this? what\n"
#  '\tdo you know of it?')
# -------------------------
# '\t[Unblinding him]'
# -------------------------
# '\tSo, look about you: know you any here?'
# -------------------------
# '\t[Exeunt BERTRAM and Lords]'
# -------------------------
# '\t[Exit with Soldiers]'
# -------------------------
# '\t[Exit]'
# -------------------------
# "\tALL'S WELL THAT ENDS WELL"
# -------------------------
# '\t[Enter HELENA, Widow, and DIANA]'
# -------------------------
# '\t[Exeunt]'
# -------------------------
# "\tALL'S WELL THAT ENDS WELL"
# -------------------------
# '\t[Enter COUNTESS, LAFEU, and Clown]'
# -------------------------
# '\t[Exit]'
# -------------------------
# '\t[Re-enter Clown]'
# -------------------------
# '\t[Exeunt]'
# -------------------------
# "\tALL'S WELL THAT ENDS WELL"
# -------------------------
# '\t[Enter HELENA, Widow, and DIANA, with two\n\tAttendants]'
# -------------------------
# '\t[Enter a Gentleman]'
# -------------------------
# ("\tThis man may help me to his majesty's ear,\n"
#  '\tIf he would spend his power. God save you, sir.')
# -------------------------
# '\t[Exeunt]'
# -------------------------
# "\tALL'S WELL THAT ENDS WELL"
# -------------------------
# '\t[Enter Clown, and PAROLLES, following]'
# -------------------------
# '\t[Enter LAFEU]'
# -------------------------
# ("\tHere is a purr of fortune's, sir, or of fortune's\n"
#  '\tcat,--but not a musk-cat,--that has fallen into the\n'
#  '\tunclean fishpond of her displeasure, and, as he\n'
#  '\tsays, is muddied withal: pray you, sir, use the\n'
#  '\tcarp as you may; for he looks like a poor, decayed,\n'
#  '\tingenious, foolish, rascally knave. I do pity his\n'
#  '\tdistress in my similes of comfort and leave him to\n'
#  '\tyour lordship.')
# -------------------------
# '\t[Exit]'
# -------------------------
# '\t[Trumpets sound]'
# -------------------------
# ("\tThe king's coming; I know by his trumpets. Sirrah,\n"
#  '\tinquire further after me; I had talk of you last\n'
#  '\tnight: though you are a fool and a knave, you shall\n'
#  '\teat; go to, follow.')
# -------------------------
# '\t[Exeunt]'
# -------------------------
# "\tALL'S WELL THAT ENDS WELL"
# -------------------------
# ('\t[Flourish. Enter KING, COUNTESS, LAFEU, the two\n'
#  '\tFrench Lords, with Attendants]')
# -------------------------
# '\t[Exit]'
# -------------------------
# '\t[Enter BERTRAM]'
# -------------------------
# '\t[BERTRAM gives a ring]'
# -------------------------
# ('\t\t     By my old beard,\n'
#  "\tAnd every hair that's on't, Helen, that's dead,\n"
#  '\tWas a sweet creature: such a ring as this,\n'
#  "\tThe last that e'er I took her at court,\n"
#  '\tI saw upon her finger.')
# -------------------------
# '\t[Guards seize BERTRAM]'
# -------------------------
# ("\tMy fore-past proofs, howe'er the matter fall,\n"
#  '\tShall tax my fears of little vanity,\n'
#  "\tHaving vainly fear'd too little. Away with him!\n"
#  "\tWe'll sift this matter further.")
# -------------------------
# '\t[Exit, guarded]'
# -------------------------
# '\t[Enter a Gentleman]'
# -------------------------
# '\t[Re-enter BERTRAM, guarded]'
# -------------------------
# '\t[Enter Widow and DIANA]'
# -------------------------
# "\t\t   What woman's that?"
# -------------------------
# '\t[Exit an Attendant]'
# -------------------------
# '\t[Enter PAROLLES]'
# -------------------------
# '\t[Exit Widow]'
# -------------------------
# ('\tThe jeweller that owes the ring is sent for,\n'
#  '\tAnd he shall surety me. But for this lord,\n'
#  '\tWho hath abused me, as he knows himself,\n'
#  "\tThough yet he never harm'd me, here I quit him:\n"
#  '\tHe knows himself my bed he hath defiled;\n'
#  '\tAnd at that time he got his wife with child:\n'
#  '\tDead though she be, she feels her young one kick:\n'
#  "\tSo there's my riddle: one that's dead is quick:\n"
#  '\tAnd now behold the meaning.')
# -------------------------
# '\t[Re-enter Widow, with HELENA]'
# -------------------------
# '\t[To PAROLLES]'
# -------------------------
# ('\tGood Tom Drum, lend me a handkercher: so,\n'
#  "\tI thank thee: wait on me home, I'll make sport with thee:\n"
#  '\tLet thy courtesies alone, they are scurvy ones.')
# -------------------------
# '\t[To DIANA]'
# -------------------------
# ("\tIf thou be'st yet a fresh uncropped flower,\n"
#  "\tChoose thou thy husband, and I'll pay thy dower;\n"
#  '\tFor I can guess that by thy honest aid\n'
#  "\tThou keep'st a wife herself, thyself a maid.\n"
#  '\tOf that and all the progress, more or less,\n'
#  '\tResolvedly more leisure shall express:\n'
#  '\tAll yet seems well; and if it end so meet,\n'
#  '\tThe bitter past, more welcome is the sweet.')
# -------------------------
# '\t[Flourish]'
# -------------------------
# "\tALL'S WELL THAT ENDS WELL"
# -------------------------
# '\tEPILOGUE'
# -------------------------
# '\t[Exeunt]\n'
# -------------------------
# ====================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================

# %%
def remove_text_with_square_brackets(play_lines):
    filtered_lines = []
    for line in play_lines:    
        if '[' in line and ']' in line:
            left_bracket_pos = line.find("[")
            right_bracket_pos = line.find("]")
            
            cleaned_line = line[:left_bracket_pos] + line[right_bracket_pos+1:]
            
            # Optionally print the 'before' and 'after' strings 
            # to test the correctnes of logic
            # print(line, "=>", cleaned_line)

            if cleaned_line.strip():
                filtered_lines.append(cleaned_line)
                
        else:
            filtered_lines.append(line)
                
    return filtered_lines

# %%
lines_without_square_bracket_text = [
    remove_text_with_square_brackets(play_lines)
    for play_lines in lines_without_act_and_scene_lines
]

# %% [markdown]
# ### Print the lines again after removing all text contained between square brackets

# %%
for play_idx, play_lines in enumerate(lines_without_square_bracket_text):
    print(play_idx)
    for line in play_lines:
        if not line[0].isalpha():
            pprint(line)
            print("-"*25)
    print("="*500)
# Out:
# 0
# ('\t\t  Look, where they come:\n'
#  '\tTake but good note, and you shall see in him.\n'
#  "\tThe triple pillar of the world transform'd\n"
#  "\tInto a strumpet's fool: behold and see.")
# -------------------------
# ("\tAnd such a twain can do't, in which I bind,\n"
#  '\tOn pain of punishment, the world to weet\n'
#  '\tWe stand up peerless.')
# -------------------------
# '\tANTONY AND CLEOPATRA'
# -------------------------
# '\t\t    What are you?'
# -------------------------
# ("\tThere's a great spirit gone! Thus did I desire it:\n"
#  '\tWhat our contempt doth often hurl from us,\n'
#  '\tWe wish it ours again; the present pleasure,\n'
#  '\tBy revolution lowering, does become\n'
#  "\tThe opposite of itself: she's good, being gone;\n"
#  '\tThe hand could pluck her back that shoved her on.\n'
#  '\tI must from this enchanting queen break off:\n'
#  '\tTen thousand harms, more than the ills I know,\n'
#  '\tMy idleness doth hatch. How now! Enobarbus!')
# -------------------------
# '\tANTONY AND CLEOPATRA'
# -------------------------
# '\tANTONY AND CLEOPATRA'
# -------------------------
# '\tANTONY AND CLEOPATRA'
# -------------------------
# '\tANTONY AND CLEOPATRA'
# -------------------------
# '\t\t       How now, Varrius!'
# -------------------------
# '\tANTONY AND CLEOPATRA'
# -------------------------
# '\tANTONY AND CLEOPATRA'
# -------------------------
# ('\tHe shall to Parthia. Be it art or hap,\n'
#  '\tHe hath spoken true: the very dice obey him;\n'
#  '\tAnd in our sports my better cunning faints\n'
#  '\tUnder his chance: if we draw lots, he speeds;\n'
#  '\tHis cocks do win the battle still of mine,\n'
#  '\tWhen it is all to nought; and his quails ever\n'
#  "\tBeat mine, inhoop'd, at odds. I will to Egypt:\n"
#  '\tAnd though I make this marriage for my peace,\n'
#  "\tI' the east my pleasure lies.")
# -------------------------
# ('\t\t        O, come, Ventidius,\n'
#  "\tYou must to Parthia: your commission's ready;\n"
#  "\tFollow me, and receive't.")
# -------------------------
# '\tANTONY AND CLEOPATRA'
# -------------------------
# '\tANTONY AND CLEOPATRA'
# -------------------------
# ('\t\t      O, from Italy\n'
#  '\tRam thou thy fruitful tidings in mine ears,\n'
#  '\tThat long time have been barren.')
# -------------------------
# ("\tHorrible villain! or I'll spurn thine eyes\n"
#  "\tLike balls before me; I'll unhair thy head:")
# -------------------------
# ("\tThou shalt be whipp'd with wire, and stew'd in brine,\n"
#  '\tSmarting in lingering pickle.')
# -------------------------
# ('\tThese hands do lack nobility, that they strike\n'
#  '\tA meaner than myself; since I myself\n'
#  '\tHave given myself the cause.')
# -------------------------
# ('\t\t       Come hither, sir.\n'
#  '\tThough it be honest, it is never good\n'
#  '\tTo bring bad news: give to a gracious message.\n'
#  '\tAn host of tongues; but let ill tidings tell\n'
#  '\tThemselves when they be felt.')
# -------------------------
# ('\tLet him for ever go:--let him not--Charmian,\n'
#  '\tThough he be painted one way like a Gorgon,\n'
#  "\tThe other way's a Mars. Bid you Alexas")
# -------------------------
# ('\tBring me word how tall she is. Pity me, Charmian,\n'
#  '\tBut do not speak to me. Lead me to my chamber.')
# -------------------------
# '\tANTONY AND CLEOPATRA'
# -------------------------
# '\tANTONY AND CLEOPATRA'
# -------------------------
# '\tShall we dance now the Egyptian Bacchanals,\n\tAnd celebrate our drink?'
# -------------------------
# '\t\n\tTHE SONG.'
# -------------------------
# ('\tCome, thou monarch of the vine,\n'
#  '\tPlumpy Bacchus with pink eyne!\n'
#  "\tIn thy fats our cares be drown'd,\n"
#  "\tWith thy grapes our hairs be crown'd:\n"
#  '\tCup us, till the world go round,\n'
#  '\tCup us, till the world go round!')
# -------------------------
# "\tMenas, I'll not on shore."
# -------------------------
# '\tANTONY AND CLEOPATRA'
# -------------------------
# '\tANTONY AND CLEOPATRA'
# -------------------------
# '\t\n\t\t\tSo;\n\tThis is to horse. Adieu, noble Agrippa.'
# -------------------------
# '\tANTONY AND CLEOPATRA'
# -------------------------
# '\tCome hither, sir.'
# -------------------------
# '\tANTONY AND CLEOPATRA'
# -------------------------
# '\tANTONY AND CLEOPATRA'
# -------------------------
# '\tANTONY AND CLEOPATRA'
# -------------------------
# '\tANTONY AND CLEOPATRA'
# -------------------------
# '\t\t    Thy business?'
# -------------------------
# '\tHow now, worthy soldier?'
# -------------------------
# '\tANTONY AND CLEOPATRA'
# -------------------------
# '\tANTONY AND CLEOPATRA'
# -------------------------
# '\tANTONY AND CLEOPATRA'
# -------------------------
# '\tANTONY AND CLEOPATRA'
# -------------------------
# '\tANTONY AND CLEOPATRA'
# -------------------------
# ("\t  To try eloquence, now 'tis time: dispatch;\n"
#  '\tFrom Antony win Cleopatra: promise,\n'
#  '\tAnd in our name, what she requires; add more,\n'
#  '\tFrom thine invention, offers: women are not\n'
#  '\tIn their best fortunes strong; but want will perjure\n'
#  "\tThe ne'er touch'd vestal: try thy cunning, Thyreus;\n"
#  '\tMake thine own edict for thy pains, which we\n'
#  '\tWill answer as a law.')
# -------------------------
# '\tANTONY AND CLEOPATRA'
# -------------------------
# '\tTake hence this Jack, and whip him.'
# -------------------------
# ('\tYou were half blasted ere I knew you: ha!\n'
#  "\tHave I my pillow left unpress'd in Rome,\n"
#  '\tForborne the getting of a lawful race,\n'
#  '\tAnd by a gem of women, to be abused\n'
#  '\tBy one that looks on feeders?')
# -------------------------
# "\t\t    Is he whipp'd?"
# -------------------------
# '\tANTONY AND CLEOPATRA'
# -------------------------
# '\tANTONY AND CLEOPATRA'
# -------------------------
# ('\t\t    Give me thy hand,\n'
#  '\tThou hast been rightly honest;--so hast thou;--\n'
#  '\tThou,--and thou,--and thou:--you have served me well,\n'
#  '\tAnd kings have been your fellows.')
# -------------------------
# '\tANTONY AND CLEOPATRA'
# -------------------------
# '\tANTONY AND CLEOPATRA'
# -------------------------
# ('\tCome good fellow, put mine iron on:\n'
#  '\tIf fortune be not ours to-day, it is\n'
#  '\tBecause we brave her: come.')
# -------------------------
# ('\tGood morrow to thee; welcome:\n'
#  "\tThou look'st like him that knows a warlike charge:\n"
#  '\tTo business that we love we rise betime,\n'
#  "\tAnd go to't with delight.")
# -------------------------
# ('\tAnd worthy shameful cheque it were, to stand\n'
#  "\tOn more mechanic compliment; I'll leave thee\n"
#  '\tNow, like a man of steel. You that will fight,\n'
#  "\tFollow me close; I'll bring you to't. Adieu.")
# -------------------------
# '\tANTONY AND CLEOPATRA'
# -------------------------
# '\tANTONY AND CLEOPATRA'
# -------------------------
# '\tANTONY AND CLEOPATRA'
# -------------------------
# '\tANTONY AND CLEOPATRA'
# -------------------------
# '\t\t    Give me thy hand'
# -------------------------
# "\tTo this great fairy I'll commend thy acts,\n\tMake her thanks bless thee."
# -------------------------
# ("\t\t      O thou day o' the world,\n"
#  "\tChain mine arm'd neck; leap thou, attire and all,\n"
#  '\tThrough proof of harness to my heart, and there\n'
#  '\tRide on the pants triumphing!')
# -------------------------
# '\tANTONY AND CLEOPATRA'
# -------------------------
# ('\t\t                  Hark! the drums\n'
#  '\tDemurely wake the sleepers. Let us bear him\n'
#  '\tTo the court of guard; he is of note: our hour\n'
#  '\tIs fully out.')
# -------------------------
# '\tANTONY AND CLEOPATRA'
# -------------------------
# '\tANTONY AND CLEOPATRA'
# -------------------------
# '\tANTONY AND CLEOPATRA'
# -------------------------
# ('\tO sun, thy uprise shall I see no more:\n'
#  '\tFortune and Antony part here; even here\n'
#  '\tDo we shake hands. All come to this? The hearts\n'
#  "\tThat spaniel'd me at heels, to whom I gave\n"
#  '\tTheir wishes, do discandy, melt their sweets\n'
#  "\tOn blossoming Caesar; and this pine is bark'd,\n"
#  "\tThat overtopp'd them all. Betray'd I am:\n"
#  '\tO this false soul of Egypt! this grave charm,--\n'
#  "\tWhose eye beck'd forth my wars, and call'd them home;\n"
#  '\tWhose bosom was my crownet, my chief end,--\n'
#  '\tLike a right gipsy, hath, at fast and loose,\n'
#  '\tBeguiled me to the very heart of loss.\n'
#  '\tWhat, Eros, Eros!')
# -------------------------
# '\tAh, thou spell! Avaunt!'
# -------------------------
# ("\t\t'Tis well thou'rt gone,\n"
#  "\tIf it be well to live; but better 'twere\n"
#  "\tThou fell'st into my fury, for one death\n"
#  '\tMight have prevented many. Eros, ho!\n'
#  '\tThe shirt of Nessus is upon me: teach me,\n'
#  '\tAlcides, thou mine ancestor, thy rage:\n'
#  "\tLet me lodge Lichas on the horns o' the moon;\n"
#  "\tAnd with those hands, that grasp'd the heaviest club,\n"
#  '\tSubdue my worthiest self. The witch shall die:\n'
#  '\tTo the young Roman boy she hath sold me, and I fall\n'
#  "\tUnder this plot; she dies for't. Eros, ho!")
# -------------------------
# '\tANTONY AND CLEOPATRA'
# -------------------------
# '\tANTONY AND CLEOPATRA'
# -------------------------
# "\t\t      O! thy vile lady!\n\tShe has robb'd me of my sword."
# -------------------------
# "\tThat thou depart'st hence safe,\n\tDoes pay thy labour richly; go."
# -------------------------
# ('\t\t         Off, pluck off:\n'
#  '\tThe seven-fold shield of Ajax cannot keep\n'
#  '\tThe battery from my heart. O, cleave, my sides!\n'
#  '\tHeart, once be stronger than thy continent,\n'
#  '\tCrack thy frail case! Apace, Eros, apace.\n'
#  '\tNo more a soldier: bruised pieces, go;\n'
#  '\tYou have been nobly borne. From me awhile.')
# -------------------------
# ("\tI will o'ertake thee, Cleopatra, and\n"
#  '\tWeep for my pardon. So it must be, for now\n'
#  '\tAll length is torture: since the torch is out,\n'
#  '\tLie down, and stray no farther: now all labour\n'
#  '\tMars what it does; yea, very force entangles\n'
#  '\tItself with strength: seal then, and all is done.\n'
#  '\tEros!--I come, my queen:--Eros!--Stay for me:\n'
#  "\tWhere souls do couch on flowers, we'll hand in hand,\n"
#  '\tAnd with our sprightly port make the ghosts gaze:\n'
#  '\tDido and her AEneas shall want troops,\n'
#  '\tAnd all the haunt be ours. Come, Eros, Eros!')
# -------------------------
# ("\tI learn'd of thee. How! not dead? not dead?\n"
#  '\tThe guard, ho! O, dispatch me!')
# -------------------------
# '\tANTONY AND CLEOPATRA'
# -------------------------
# '\t\t  How now! is he dead?'
# -------------------------
# ('\tAnd welcome, welcome! die where thou hast lived:\n'
#  '\tQuicken with kissing: had my lips that power,\n'
#  '\tThus would I wear them out.')
# -------------------------
# ("\tThe crown o' the earth doth melt. My lord!\n"
#  "\tO, wither'd is the garland of the war,\n"
#  "\tThe soldier's pole is fall'n: young boys and girls\n"
#  '\tAre level now with men; the odds is gone,\n'
#  '\tAnd there is nothing left remarkable\n'
#  '\tBeneath the visiting moon.')
# -------------------------
# '\tANTONY AND CLEOPATRA'
# -------------------------
# ('\tThe business of this man looks out of him;\n'
#  "\tWe'll hear him what he says. Whence are you?")
# -------------------------
# "\t\tWhere's Dolabella,\n\tTo second Proculeius?"
# -------------------------
# '\tANTONY AND CLEOPATRA'
# -------------------------
# '\tGuard her till Caesar come.'
# -------------------------
# "\tDo not yourself such wrong, who are in this\n\tRelieved, but not betray'd."
# -------------------------
# "\tTo Caesar I will speak what you shall please,\n\tIf you'll employ me to him."
# -------------------------
# ('\t\t   Prithee, go hence;\n'
#  '\tOr I shall show the cinders of my spirits\n'
#  '\tThrough the ashes of my chance: wert thou a man,\n'
#  '\tThou wouldst have mercy on me.')
# -------------------------
# ("\t\tNow, Iras, what think'st thou?\n"
#  '\tThou, an Egyptian puppet, shalt be shown\n'
#  '\tIn Rome, as well as I\tmechanic slaves\n'
#  '\tWith greasy aprons, rules, and hammers, shall\n'
#  '\tUplift us to the view; in their thick breaths,\n'
#  '\tRank of gross diet, shall be enclouded,\n'
#  '\tAnd forced to drink their vapour.')
# -------------------------
# ('\t\t     Now, Charmian!\n'
#  '\tShow me, my women, like a queen: go fetch\n'
#  '\tMy best attires: I am again for Cydnus,\n'
#  '\tTo meet Mark Antony: sirrah Iras, go.\n'
#  "\tNow, noble Charmian, we'll dispatch indeed;\n"
#  "\tAnd, when thou hast done this chare, I'll give thee leave\n"
#  '\tTo play till doomsday. Bring our crown and all.\n'
#  "\tWherefore's this noise?")
# -------------------------
# ('\tWhat poor an instrument\n'
#  '\tMay do a noble deed! he brings me liberty.\n'
#  "\tMy resolution's placed, and I have nothing\n"
#  '\tOf woman in me: now from head to foot\n'
#  '\tI am marble-constant; now the fleeting moon\n'
#  '\tNo planet is of mine.')
# -------------------------
# '\tHast thou the pretty worm of Nilus there,\n\tThat kills and pains not?'
# -------------------------
# ('\tHave I the aspic in my lips? Dost fall?\n'
#  '\tIf thou and nature can so gently part,\n'
#  "\tThe stroke of death is as a lover's pinch,\n"
#  '\tWhich hurts, and is desired. Dost thou lie still?\n'
#  "\tIf thus thou vanishest, thou tell'st the world\n"
#  '\tIt is not worth leave-taking.')
# -------------------------
# ('\tWith thy sharp teeth this knot intrinsicate\n'
#  '\tOf life at once untie: poor venomous fool\n'
#  '\tBe angry, and dispatch. O, couldst thou speak,\n'
#  '\tThat I might hear thee call great Caesar ass\n'
#  '\tUnpolicied!')
# -------------------------
# '\tWhat should I stay--'
# -------------------------
# '\tO, come apace, dispatch! I partly feel thee.'
# -------------------------
# ====================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================
# 1
# '\tTHE COMEDY OF ERRORS'
# -------------------------
# ('\tHere comes the almanac of my true date.\n'
#  "\tWhat now? how chance thou art return'd so soon?")
# -------------------------
# '\tTHE COMEDY OF ERRORS'
# -------------------------
# '\tTHE COMEDY OF ERRORS'
# -------------------------
# ("\tHow now sir! is your merry humour alter'd?\n"
#  '\tAs you love strokes, so jest with me again.\n'
#  '\tYou know no Centaur? you received no gold?\n'
#  '\tYour mistress sent to have me home to dinner?\n'
#  '\tMy house was at the Phoenix? Wast thou mad,\n'
#  '\tThat thus so madly thou didst answer me?')
# -------------------------
# '\tTHE COMEDY OF ERRORS'
# -------------------------
# ('\t\t    Get you home\n'
#  "\tAnd fetch the chain; by this I know 'tis made:\n"
#  '\tBring it, I pray you, to the Porpentine;\n'
#  "\tFor there's the house: that chain will I bestow--\n"
#  '\tBe it for nothing but to spite my wife--\n'
#  '\tUpon mine hostess there: good sir, make haste.\n'
#  '\tSince mine own doors refuse to entertain me,\n'
#  "\tI'll knock elsewhere, to see if they'll disdain me.")
# -------------------------
# '\tTHE COMEDY OF ERRORS'
# -------------------------
# '\tTHE COMEDY OF ERRORS'
# -------------------------
# '\tTHE COMEDY OF ERRORS'
# -------------------------
# ('\t\tThis I wonder at,\n'
#  '\tThat he, unknown to me, should be in debt.\n'
#  '\tTell me, was he arrested on a band?')
# -------------------------
# '\tTHE COMEDY OF ERRORS'
# -------------------------
# '\tTHE COMEDY OF ERRORS'
# -------------------------
# ('\tHere comes my man; I think he brings the money.\n'
#  '\tHow now, sir! have you that I sent you for?')
# -------------------------
# '\tSay now, whose suit is he arrested at?'
# -------------------------
# '\tTHE COMEDY OF ERRORS'
# -------------------------
# '\tHark, hark! I hear him, mistress. fly, be gone!'
# -------------------------
# ('\t\tWhat I told you then,\n'
#  '\tI hope I shall have leisure to make good;\n'
#  '\tIf this be not a dream I see and hear.')
# -------------------------
# ====================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================
# 2
# "\t'Twill be a good way; and to-morrow the wrestling is."
# -------------------------
# ('\tNow will I stir this gamester: I hope I shall see\n'
#  '\tan end of him; for my soul, yet I know not why,\n'
#  "\thates nothing more than he. Yet he's gentle, never\n"
#  '\tschooled and yet learned, full of noble device, of\n'
#  '\tall sorts enchantingly beloved, and indeed so much\n'
#  '\tin the heart of the world, and especially of my own\n'
#  '\tpeople, who best know him, that I am altogether\n'
#  '\tmisprised: but it shall not be so long; this\n'
#  '\twrestler shall clear all: nothing remains but that\n'
#  "\tI kindle the boy thither; which now I'll go about.")
# -------------------------
# '\tAS YOU LIKE IT'
# -------------------------
# "\tBon jour, Monsieur Le Beau: what's the news?"
# -------------------------
# ('\tWear this for me, one out of suits with fortune,\n'
#  '\tThat could give more, but that her hand lacks means.\n'
#  '\tShall we go, coz?')
# -------------------------
# ('\tThus must I from the smoke into the smother;\n'
#  '\tFrom tyrant duke unto a tyrant brother:\n'
#  '\tBut heavenly Rosalind!')
# -------------------------
# '\tAS YOU LIKE IT'
# -------------------------
# '\tAS YOU LIKE IT'
# -------------------------
# '\tAS YOU LIKE IT'
# -------------------------
# '\tAS YOU LIKE IT'
# -------------------------
# '\tAS YOU LIKE IT'
# -------------------------
# '\tLook you, who comes here; a young man and an old in\n\tsolemn talk.'
# -------------------------
# '\tAS YOU LIKE IT'
# -------------------------
# ('\t\n'
#  '\t\n'
#  '\tSONG.\n'
#  'AMIENS\tUnder the greenwood tree\n'
#  '\tWho loves to lie with me,\n'
#  '\tAnd turn his merry note\n'
#  "\tUnto the sweet bird's throat,\n"
#  '\tCome hither, come hither, come hither:\n'
#  '\tHere shall he see No enemy\n'
#  '\tBut winter and rough weather.')
# -------------------------
# ("\tAnd loves to live i' the sun,\n"
#  '\tSeeking the food he eats\n'
#  '\tAnd pleased with what he gets,\n'
#  '\tCome hither, come hither, come hither:\n'
#  '\tHere shall he see No enemy\n'
#  '\tBut winter and rough weather.')
# -------------------------
# ('\tIf it do come to pass\n'
#  '\tThat any man turn ass,\n'
#  '\tLeaving his wealth and ease,\n'
#  '\tA stubborn will to please,\n'
#  '\tDucdame, ducdame, ducdame:\n'
#  '\tHere shall he see\n'
#  '\tGross fools as he,\n'
#  '\tAn if he will come to me.')
# -------------------------
# '\tAS YOU LIKE IT'
# -------------------------
# '\tAS YOU LIKE IT'
# -------------------------
# '\tAS YOU LIKE IT'
# -------------------------
# '\tAS YOU LIKE IT'
# -------------------------
# ('\tWhy should this a desert be?\n'
#  '\tFor it is unpeopled? No:\n'
#  "\tTongues I'll hang on every tree,\n"
#  '\tThat shall civil sayings show:\n'
#  '\tSome, how brief the life of man\n'
#  '\tRuns his erring pilgrimage,\n'
#  '\tThat the stretching of a span\n'
#  '\tBuckles in his sum of age;\n'
#  '\tSome, of violated vows\n'
#  "\t'Twixt the souls of friend and friend:\n"
#  '\tBut upon the fairest boughs,\n'
#  '\tOr at every sentence end,\n'
#  '\tWill I Rosalinda write,\n'
#  '\tTeaching all that read to know\n'
#  '\tThe quintessence of every sprite\n'
#  '\tHeaven would in little show.\n'
#  '\tTherefore Heaven Nature charged\n'
#  "\tThat one body should be fill'd\n"
#  '\tWith all graces wide-enlarged:\n'
#  "\tNature presently distill'd\n"
#  "\tHelen's cheek, but not her heart,\n"
#  "\tCleopatra's majesty,\n"
#  "\tAtalanta's better part,\n"
#  "\tSad Lucretia's modesty.\n"
#  '\tThus Rosalind of many parts\n'
#  '\tBy heavenly synod was devised,\n'
#  '\tOf many faces, eyes and hearts,\n'
#  '\tTo have the touches dearest prized.\n'
#  '\tHeaven would that she these gifts should have,\n'
#  '\tAnd I to live and die her slave.')
# -------------------------
# '\tAS YOU LIKE IT'
# -------------------------
# ('\tSir Oliver Martext, you are well met: will you\n'
#  '\tdispatch us here under this tree, or shall we go\n'
#  '\twith you to your chapel?')
# -------------------------
# "\tProceed, proceed\tI'll give her."
# -------------------------
# '\tAS YOU LIKE IT'
# -------------------------
# '\tAS YOU LIKE IT'
# -------------------------
# '\tAS YOU LIKE IT'
# -------------------------
# '\tAS YOU LIKE IT'
# -------------------------
# ('\tTake thou no scorn to wear the horn;\n'
#  '\tIt was a crest ere thou wast born:\n'
#  "\tThy father's father wore it,\n"
#  '\tAnd thy father bore it:\n'
#  '\tThe horn, the horn, the lusty horn\n'
#  '\tIs not a thing to laugh to scorn.')
# -------------------------
# '\tAS YOU LIKE IT'
# -------------------------
# ("\tArt thou god to shepherd turn'd,\n"
#  "\tThat a maiden's heart hath burn'd?\n"
#  '\tCan a woman rail thus?')
# -------------------------
# ('\tWhy, thy godhead laid apart,\n'
#  "\tWarr'st thou with a woman's heart?\n"
#  '\tDid you ever hear such railing?\n'
#  '\tWhiles the eye of man did woo me,\n'
#  '\tThat could do no vengeance to me.\n'
#  '\tMeaning me a beast.\n'
#  '\tIf the scorn of your bright eyne\n'
#  '\tHave power to raise such love in mine,\n'
#  '\tAlack, in me what strange effect\n'
#  '\tWould they work in mild aspect!\n'
#  '\tWhiles you chid me, I did love;\n'
#  '\tHow then might your prayers move!\n'
#  '\tHe that brings this love to thee\n'
#  '\tLittle knows this love in me:\n'
#  '\tAnd by him seal up thy mind;\n'
#  '\tWhether that thy youth and kind\n'
#  '\tWill the faithful offer take\n'
#  '\tOf me and all that I can make;\n'
#  '\tOr else by him my love deny,\n'
#  "\tAnd then I'll study how to die.")
# -------------------------
# '\tAS YOU LIKE IT'
# -------------------------
# '\tAS YOU LIKE IT'
# -------------------------
# '\tLook, here comes a lover of mine and a lover of hers.'
# -------------------------
# '\tI will help you, if I can:'
# -------------------------
# '\tI would love you, if I could. To-morrow meet me all together.'
# -------------------------
# "\tI will marry you, if ever I marry woman, and I'll be\n\tmarried to-morrow:"
# -------------------------
# ('\tI will satisfy you, if ever I satisfied man, and you\n'
#  '\tshall be married to-morrow:')
# -------------------------
# ('\tI will content you, if what pleases you contents\n'
#  '\tyou, and you shall be married to-morrow.')
# -------------------------
# '\tAs you love Rosalind, meet:'
# -------------------------
# ('\tas you love Phebe, meet: and as I love no woman,\n'
#  "\tI'll meet. So fare you well: I have left you commands.")
# -------------------------
# '\tAS YOU LIKE IT'
# -------------------------
# ('\tBetween the acres of the rye,\n'
#  '\tWith a hey, and a ho, and a hey nonino\n'
#  '\tThese pretty country folks would lie,\n'
#  '\tIn spring time, &c.')
# -------------------------
# ('\tThis carol they began that hour,\n'
#  '\tWith a hey, and a ho, and a hey nonino,\n'
#  '\tHow that a life was but a flower\n'
#  '\tIn spring time, &c.')
# -------------------------
# ('\tAnd therefore take the present time,\n'
#  '\tWith a hey, and a ho, and a hey nonino;\n'
#  '\tFor love is crowned with the prime\n'
#  '\tIn spring time, &c.')
# -------------------------
# '\tAS YOU LIKE IT'
# -------------------------
# '\tTo you I give myself, for I am yours.'
# -------------------------
# ('\tYou to your former honour I bequeath;\n'
#  '\tYour patience and your virtue well deserves it:')
# -------------------------
# '\tYou to a love that your true faith doth merit:'
# -------------------------
# '\tYou to your land and love and great allies:'
# -------------------------
# '\tYou to a long and well-deserved bed:'
# -------------------------
# ('\tAnd you to wrangling; for thy loving voyage\n'
#  "\tIs but for two months victuall'd. So, to your pleasures:\n"
#  '\tI am for other than for dancing measures.')
# -------------------------
# '\tAS YOU LIKE IT'
# -------------------------
# '\tEPILOGUE'
# -------------------------
# ====================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================
# 3
# ("\tWhat shouts are these? The other side o' the city\n"
#  '\tis risen: why stay we prating here? to the Capitol!')
# -------------------------
# '\t\t       Hail, noble Marcius!'
# -------------------------
# '\t  Follow Cominius; we must follow you;\n\tRight worthy you priority.'
# -------------------------
# '\tCORIOLANUS'
# -------------------------
# ("\t'They have press'd a power, but it is not known\n"
#  '\tWhether for east or west: the dearth is great;\n'
#  "\tThe people mutinous; and it is rumour'd,\n"
#  '\tCominius, Marcius your old enemy,\n'
#  '\tWho is of Rome worse hated than of you,\n'
#  '\tAnd Titus Lartius, a most valiant Roman,\n'
#  '\tThese three lead on this preparation\n'
#  "\tWhither 'tis bent: most likely 'tis for you:\n"
#  "\tConsider of it.'")
# -------------------------
# '\tCORIOLANUS'
# -------------------------
# '\tCORIOLANUS'
# -------------------------
# '\tTutus Aufidius, is he within your walls?'
# -------------------------
# ('\t\t       Hark! our drums\n'
#  "\tAre bringing forth our youth. We'll break our walls,\n"
#  '\tRather than they shall pound us up: our gates,\n'
#  "\tWhich yet seem shut, we, have but pinn'd with rushes;\n"
#  "\tThey'll open of themselves.")
# -------------------------
# ('\t\t      Hark you. far off!\n'
#  '\tThere is Aufidius; list, what work he makes\n'
#  '\tAmongst your cloven army.')
# -------------------------
# ('\tSo, now the gates are ope: now prove good seconds:\n'
#  "\t'Tis for the followers fortune widens them,\n"
#  '\tNot for the fliers: mark me, and do the like.')
# -------------------------
# '\tCORIOLANUS'
# -------------------------
# ('\tGo, sound thy trumpet in the market-place;\n'
#  "\tCall thither all the officers o' the town,\n"
#  '\tWhere they shall know our mind: away!')
# -------------------------
# '\tCORIOLANUS'
# -------------------------
# '\t\t                  Thy news?'
# -------------------------
# ('\tO, me alone! make you a sword of me?\n'
#  '\tIf these shows be not outward, which of you\n'
#  '\tBut is four Volsces? none of you but is\n'
#  '\tAble to bear against the great Aufidius\n'
#  '\tA shield as hard as his. A certain number,\n'
#  '\tThough thanks to all, must I select\n'
#  '\tfrom all: the rest\n'
#  '\tShall bear the business in some other fight,\n'
#  "\tAs cause will be obey'd. Please you to march;\n"
#  '\tAnd four shall quickly draw out my command,\n'
#  '\tWhich men are best inclined.')
# -------------------------
# '\tCORIOLANUS'
# -------------------------
# '\tCORIOLANUS'
# -------------------------
# '\tOfficious, and not valiant, you have shamed me\n\tIn your condemned seconds.'
# -------------------------
# '\tCORIOLANUS'
# -------------------------
# '\tCORIOLANUS'
# -------------------------
# '\tCORIOLANUS'
# -------------------------
# '\t[Enter MENENIUS with the two Tribunes of the people,\n\tSICINIUS and BRUTUS.'
# -------------------------
# ('\tHow now, my as fair as noble ladies,--and the moon,\n'
#  '\twere she earthly, no nobler,--whither do you follow\n'
#  '\tyour eyes so fast?')
# -------------------------
# ('\tGod save your good worships! Marcius is coming\n'
#  '\thome: he has more cause to be proud. Where is he wounded?')
# -------------------------
# '\tHark! the trumpets.'
# -------------------------
# '\t\n\tO my sweet lady, pardon.'
# -------------------------
# '\tCORIOLANUS'
# -------------------------
# ("\t\t     Masters o' the people,\n"
#  '\tWe do request your kindest ears, and after,\n'
#  '\tYour loving motion toward the common body,\n'
#  '\tTo yield what passes here.')
# -------------------------
# '\t\t  Nay, keep your place.'
# -------------------------
# '\tCORIOLANUS'
# -------------------------
# ('\tHere he comes, and in the gown of humility: mark his\n'
#  '\tbehavior. We are not to stay all together, but to\n'
#  '\tcome by him where he stands, by ones, by twos, and\n'
#  "\tby threes. He's to make his requests by\n"
#  '\tparticulars; wherein every one of us has a single\n'
#  '\thonour, in giving him our own voices with our own\n'
#  '\ttongues: therefore follow me, and I direct you how\n'
#  '\tyou shall go by him.')
# -------------------------
# '\t\t      So, here comes a brace.'
# -------------------------
# '\tYou know the cause, air, of my standing here.'
# -------------------------
# ('\tHere come more voices.\n'
#  '\tYour voices: for your voices I have fought;\n'
#  "\tWatch'd for your voices; for Your voices bear\n"
#  '\tOf wounds two dozen odd; battles thrice six\n'
#  '\tI have seen and heard of; for your voices have\n'
#  '\tDone many things, some less, some more your voices:\n'
#  '\tIndeed I would be consul.')
# -------------------------
# "\tHe has it now, and by his looks methink\n\t'Tis warm at 's heart."
# -------------------------
# '\tCORIOLANUS'
# -------------------------
# ('\tBehold, these are the tribunes of the people,\n'
#  "\tThe tongues o' the common mouth: I do despise them;\n"
#  '\tFor they do prank them in authority,\n'
#  '\tAgainst all noble sufferance.')
# -------------------------
# '\tLet him be apprehended.'
# -------------------------
# ('\t\tin whose name myself\n'
#  '\tAttach thee as a traitorous innovator,\n'
#  '\tA foe to the public weal: obey, I charge thee,\n'
#  '\tAnd follow to thine answer.')
# -------------------------
# ("\t'Tribunes!' 'Patricians!' 'Citizens!' 'What, ho!'\n"
#  "\t'Sicinius!' 'Brutus!' 'Coriolanus!' 'Citizens!'\n"
#  "\t'Peace, peace, peace!' 'Stay, hold, peace!'")
# -------------------------
# ("\tThere's some among you have beheld me fighting:\n"
#  '\tCome, try upon yourselves what you have seen me.')
# -------------------------
# "\t\t      Here's goodly work!"
# -------------------------
# '\tLet me desire your company: he must come,\n\tOr what is worst will follow.'
# -------------------------
# '\tCORIOLANUS'
# -------------------------
# ('\t\t    I talk of you:\n'
#  '\tWhy did you wish me milder? would you have me\n'
#  '\tFalse to my nature? Rather say I play\n'
#  '\tThe man I am.')
# -------------------------
# '\tCORIOLANUS'
# -------------------------
# '\tWhat, will he come?'
# -------------------------
# ('\tPut him to choler straight: he hath been used\n'
#  '\tEver to conquer, and to have his worth\n'
#  '\tOf contradiction: being once chafed, he cannot\n'
#  "\tBe rein'd again to temperance; then he speaks\n"
#  "\tWhat's in his heart; and that is there which looks\n"
#  '\tWith us to break his neck.')
# -------------------------
# '\tCORIOLANUS'
# -------------------------
# '\tCORIOLANUS'
# -------------------------
# '\tHere comes his mother.'
# -------------------------
# '\t\t        Will you be gone?'
# -------------------------
# ('\tI would the gods had nothing else to do\n'
#  "\tBut to confirm my curses! Could I meet 'em\n"
#  '\tBut once a-day, it would unclog my heart\n'
#  "\tOf what lies heavy to't.")
# -------------------------
# '\tCORIOLANUS'
# -------------------------
# '\tCORIOLANUS'
# -------------------------
# '\t\t  Save you, sir.'
# -------------------------
# ('\tO world, thy slippery turns! Friends now fast sworn,\n'
#  '\tWhose double bosoms seem to wear one heart,\n'
#  '\tWhose house, whose bed, whose meal, and exercise,\n'
#  "\tAre still together, who twin, as 'twere, in love\n"
#  '\tUnseparable, shall within this hour,\n'
#  '\tOn a dissension of a doit, break out\n'
#  '\tTo bitterest enmity: so, fellest foes,\n'
#  '\tWhose passions and whose plots have broke their sleep,\n'
#  '\tTo take the one the other, by some chance,\n'
#  '\tSome trick not worth an egg, shall grow dear friends\n'
#  '\tAnd interjoin their issues. So with me:\n'
#  "\tMy birth-place hate I, and my love's upon\n"
#  "\tThis enemy town. I'll enter: if he slay me,\n"
#  '\tHe does fair justice; if he give me way,\n'
#  "\tI'll do his country service.")
# -------------------------
# '\tCORIOLANUS'
# -------------------------
# ('\tNot yet thou knowest me, and, seeing me, dost not\n'
#  '\tThink me for the man I am, necessity\n'
#  '\tCommands me name myself.')
# -------------------------
# '\tCORIOLANUS'
# -------------------------
# '\t\t      Is this Menenius?'
# -------------------------
# '\tCORIOLANUS'
# -------------------------
# '\tCORIOLANUS'
# -------------------------
# '\tCORIOLANUS'
# -------------------------
# ('\tThe glorious gods sit in hourly synod about thy\n'
#  '\tparticular prosperity, and love thee no worse than\n'
#  '\tthy old father Menenius does! O my son, my son!\n'
#  "\tthou art preparing fire for us; look thee, here's\n"
#  '\twater to quench it. I was hardly moved to come to\n'
#  '\tthee; but being assured none but myself could move\n'
#  '\tthee, I have been blown out of your gates with\n'
#  '\tsighs; and conjure thee to pardon Rome, and thy\n'
#  '\tpetitionary countrymen. The good gods assuage thy\n'
#  '\twrath, and turn the dregs of it upon this varlet\n'
#  '\there,--this, who, like a block, hath denied my\n'
#  '\taccess to thee.')
# -------------------------
# ('\tAnd would have rent it. Another word, Menenius,\n'
#  '\tI will not hear thee speak. This man, Aufidius,\n'
#  "\tWas my beloved in Rome: yet thou behold'st!")
# -------------------------
# '\tCORIOLANUS'
# -------------------------
# ('\tShall I be tempted to infringe my vow\n'
#  "\tIn the same time 'tis made? I will not.")
# -------------------------
# ("\tMy wife comes foremost; then the honour'd mould\n"
#  '\tWherein this trunk was framed, and in her hand\n'
#  '\tThe grandchild to her blood. But, out, affection!\n'
#  '\tAll bond and privilege of nature, break!\n'
#  '\tLet it be virtuous to be obstinate.\n'
#  "\tWhat is that curt'sy worth? or those doves' eyes,\n"
#  '\tWhich can make gods forsworn? I melt, and am not\n'
#  '\tOf stronger earth than others. My mother bows;\n'
#  '\tAs if Olympus to a molehill should\n'
#  '\tIn supplication nod: and my young boy\n'
#  '\tHath an aspect of intercession, which\n'
#  "\tGreat nature cries 'Deny not.' let the Volsces\n"
#  "\tPlough Rome and harrow Italy: I'll never\n"
#  '\tBe such a gosling to obey instinct, but stand,\n'
#  '\tAs if a man were author of himself\n'
#  '\tAnd knew no other kin.')
# -------------------------
# '\tOf thy deep duty more impression show\n\tThan that of common sons.'
# -------------------------
# ('\tBut we will drink together; and you shall bear\n'
#  '\tA better witness back than words, which we,\n'
#  "\tOn like conditions, will have counter-seal'd.\n"
#  '\tCome, enter with us. Ladies, you deserve\n'
#  '\tTo have a temple built you: all the swords\n'
#  '\tIn Italy, and her confederate arms,\n'
#  '\tCould not have made this peace.')
# -------------------------
# '\tCORIOLANUS'
# -------------------------
# ('\tThe trumpets, sackbuts, psalteries and fifes,\n'
#  '\tTabours and cymbals and the shouting Romans,\n'
#  '\tMake the sun dance. Hark you!')
# -------------------------
# '\tCORIOLANUS'
# -------------------------
# '\tCORIOLANUS'
# -------------------------
# '\tMost welcome!'
# -------------------------
# ====================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================
# 4
# ('\tOne that goes with him: I love him for his sake;\n'
#  '\tAnd yet I know him a notorious liar,\n'
#  '\tThink him a great way fool, solely a coward;\n'
#  '\tYet these fixed evils sit so fit in him,\n'
#  "\tThat they take place, when virtue's steely bones\n"
#  "\tLook bleak i' the cold wind: withal, full oft we see\n"
#  '\tCold wisdom waiting on superfluous folly.')
# -------------------------
# "\tALL'S WELL THAT ENDS WELL"
# -------------------------
# "\tALL'S WELL THAT ENDS WELL"
# -------------------------
# ('\tEven so it was with me when I was young:\n'
#  "\tIf ever we are nature's, these are ours; this thorn\n"
#  '\tDoth to our rose of youth rightly belong;\n'
#  '\tOur blood to us, this to our blood is born;\n'
#  "\tIt is the show and seal of nature's truth,\n"
#  "\tWhere love's strong passion is impress'd in youth:\n"
#  '\tBy our remembrances of days foregone,\n'
#  '\tSuch were our faults, or then we thought them none.\n'
#  "\tHer eye is sick on't: I observe her now.")
# -------------------------
# "\tALL'S WELL THAT ENDS WELL"
# -------------------------
# "\tALL'S WELL THAT ENDS WELL"
# -------------------------
# "\tALL'S WELL THAT ENDS WELL"
# -------------------------
# ('\tand debile minister, great power, great\n'
#  '\ttranscendence: which should, indeed, give us a\n'
#  '\tfurther use to be made than alone the recovery of\n'
#  '\tthe king, as to be--')
# -------------------------
# '\tgenerally thankful.'
# -------------------------
# ('\tFair maid, send forth thine eye: this youthful parcel\n'
#  '\tOf noble bachelors stand at my bestowing,\n'
#  "\tO'er whom both sovereign power and father's voice\n"
#  '\tI have to use: thy frank election make;\n'
#  '\tThou hast power to choose, and they none to forsake.')
# -------------------------
# "\tALL'S WELL THAT ENDS WELL"
# -------------------------
# '\tCome, sirrah.'
# -------------------------
# "\tALL'S WELL THAT ENDS WELL"
# -------------------------
# "\t'Twill be two days ere I shall see you, so\n\tI leave you to your wisdom."
# -------------------------
# ('\tGo thou toward home; where I will never come\n'
#  '\tWhilst I can shake my sword or hear the drum.\n'
#  '\tAway, and for our flight.')
# -------------------------
# "\tALL'S WELL THAT ENDS WELL"
# -------------------------
# ('\t[Flourish. Enter the DUKE of Florence attended;\n'
#  '\tthe two Frenchmen, with a troop of soldiers.')
# -------------------------
# "\tALL'S WELL THAT ENDS WELL"
# -------------------------
# ('\tWhen thou canst get the ring upon my finger which\n'
#  '\tnever shall come off, and show me a child begotten\n'
#  '\tof thy body that I am father to, then call me\n'
#  "\thusband: but in such a 'then' I write a 'never.'\n"
#  '\tThis is a dreadful sentence.')
# -------------------------
# "\tALL'S WELL THAT ENDS WELL"
# -------------------------
# "\tALL'S WELL THAT ENDS WELL"
# -------------------------
# ("\tI am Saint Jaques' pilgrim, thither gone:\n"
#  '\tAmbitious love hath so in me offended,\n'
#  '\tThat barefoot plod I the cold ground upon,\n'
#  '\tWith sainted vow my faults to have amended.\n'
#  '\tWrite, write, that from the bloody course of war\n'
#  '\tMy dearest master, your dear son, may hie:\n'
#  '\tBless him at home in peace, whilst I from far\n'
#  '\tHis name with zealous fervor sanctify:\n'
#  '\tHis taken labours bid him me forgive;\n'
#  '\tI, his despiteful Juno, sent him forth\n'
#  '\tFrom courtly friends, with camping foes to live,\n'
#  '\tWhere death and danger dogs the heels of worth:\n'
#  '\tHe is too good and fair for death and me:\n'
#  '\tWhom I myself embrace, to set him free.')
# -------------------------
# "\tALL'S WELL THAT ENDS WELL"
# -------------------------
# ('\tWe have lost our labour; they are gone a contrary\n'
#  '\tway: hark! you may know by their trumpets.')
# -------------------------
# ('\tLook, here comes a pilgrim: I know she will lie at\n'
#  "\tmy house; thither they send one another: I'll\n"
#  '\tquestion her. God save you, pilgrim! whither are you bound?')
# -------------------------
# ('\tHark you! they come this way.\n'
#  '\tIf you will tarry, holy pilgrim,\n'
#  '\tBut till the troops come by,\n'
#  '\tI will conduct you where you shall be lodged;\n'
#  '\tThe rather, for I think I know your hostess\n'
#  '\tAs ample as myself.')
# -------------------------
# "\tThat is Antonio, the duke's eldest son;\n\tThat, Escalus."
# -------------------------
# "\tALL'S WELL THAT ENDS WELL"
# -------------------------
# "\tALL'S WELL THAT ENDS WELL"
# -------------------------
# "\tALL'S WELL THAT ENDS WELL"
# -------------------------
# "\tALL'S WELL THAT ENDS WELL"
# -------------------------
# "\tALL'S WELL THAT ENDS WELL"
# -------------------------
# "\tHow now! where's your master?"
# -------------------------
# "\tHow now, my lord! is't not after midnight?"
# -------------------------
# ("\t'You shall demand of him, whether one Captain Dumain\n"
#  "\tbe i' the camp, a Frenchman; what his reputation is\n"
#  '\twith the duke; what his valour, honesty, and\n'
#  '\texpertness in wars; or whether he thinks it were not\n'
#  '\tpossible, with well-weighing sums of gold, to\n'
#  "\tcorrupt him to revolt.' What say you to this? what\n"
#  '\tdo you know of it?')
# -------------------------
# '\tSo, look about you: know you any here?'
# -------------------------
# "\tALL'S WELL THAT ENDS WELL"
# -------------------------
# "\tALL'S WELL THAT ENDS WELL"
# -------------------------
# "\tALL'S WELL THAT ENDS WELL"
# -------------------------
# ("\tThis man may help me to his majesty's ear,\n"
#  '\tIf he would spend his power. God save you, sir.')
# -------------------------
# "\tALL'S WELL THAT ENDS WELL"
# -------------------------
# ("\tHere is a purr of fortune's, sir, or of fortune's\n"
#  '\tcat,--but not a musk-cat,--that has fallen into the\n'
#  '\tunclean fishpond of her displeasure, and, as he\n'
#  '\tsays, is muddied withal: pray you, sir, use the\n'
#  '\tcarp as you may; for he looks like a poor, decayed,\n'
#  '\tingenious, foolish, rascally knave. I do pity his\n'
#  '\tdistress in my similes of comfort and leave him to\n'
#  '\tyour lordship.')
# -------------------------
# ("\tThe king's coming; I know by his trumpets. Sirrah,\n"
#  '\tinquire further after me; I had talk of you last\n'
#  '\tnight: though you are a fool and a knave, you shall\n'
#  '\teat; go to, follow.')
# -------------------------
# "\tALL'S WELL THAT ENDS WELL"
# -------------------------
# ('\t\t     By my old beard,\n'
#  "\tAnd every hair that's on't, Helen, that's dead,\n"
#  '\tWas a sweet creature: such a ring as this,\n'
#  "\tThe last that e'er I took her at court,\n"
#  '\tI saw upon her finger.')
# -------------------------
# ("\tMy fore-past proofs, howe'er the matter fall,\n"
#  '\tShall tax my fears of little vanity,\n'
#  "\tHaving vainly fear'd too little. Away with him!\n"
#  "\tWe'll sift this matter further.")
# -------------------------
# "\t\t   What woman's that?"
# -------------------------
# ('\tThe jeweller that owes the ring is sent for,\n'
#  '\tAnd he shall surety me. But for this lord,\n'
#  '\tWho hath abused me, as he knows himself,\n'
#  "\tThough yet he never harm'd me, here I quit him:\n"
#  '\tHe knows himself my bed he hath defiled;\n'
#  '\tAnd at that time he got his wife with child:\n'
#  '\tDead though she be, she feels her young one kick:\n'
#  "\tSo there's my riddle: one that's dead is quick:\n"
#  '\tAnd now behold the meaning.')
# -------------------------
# ('\tGood Tom Drum, lend me a handkercher: so,\n'
#  "\tI thank thee: wait on me home, I'll make sport with thee:\n"
#  '\tLet thy courtesies alone, they are scurvy ones.')
# -------------------------
# ("\tIf thou be'st yet a fresh uncropped flower,\n"
#  "\tChoose thou thy husband, and I'll pay thy dower;\n"
#  '\tFor I can guess that by thy honest aid\n'
#  "\tThou keep'st a wife herself, thyself a maid.\n"
#  '\tOf that and all the progress, more or less,\n'
#  '\tResolvedly more leisure shall express:\n'
#  '\tAll yet seems well; and if it end so meet,\n'
#  '\tThe bitter past, more welcome is the sweet.')
# -------------------------
# "\tALL'S WELL THAT ENDS WELL"
# -------------------------
# '\tEPILOGUE'
# -------------------------
# ====================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================

# %%
def remove_play_name(play_lines):
    whitespace = {' ', '\t', '\n'}
    filtered_lines = []
    
    for line in play_lines:
        if line[0] in whitespace and line.strip().isupper():
            continue
        else:
            filtered_lines.append(line)
            
    return filtered_lines

# %%
lines_without_play_name = [
    remove_play_name(play_lines)
    for play_lines in lines_without_square_bracket_text
]

# %% [markdown]
# ### Print the lines again after removing names of the plays

# %%
for play_idx, play_lines in enumerate(lines_without_play_name):
    print(play_idx)
    for line in play_lines:
        if not line[0].isalpha():
            pprint(line)
            print("-"*25)
    print("="*500)
# Out:
# 0
# ('\t\t  Look, where they come:\n'
#  '\tTake but good note, and you shall see in him.\n'
#  "\tThe triple pillar of the world transform'd\n"
#  "\tInto a strumpet's fool: behold and see.")
# -------------------------
# ("\tAnd such a twain can do't, in which I bind,\n"
#  '\tOn pain of punishment, the world to weet\n'
#  '\tWe stand up peerless.')
# -------------------------
# '\t\t    What are you?'
# -------------------------
# ("\tThere's a great spirit gone! Thus did I desire it:\n"
#  '\tWhat our contempt doth often hurl from us,\n'
#  '\tWe wish it ours again; the present pleasure,\n'
#  '\tBy revolution lowering, does become\n'
#  "\tThe opposite of itself: she's good, being gone;\n"
#  '\tThe hand could pluck her back that shoved her on.\n'
#  '\tI must from this enchanting queen break off:\n'
#  '\tTen thousand harms, more than the ills I know,\n'
#  '\tMy idleness doth hatch. How now! Enobarbus!')
# -------------------------
# '\t\t       How now, Varrius!'
# -------------------------
# ('\tHe shall to Parthia. Be it art or hap,\n'
#  '\tHe hath spoken true: the very dice obey him;\n'
#  '\tAnd in our sports my better cunning faints\n'
#  '\tUnder his chance: if we draw lots, he speeds;\n'
#  '\tHis cocks do win the battle still of mine,\n'
#  '\tWhen it is all to nought; and his quails ever\n'
#  "\tBeat mine, inhoop'd, at odds. I will to Egypt:\n"
#  '\tAnd though I make this marriage for my peace,\n'
#  "\tI' the east my pleasure lies.")
# -------------------------
# ('\t\t        O, come, Ventidius,\n'
#  "\tYou must to Parthia: your commission's ready;\n"
#  "\tFollow me, and receive't.")
# -------------------------
# ('\t\t      O, from Italy\n'
#  '\tRam thou thy fruitful tidings in mine ears,\n'
#  '\tThat long time have been barren.')
# -------------------------
# ("\tHorrible villain! or I'll spurn thine eyes\n"
#  "\tLike balls before me; I'll unhair thy head:")
# -------------------------
# ("\tThou shalt be whipp'd with wire, and stew'd in brine,\n"
#  '\tSmarting in lingering pickle.')
# -------------------------
# ('\tThese hands do lack nobility, that they strike\n'
#  '\tA meaner than myself; since I myself\n'
#  '\tHave given myself the cause.')
# -------------------------
# ('\t\t       Come hither, sir.\n'
#  '\tThough it be honest, it is never good\n'
#  '\tTo bring bad news: give to a gracious message.\n'
#  '\tAn host of tongues; but let ill tidings tell\n'
#  '\tThemselves when they be felt.')
# -------------------------
# ('\tLet him for ever go:--let him not--Charmian,\n'
#  '\tThough he be painted one way like a Gorgon,\n'
#  "\tThe other way's a Mars. Bid you Alexas")
# -------------------------
# ('\tBring me word how tall she is. Pity me, Charmian,\n'
#  '\tBut do not speak to me. Lead me to my chamber.')
# -------------------------
# '\tShall we dance now the Egyptian Bacchanals,\n\tAnd celebrate our drink?'
# -------------------------
# ('\tCome, thou monarch of the vine,\n'
#  '\tPlumpy Bacchus with pink eyne!\n'
#  "\tIn thy fats our cares be drown'd,\n"
#  "\tWith thy grapes our hairs be crown'd:\n"
#  '\tCup us, till the world go round,\n'
#  '\tCup us, till the world go round!')
# -------------------------
# "\tMenas, I'll not on shore."
# -------------------------
# '\t\n\t\t\tSo;\n\tThis is to horse. Adieu, noble Agrippa.'
# -------------------------
# '\tCome hither, sir.'
# -------------------------
# '\t\t    Thy business?'
# -------------------------
# '\tHow now, worthy soldier?'
# -------------------------
# ("\t  To try eloquence, now 'tis time: dispatch;\n"
#  '\tFrom Antony win Cleopatra: promise,\n'
#  '\tAnd in our name, what she requires; add more,\n'
#  '\tFrom thine invention, offers: women are not\n'
#  '\tIn their best fortunes strong; but want will perjure\n'
#  "\tThe ne'er touch'd vestal: try thy cunning, Thyreus;\n"
#  '\tMake thine own edict for thy pains, which we\n'
#  '\tWill answer as a law.')
# -------------------------
# '\tTake hence this Jack, and whip him.'
# -------------------------
# ('\tYou were half blasted ere I knew you: ha!\n'
#  "\tHave I my pillow left unpress'd in Rome,\n"
#  '\tForborne the getting of a lawful race,\n'
#  '\tAnd by a gem of women, to be abused\n'
#  '\tBy one that looks on feeders?')
# -------------------------
# "\t\t    Is he whipp'd?"
# -------------------------
# ('\t\t    Give me thy hand,\n'
#  '\tThou hast been rightly honest;--so hast thou;--\n'
#  '\tThou,--and thou,--and thou:--you have served me well,\n'
#  '\tAnd kings have been your fellows.')
# -------------------------
# ('\tCome good fellow, put mine iron on:\n'
#  '\tIf fortune be not ours to-day, it is\n'
#  '\tBecause we brave her: come.')
# -------------------------
# ('\tGood morrow to thee; welcome:\n'
#  "\tThou look'st like him that knows a warlike charge:\n"
#  '\tTo business that we love we rise betime,\n'
#  "\tAnd go to't with delight.")
# -------------------------
# ('\tAnd worthy shameful cheque it were, to stand\n'
#  "\tOn more mechanic compliment; I'll leave thee\n"
#  '\tNow, like a man of steel. You that will fight,\n'
#  "\tFollow me close; I'll bring you to't. Adieu.")
# -------------------------
# '\t\t    Give me thy hand'
# -------------------------
# "\tTo this great fairy I'll commend thy acts,\n\tMake her thanks bless thee."
# -------------------------
# ("\t\t      O thou day o' the world,\n"
#  "\tChain mine arm'd neck; leap thou, attire and all,\n"
#  '\tThrough proof of harness to my heart, and there\n'
#  '\tRide on the pants triumphing!')
# -------------------------
# ('\t\t                  Hark! the drums\n'
#  '\tDemurely wake the sleepers. Let us bear him\n'
#  '\tTo the court of guard; he is of note: our hour\n'
#  '\tIs fully out.')
# -------------------------
# ('\tO sun, thy uprise shall I see no more:\n'
#  '\tFortune and Antony part here; even here\n'
#  '\tDo we shake hands. All come to this? The hearts\n'
#  "\tThat spaniel'd me at heels, to whom I gave\n"
#  '\tTheir wishes, do discandy, melt their sweets\n'
#  "\tOn blossoming Caesar; and this pine is bark'd,\n"
#  "\tThat overtopp'd them all. Betray'd I am:\n"
#  '\tO this false soul of Egypt! this grave charm,--\n'
#  "\tWhose eye beck'd forth my wars, and call'd them home;\n"
#  '\tWhose bosom was my crownet, my chief end,--\n'
#  '\tLike a right gipsy, hath, at fast and loose,\n'
#  '\tBeguiled me to the very heart of loss.\n'
#  '\tWhat, Eros, Eros!')
# -------------------------
# '\tAh, thou spell! Avaunt!'
# -------------------------
# ("\t\t'Tis well thou'rt gone,\n"
#  "\tIf it be well to live; but better 'twere\n"
#  "\tThou fell'st into my fury, for one death\n"
#  '\tMight have prevented many. Eros, ho!\n'
#  '\tThe shirt of Nessus is upon me: teach me,\n'
#  '\tAlcides, thou mine ancestor, thy rage:\n'
#  "\tLet me lodge Lichas on the horns o' the moon;\n"
#  "\tAnd with those hands, that grasp'd the heaviest club,\n"
#  '\tSubdue my worthiest self. The witch shall die:\n'
#  '\tTo the young Roman boy she hath sold me, and I fall\n'
#  "\tUnder this plot; she dies for't. Eros, ho!")
# -------------------------
# "\t\t      O! thy vile lady!\n\tShe has robb'd me of my sword."
# -------------------------
# "\tThat thou depart'st hence safe,\n\tDoes pay thy labour richly; go."
# -------------------------
# ('\t\t         Off, pluck off:\n'
#  '\tThe seven-fold shield of Ajax cannot keep\n'
#  '\tThe battery from my heart. O, cleave, my sides!\n'
#  '\tHeart, once be stronger than thy continent,\n'
#  '\tCrack thy frail case! Apace, Eros, apace.\n'
#  '\tNo more a soldier: bruised pieces, go;\n'
#  '\tYou have been nobly borne. From me awhile.')
# -------------------------
# ("\tI will o'ertake thee, Cleopatra, and\n"
#  '\tWeep for my pardon. So it must be, for now\n'
#  '\tAll length is torture: since the torch is out,\n'
#  '\tLie down, and stray no farther: now all labour\n'
#  '\tMars what it does; yea, very force entangles\n'
#  '\tItself with strength: seal then, and all is done.\n'
#  '\tEros!--I come, my queen:--Eros!--Stay for me:\n'
#  "\tWhere souls do couch on flowers, we'll hand in hand,\n"
#  '\tAnd with our sprightly port make the ghosts gaze:\n'
#  '\tDido and her AEneas shall want troops,\n'
#  '\tAnd all the haunt be ours. Come, Eros, Eros!')
# -------------------------
# ("\tI learn'd of thee. How! not dead? not dead?\n"
#  '\tThe guard, ho! O, dispatch me!')
# -------------------------
# '\t\t  How now! is he dead?'
# -------------------------
# ('\tAnd welcome, welcome! die where thou hast lived:\n'
#  '\tQuicken with kissing: had my lips that power,\n'
#  '\tThus would I wear them out.')
# -------------------------
# ("\tThe crown o' the earth doth melt. My lord!\n"
#  "\tO, wither'd is the garland of the war,\n"
#  "\tThe soldier's pole is fall'n: young boys and girls\n"
#  '\tAre level now with men; the odds is gone,\n'
#  '\tAnd there is nothing left remarkable\n'
#  '\tBeneath the visiting moon.')
# -------------------------
# ('\tThe business of this man looks out of him;\n'
#  "\tWe'll hear him what he says. Whence are you?")
# -------------------------
# "\t\tWhere's Dolabella,\n\tTo second Proculeius?"
# -------------------------
# '\tGuard her till Caesar come.'
# -------------------------
# "\tDo not yourself such wrong, who are in this\n\tRelieved, but not betray'd."
# -------------------------
# "\tTo Caesar I will speak what you shall please,\n\tIf you'll employ me to him."
# -------------------------
# ('\t\t   Prithee, go hence;\n'
#  '\tOr I shall show the cinders of my spirits\n'
#  '\tThrough the ashes of my chance: wert thou a man,\n'
#  '\tThou wouldst have mercy on me.')
# -------------------------
# ("\t\tNow, Iras, what think'st thou?\n"
#  '\tThou, an Egyptian puppet, shalt be shown\n'
#  '\tIn Rome, as well as I\tmechanic slaves\n'
#  '\tWith greasy aprons, rules, and hammers, shall\n'
#  '\tUplift us to the view; in their thick breaths,\n'
#  '\tRank of gross diet, shall be enclouded,\n'
#  '\tAnd forced to drink their vapour.')
# -------------------------
# ('\t\t     Now, Charmian!\n'
#  '\tShow me, my women, like a queen: go fetch\n'
#  '\tMy best attires: I am again for Cydnus,\n'
#  '\tTo meet Mark Antony: sirrah Iras, go.\n'
#  "\tNow, noble Charmian, we'll dispatch indeed;\n"
#  "\tAnd, when thou hast done this chare, I'll give thee leave\n"
#  '\tTo play till doomsday. Bring our crown and all.\n'
#  "\tWherefore's this noise?")
# -------------------------
# ('\tWhat poor an instrument\n'
#  '\tMay do a noble deed! he brings me liberty.\n'
#  "\tMy resolution's placed, and I have nothing\n"
#  '\tOf woman in me: now from head to foot\n'
#  '\tI am marble-constant; now the fleeting moon\n'
#  '\tNo planet is of mine.')
# -------------------------
# '\tHast thou the pretty worm of Nilus there,\n\tThat kills and pains not?'
# -------------------------
# ('\tHave I the aspic in my lips? Dost fall?\n'
#  '\tIf thou and nature can so gently part,\n'
#  "\tThe stroke of death is as a lover's pinch,\n"
#  '\tWhich hurts, and is desired. Dost thou lie still?\n'
#  "\tIf thus thou vanishest, thou tell'st the world\n"
#  '\tIt is not worth leave-taking.')
# -------------------------
# ('\tWith thy sharp teeth this knot intrinsicate\n'
#  '\tOf life at once untie: poor venomous fool\n'
#  '\tBe angry, and dispatch. O, couldst thou speak,\n'
#  '\tThat I might hear thee call great Caesar ass\n'
#  '\tUnpolicied!')
# -------------------------
# '\tWhat should I stay--'
# -------------------------
# '\tO, come apace, dispatch! I partly feel thee.'
# -------------------------
# ====================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================
# 1
# ('\tHere comes the almanac of my true date.\n'
#  "\tWhat now? how chance thou art return'd so soon?")
# -------------------------
# ("\tHow now sir! is your merry humour alter'd?\n"
#  '\tAs you love strokes, so jest with me again.\n'
#  '\tYou know no Centaur? you received no gold?\n'
#  '\tYour mistress sent to have me home to dinner?\n'
#  '\tMy house was at the Phoenix? Wast thou mad,\n'
#  '\tThat thus so madly thou didst answer me?')
# -------------------------
# ('\t\t    Get you home\n'
#  "\tAnd fetch the chain; by this I know 'tis made:\n"
#  '\tBring it, I pray you, to the Porpentine;\n'
#  "\tFor there's the house: that chain will I bestow--\n"
#  '\tBe it for nothing but to spite my wife--\n'
#  '\tUpon mine hostess there: good sir, make haste.\n'
#  '\tSince mine own doors refuse to entertain me,\n'
#  "\tI'll knock elsewhere, to see if they'll disdain me.")
# -------------------------
# ('\t\tThis I wonder at,\n'
#  '\tThat he, unknown to me, should be in debt.\n'
#  '\tTell me, was he arrested on a band?')
# -------------------------
# ('\tHere comes my man; I think he brings the money.\n'
#  '\tHow now, sir! have you that I sent you for?')
# -------------------------
# '\tSay now, whose suit is he arrested at?'
# -------------------------
# '\tHark, hark! I hear him, mistress. fly, be gone!'
# -------------------------
# ('\t\tWhat I told you then,\n'
#  '\tI hope I shall have leisure to make good;\n'
#  '\tIf this be not a dream I see and hear.')
# -------------------------
# ====================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================
# 2
# "\t'Twill be a good way; and to-morrow the wrestling is."
# -------------------------
# ('\tNow will I stir this gamester: I hope I shall see\n'
#  '\tan end of him; for my soul, yet I know not why,\n'
#  "\thates nothing more than he. Yet he's gentle, never\n"
#  '\tschooled and yet learned, full of noble device, of\n'
#  '\tall sorts enchantingly beloved, and indeed so much\n'
#  '\tin the heart of the world, and especially of my own\n'
#  '\tpeople, who best know him, that I am altogether\n'
#  '\tmisprised: but it shall not be so long; this\n'
#  '\twrestler shall clear all: nothing remains but that\n'
#  "\tI kindle the boy thither; which now I'll go about.")
# -------------------------
# "\tBon jour, Monsieur Le Beau: what's the news?"
# -------------------------
# ('\tWear this for me, one out of suits with fortune,\n'
#  '\tThat could give more, but that her hand lacks means.\n'
#  '\tShall we go, coz?')
# -------------------------
# ('\tThus must I from the smoke into the smother;\n'
#  '\tFrom tyrant duke unto a tyrant brother:\n'
#  '\tBut heavenly Rosalind!')
# -------------------------
# '\tLook you, who comes here; a young man and an old in\n\tsolemn talk.'
# -------------------------
# ('\t\n'
#  '\t\n'
#  '\tSONG.\n'
#  'AMIENS\tUnder the greenwood tree\n'
#  '\tWho loves to lie with me,\n'
#  '\tAnd turn his merry note\n'
#  "\tUnto the sweet bird's throat,\n"
#  '\tCome hither, come hither, come hither:\n'
#  '\tHere shall he see No enemy\n'
#  '\tBut winter and rough weather.')
# -------------------------
# ("\tAnd loves to live i' the sun,\n"
#  '\tSeeking the food he eats\n'
#  '\tAnd pleased with what he gets,\n'
#  '\tCome hither, come hither, come hither:\n'
#  '\tHere shall he see No enemy\n'
#  '\tBut winter and rough weather.')
# -------------------------
# ('\tIf it do come to pass\n'
#  '\tThat any man turn ass,\n'
#  '\tLeaving his wealth and ease,\n'
#  '\tA stubborn will to please,\n'
#  '\tDucdame, ducdame, ducdame:\n'
#  '\tHere shall he see\n'
#  '\tGross fools as he,\n'
#  '\tAn if he will come to me.')
# -------------------------
# ('\tWhy should this a desert be?\n'
#  '\tFor it is unpeopled? No:\n'
#  "\tTongues I'll hang on every tree,\n"
#  '\tThat shall civil sayings show:\n'
#  '\tSome, how brief the life of man\n'
#  '\tRuns his erring pilgrimage,\n'
#  '\tThat the stretching of a span\n'
#  '\tBuckles in his sum of age;\n'
#  '\tSome, of violated vows\n'
#  "\t'Twixt the souls of friend and friend:\n"
#  '\tBut upon the fairest boughs,\n'
#  '\tOr at every sentence end,\n'
#  '\tWill I Rosalinda write,\n'
#  '\tTeaching all that read to know\n'
#  '\tThe quintessence of every sprite\n'
#  '\tHeaven would in little show.\n'
#  '\tTherefore Heaven Nature charged\n'
#  "\tThat one body should be fill'd\n"
#  '\tWith all graces wide-enlarged:\n'
#  "\tNature presently distill'd\n"
#  "\tHelen's cheek, but not her heart,\n"
#  "\tCleopatra's majesty,\n"
#  "\tAtalanta's better part,\n"
#  "\tSad Lucretia's modesty.\n"
#  '\tThus Rosalind of many parts\n'
#  '\tBy heavenly synod was devised,\n'
#  '\tOf many faces, eyes and hearts,\n'
#  '\tTo have the touches dearest prized.\n'
#  '\tHeaven would that she these gifts should have,\n'
#  '\tAnd I to live and die her slave.')
# -------------------------
# ('\tSir Oliver Martext, you are well met: will you\n'
#  '\tdispatch us here under this tree, or shall we go\n'
#  '\twith you to your chapel?')
# -------------------------
# "\tProceed, proceed\tI'll give her."
# -------------------------
# ('\tTake thou no scorn to wear the horn;\n'
#  '\tIt was a crest ere thou wast born:\n'
#  "\tThy father's father wore it,\n"
#  '\tAnd thy father bore it:\n'
#  '\tThe horn, the horn, the lusty horn\n'
#  '\tIs not a thing to laugh to scorn.')
# -------------------------
# ("\tArt thou god to shepherd turn'd,\n"
#  "\tThat a maiden's heart hath burn'd?\n"
#  '\tCan a woman rail thus?')
# -------------------------
# ('\tWhy, thy godhead laid apart,\n'
#  "\tWarr'st thou with a woman's heart?\n"
#  '\tDid you ever hear such railing?\n'
#  '\tWhiles the eye of man did woo me,\n'
#  '\tThat could do no vengeance to me.\n'
#  '\tMeaning me a beast.\n'
#  '\tIf the scorn of your bright eyne\n'
#  '\tHave power to raise such love in mine,\n'
#  '\tAlack, in me what strange effect\n'
#  '\tWould they work in mild aspect!\n'
#  '\tWhiles you chid me, I did love;\n'
#  '\tHow then might your prayers move!\n'
#  '\tHe that brings this love to thee\n'
#  '\tLittle knows this love in me:\n'
#  '\tAnd by him seal up thy mind;\n'
#  '\tWhether that thy youth and kind\n'
#  '\tWill the faithful offer take\n'
#  '\tOf me and all that I can make;\n'
#  '\tOr else by him my love deny,\n'
#  "\tAnd then I'll study how to die.")
# -------------------------
# '\tLook, here comes a lover of mine and a lover of hers.'
# -------------------------
# '\tI will help you, if I can:'
# -------------------------
# '\tI would love you, if I could. To-morrow meet me all together.'
# -------------------------
# "\tI will marry you, if ever I marry woman, and I'll be\n\tmarried to-morrow:"
# -------------------------
# ('\tI will satisfy you, if ever I satisfied man, and you\n'
#  '\tshall be married to-morrow:')
# -------------------------
# ('\tI will content you, if what pleases you contents\n'
#  '\tyou, and you shall be married to-morrow.')
# -------------------------
# '\tAs you love Rosalind, meet:'
# -------------------------
# ('\tas you love Phebe, meet: and as I love no woman,\n'
#  "\tI'll meet. So fare you well: I have left you commands.")
# -------------------------
# ('\tBetween the acres of the rye,\n'
#  '\tWith a hey, and a ho, and a hey nonino\n'
#  '\tThese pretty country folks would lie,\n'
#  '\tIn spring time, &c.')
# -------------------------
# ('\tThis carol they began that hour,\n'
#  '\tWith a hey, and a ho, and a hey nonino,\n'
#  '\tHow that a life was but a flower\n'
#  '\tIn spring time, &c.')
# -------------------------
# ('\tAnd therefore take the present time,\n'
#  '\tWith a hey, and a ho, and a hey nonino;\n'
#  '\tFor love is crowned with the prime\n'
#  '\tIn spring time, &c.')
# -------------------------
# '\tTo you I give myself, for I am yours.'
# -------------------------
# ('\tYou to your former honour I bequeath;\n'
#  '\tYour patience and your virtue well deserves it:')
# -------------------------
# '\tYou to a love that your true faith doth merit:'
# -------------------------
# '\tYou to your land and love and great allies:'
# -------------------------
# '\tYou to a long and well-deserved bed:'
# -------------------------
# ('\tAnd you to wrangling; for thy loving voyage\n'
#  "\tIs but for two months victuall'd. So, to your pleasures:\n"
#  '\tI am for other than for dancing measures.')
# -------------------------
# ====================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================
# 3
# ("\tWhat shouts are these? The other side o' the city\n"
#  '\tis risen: why stay we prating here? to the Capitol!')
# -------------------------
# '\t\t       Hail, noble Marcius!'
# -------------------------
# '\t  Follow Cominius; we must follow you;\n\tRight worthy you priority.'
# -------------------------
# ("\t'They have press'd a power, but it is not known\n"
#  '\tWhether for east or west: the dearth is great;\n'
#  "\tThe people mutinous; and it is rumour'd,\n"
#  '\tCominius, Marcius your old enemy,\n'
#  '\tWho is of Rome worse hated than of you,\n'
#  '\tAnd Titus Lartius, a most valiant Roman,\n'
#  '\tThese three lead on this preparation\n'
#  "\tWhither 'tis bent: most likely 'tis for you:\n"
#  "\tConsider of it.'")
# -------------------------
# '\tTutus Aufidius, is he within your walls?'
# -------------------------
# ('\t\t       Hark! our drums\n'
#  "\tAre bringing forth our youth. We'll break our walls,\n"
#  '\tRather than they shall pound us up: our gates,\n'
#  "\tWhich yet seem shut, we, have but pinn'd with rushes;\n"
#  "\tThey'll open of themselves.")
# -------------------------
# ('\t\t      Hark you. far off!\n'
#  '\tThere is Aufidius; list, what work he makes\n'
#  '\tAmongst your cloven army.')
# -------------------------
# ('\tSo, now the gates are ope: now prove good seconds:\n'
#  "\t'Tis for the followers fortune widens them,\n"
#  '\tNot for the fliers: mark me, and do the like.')
# -------------------------
# ('\tGo, sound thy trumpet in the market-place;\n'
#  "\tCall thither all the officers o' the town,\n"
#  '\tWhere they shall know our mind: away!')
# -------------------------
# '\t\t                  Thy news?'
# -------------------------
# ('\tO, me alone! make you a sword of me?\n'
#  '\tIf these shows be not outward, which of you\n'
#  '\tBut is four Volsces? none of you but is\n'
#  '\tAble to bear against the great Aufidius\n'
#  '\tA shield as hard as his. A certain number,\n'
#  '\tThough thanks to all, must I select\n'
#  '\tfrom all: the rest\n'
#  '\tShall bear the business in some other fight,\n'
#  "\tAs cause will be obey'd. Please you to march;\n"
#  '\tAnd four shall quickly draw out my command,\n'
#  '\tWhich men are best inclined.')
# -------------------------
# '\tOfficious, and not valiant, you have shamed me\n\tIn your condemned seconds.'
# -------------------------
# '\t[Enter MENENIUS with the two Tribunes of the people,\n\tSICINIUS and BRUTUS.'
# -------------------------
# ('\tHow now, my as fair as noble ladies,--and the moon,\n'
#  '\twere she earthly, no nobler,--whither do you follow\n'
#  '\tyour eyes so fast?')
# -------------------------
# ('\tGod save your good worships! Marcius is coming\n'
#  '\thome: he has more cause to be proud. Where is he wounded?')
# -------------------------
# '\tHark! the trumpets.'
# -------------------------
# '\t\n\tO my sweet lady, pardon.'
# -------------------------
# ("\t\t     Masters o' the people,\n"
#  '\tWe do request your kindest ears, and after,\n'
#  '\tYour loving motion toward the common body,\n'
#  '\tTo yield what passes here.')
# -------------------------
# '\t\t  Nay, keep your place.'
# -------------------------
# ('\tHere he comes, and in the gown of humility: mark his\n'
#  '\tbehavior. We are not to stay all together, but to\n'
#  '\tcome by him where he stands, by ones, by twos, and\n'
#  "\tby threes. He's to make his requests by\n"
#  '\tparticulars; wherein every one of us has a single\n'
#  '\thonour, in giving him our own voices with our own\n'
#  '\ttongues: therefore follow me, and I direct you how\n'
#  '\tyou shall go by him.')
# -------------------------
# '\t\t      So, here comes a brace.'
# -------------------------
# '\tYou know the cause, air, of my standing here.'
# -------------------------
# ('\tHere come more voices.\n'
#  '\tYour voices: for your voices I have fought;\n'
#  "\tWatch'd for your voices; for Your voices bear\n"
#  '\tOf wounds two dozen odd; battles thrice six\n'
#  '\tI have seen and heard of; for your voices have\n'
#  '\tDone many things, some less, some more your voices:\n'
#  '\tIndeed I would be consul.')
# -------------------------
# "\tHe has it now, and by his looks methink\n\t'Tis warm at 's heart."
# -------------------------
# ('\tBehold, these are the tribunes of the people,\n'
#  "\tThe tongues o' the common mouth: I do despise them;\n"
#  '\tFor they do prank them in authority,\n'
#  '\tAgainst all noble sufferance.')
# -------------------------
# '\tLet him be apprehended.'
# -------------------------
# ('\t\tin whose name myself\n'
#  '\tAttach thee as a traitorous innovator,\n'
#  '\tA foe to the public weal: obey, I charge thee,\n'
#  '\tAnd follow to thine answer.')
# -------------------------
# ("\t'Tribunes!' 'Patricians!' 'Citizens!' 'What, ho!'\n"
#  "\t'Sicinius!' 'Brutus!' 'Coriolanus!' 'Citizens!'\n"
#  "\t'Peace, peace, peace!' 'Stay, hold, peace!'")
# -------------------------
# ("\tThere's some among you have beheld me fighting:\n"
#  '\tCome, try upon yourselves what you have seen me.')
# -------------------------
# "\t\t      Here's goodly work!"
# -------------------------
# '\tLet me desire your company: he must come,\n\tOr what is worst will follow.'
# -------------------------
# ('\t\t    I talk of you:\n'
#  '\tWhy did you wish me milder? would you have me\n'
#  '\tFalse to my nature? Rather say I play\n'
#  '\tThe man I am.')
# -------------------------
# '\tWhat, will he come?'
# -------------------------
# ('\tPut him to choler straight: he hath been used\n'
#  '\tEver to conquer, and to have his worth\n'
#  '\tOf contradiction: being once chafed, he cannot\n'
#  "\tBe rein'd again to temperance; then he speaks\n"
#  "\tWhat's in his heart; and that is there which looks\n"
#  '\tWith us to break his neck.')
# -------------------------
# '\tHere comes his mother.'
# -------------------------
# '\t\t        Will you be gone?'
# -------------------------
# ('\tI would the gods had nothing else to do\n'
#  "\tBut to confirm my curses! Could I meet 'em\n"
#  '\tBut once a-day, it would unclog my heart\n'
#  "\tOf what lies heavy to't.")
# -------------------------
# '\t\t  Save you, sir.'
# -------------------------
# ('\tO world, thy slippery turns! Friends now fast sworn,\n'
#  '\tWhose double bosoms seem to wear one heart,\n'
#  '\tWhose house, whose bed, whose meal, and exercise,\n'
#  "\tAre still together, who twin, as 'twere, in love\n"
#  '\tUnseparable, shall within this hour,\n'
#  '\tOn a dissension of a doit, break out\n'
#  '\tTo bitterest enmity: so, fellest foes,\n'
#  '\tWhose passions and whose plots have broke their sleep,\n'
#  '\tTo take the one the other, by some chance,\n'
#  '\tSome trick not worth an egg, shall grow dear friends\n'
#  '\tAnd interjoin their issues. So with me:\n'
#  "\tMy birth-place hate I, and my love's upon\n"
#  "\tThis enemy town. I'll enter: if he slay me,\n"
#  '\tHe does fair justice; if he give me way,\n'
#  "\tI'll do his country service.")
# -------------------------
# ('\tNot yet thou knowest me, and, seeing me, dost not\n'
#  '\tThink me for the man I am, necessity\n'
#  '\tCommands me name myself.')
# -------------------------
# '\t\t      Is this Menenius?'
# -------------------------
# ('\tThe glorious gods sit in hourly synod about thy\n'
#  '\tparticular prosperity, and love thee no worse than\n'
#  '\tthy old father Menenius does! O my son, my son!\n'
#  "\tthou art preparing fire for us; look thee, here's\n"
#  '\twater to quench it. I was hardly moved to come to\n'
#  '\tthee; but being assured none but myself could move\n'
#  '\tthee, I have been blown out of your gates with\n'
#  '\tsighs; and conjure thee to pardon Rome, and thy\n'
#  '\tpetitionary countrymen. The good gods assuage thy\n'
#  '\twrath, and turn the dregs of it upon this varlet\n'
#  '\there,--this, who, like a block, hath denied my\n'
#  '\taccess to thee.')
# -------------------------
# ('\tAnd would have rent it. Another word, Menenius,\n'
#  '\tI will not hear thee speak. This man, Aufidius,\n'
#  "\tWas my beloved in Rome: yet thou behold'st!")
# -------------------------
# ('\tShall I be tempted to infringe my vow\n'
#  "\tIn the same time 'tis made? I will not.")
# -------------------------
# ("\tMy wife comes foremost; then the honour'd mould\n"
#  '\tWherein this trunk was framed, and in her hand\n'
#  '\tThe grandchild to her blood. But, out, affection!\n'
#  '\tAll bond and privilege of nature, break!\n'
#  '\tLet it be virtuous to be obstinate.\n'
#  "\tWhat is that curt'sy worth? or those doves' eyes,\n"
#  '\tWhich can make gods forsworn? I melt, and am not\n'
#  '\tOf stronger earth than others. My mother bows;\n'
#  '\tAs if Olympus to a molehill should\n'
#  '\tIn supplication nod: and my young boy\n'
#  '\tHath an aspect of intercession, which\n'
#  "\tGreat nature cries 'Deny not.' let the Volsces\n"
#  "\tPlough Rome and harrow Italy: I'll never\n"
#  '\tBe such a gosling to obey instinct, but stand,\n'
#  '\tAs if a man were author of himself\n'
#  '\tAnd knew no other kin.')
# -------------------------
# '\tOf thy deep duty more impression show\n\tThan that of common sons.'
# -------------------------
# ('\tBut we will drink together; and you shall bear\n'
#  '\tA better witness back than words, which we,\n'
#  "\tOn like conditions, will have counter-seal'd.\n"
#  '\tCome, enter with us. Ladies, you deserve\n'
#  '\tTo have a temple built you: all the swords\n'
#  '\tIn Italy, and her confederate arms,\n'
#  '\tCould not have made this peace.')
# -------------------------
# ('\tThe trumpets, sackbuts, psalteries and fifes,\n'
#  '\tTabours and cymbals and the shouting Romans,\n'
#  '\tMake the sun dance. Hark you!')
# -------------------------
# '\tMost welcome!'
# -------------------------
# ====================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================
# 4
# ('\tOne that goes with him: I love him for his sake;\n'
#  '\tAnd yet I know him a notorious liar,\n'
#  '\tThink him a great way fool, solely a coward;\n'
#  '\tYet these fixed evils sit so fit in him,\n'
#  "\tThat they take place, when virtue's steely bones\n"
#  "\tLook bleak i' the cold wind: withal, full oft we see\n"
#  '\tCold wisdom waiting on superfluous folly.')
# -------------------------
# ('\tEven so it was with me when I was young:\n'
#  "\tIf ever we are nature's, these are ours; this thorn\n"
#  '\tDoth to our rose of youth rightly belong;\n'
#  '\tOur blood to us, this to our blood is born;\n'
#  "\tIt is the show and seal of nature's truth,\n"
#  "\tWhere love's strong passion is impress'd in youth:\n"
#  '\tBy our remembrances of days foregone,\n'
#  '\tSuch were our faults, or then we thought them none.\n'
#  "\tHer eye is sick on't: I observe her now.")
# -------------------------
# ('\tand debile minister, great power, great\n'
#  '\ttranscendence: which should, indeed, give us a\n'
#  '\tfurther use to be made than alone the recovery of\n'
#  '\tthe king, as to be--')
# -------------------------
# '\tgenerally thankful.'
# -------------------------
# ('\tFair maid, send forth thine eye: this youthful parcel\n'
#  '\tOf noble bachelors stand at my bestowing,\n'
#  "\tO'er whom both sovereign power and father's voice\n"
#  '\tI have to use: thy frank election make;\n'
#  '\tThou hast power to choose, and they none to forsake.')
# -------------------------
# '\tCome, sirrah.'
# -------------------------
# "\t'Twill be two days ere I shall see you, so\n\tI leave you to your wisdom."
# -------------------------
# ('\tGo thou toward home; where I will never come\n'
#  '\tWhilst I can shake my sword or hear the drum.\n'
#  '\tAway, and for our flight.')
# -------------------------
# ('\t[Flourish. Enter the DUKE of Florence attended;\n'
#  '\tthe two Frenchmen, with a troop of soldiers.')
# -------------------------
# ('\tWhen thou canst get the ring upon my finger which\n'
#  '\tnever shall come off, and show me a child begotten\n'
#  '\tof thy body that I am father to, then call me\n'
#  "\thusband: but in such a 'then' I write a 'never.'\n"
#  '\tThis is a dreadful sentence.')
# -------------------------
# ("\tI am Saint Jaques' pilgrim, thither gone:\n"
#  '\tAmbitious love hath so in me offended,\n'
#  '\tThat barefoot plod I the cold ground upon,\n'
#  '\tWith sainted vow my faults to have amended.\n'
#  '\tWrite, write, that from the bloody course of war\n'
#  '\tMy dearest master, your dear son, may hie:\n'
#  '\tBless him at home in peace, whilst I from far\n'
#  '\tHis name with zealous fervor sanctify:\n'
#  '\tHis taken labours bid him me forgive;\n'
#  '\tI, his despiteful Juno, sent him forth\n'
#  '\tFrom courtly friends, with camping foes to live,\n'
#  '\tWhere death and danger dogs the heels of worth:\n'
#  '\tHe is too good and fair for death and me:\n'
#  '\tWhom I myself embrace, to set him free.')
# -------------------------
# ('\tWe have lost our labour; they are gone a contrary\n'
#  '\tway: hark! you may know by their trumpets.')
# -------------------------
# ('\tLook, here comes a pilgrim: I know she will lie at\n'
#  "\tmy house; thither they send one another: I'll\n"
#  '\tquestion her. God save you, pilgrim! whither are you bound?')
# -------------------------
# ('\tHark you! they come this way.\n'
#  '\tIf you will tarry, holy pilgrim,\n'
#  '\tBut till the troops come by,\n'
#  '\tI will conduct you where you shall be lodged;\n'
#  '\tThe rather, for I think I know your hostess\n'
#  '\tAs ample as myself.')
# -------------------------
# "\tThat is Antonio, the duke's eldest son;\n\tThat, Escalus."
# -------------------------
# "\tHow now! where's your master?"
# -------------------------
# "\tHow now, my lord! is't not after midnight?"
# -------------------------
# ("\t'You shall demand of him, whether one Captain Dumain\n"
#  "\tbe i' the camp, a Frenchman; what his reputation is\n"
#  '\twith the duke; what his valour, honesty, and\n'
#  '\texpertness in wars; or whether he thinks it were not\n'
#  '\tpossible, with well-weighing sums of gold, to\n'
#  "\tcorrupt him to revolt.' What say you to this? what\n"
#  '\tdo you know of it?')
# -------------------------
# '\tSo, look about you: know you any here?'
# -------------------------
# ("\tThis man may help me to his majesty's ear,\n"
#  '\tIf he would spend his power. God save you, sir.')
# -------------------------
# ("\tHere is a purr of fortune's, sir, or of fortune's\n"
#  '\tcat,--but not a musk-cat,--that has fallen into the\n'
#  '\tunclean fishpond of her displeasure, and, as he\n'
#  '\tsays, is muddied withal: pray you, sir, use the\n'
#  '\tcarp as you may; for he looks like a poor, decayed,\n'
#  '\tingenious, foolish, rascally knave. I do pity his\n'
#  '\tdistress in my similes of comfort and leave him to\n'
#  '\tyour lordship.')
# -------------------------
# ("\tThe king's coming; I know by his trumpets. Sirrah,\n"
#  '\tinquire further after me; I had talk of you last\n'
#  '\tnight: though you are a fool and a knave, you shall\n'
#  '\teat; go to, follow.')
# -------------------------
# ('\t\t     By my old beard,\n'
#  "\tAnd every hair that's on't, Helen, that's dead,\n"
#  '\tWas a sweet creature: such a ring as this,\n'
#  "\tThe last that e'er I took her at court,\n"
#  '\tI saw upon her finger.')
# -------------------------
# ("\tMy fore-past proofs, howe'er the matter fall,\n"
#  '\tShall tax my fears of little vanity,\n'
#  "\tHaving vainly fear'd too little. Away with him!\n"
#  "\tWe'll sift this matter further.")
# -------------------------
# "\t\t   What woman's that?"
# -------------------------
# ('\tThe jeweller that owes the ring is sent for,\n'
#  '\tAnd he shall surety me. But for this lord,\n'
#  '\tWho hath abused me, as he knows himself,\n'
#  "\tThough yet he never harm'd me, here I quit him:\n"
#  '\tHe knows himself my bed he hath defiled;\n'
#  '\tAnd at that time he got his wife with child:\n'
#  '\tDead though she be, she feels her young one kick:\n'
#  "\tSo there's my riddle: one that's dead is quick:\n"
#  '\tAnd now behold the meaning.')
# -------------------------
# ('\tGood Tom Drum, lend me a handkercher: so,\n'
#  "\tI thank thee: wait on me home, I'll make sport with thee:\n"
#  '\tLet thy courtesies alone, they are scurvy ones.')
# -------------------------
# ("\tIf thou be'st yet a fresh uncropped flower,\n"
#  "\tChoose thou thy husband, and I'll pay thy dower;\n"
#  '\tFor I can guess that by thy honest aid\n'
#  "\tThou keep'st a wife herself, thyself a maid.\n"
#  '\tOf that and all the progress, more or less,\n'
#  '\tResolvedly more leisure shall express:\n'
#  '\tAll yet seems well; and if it end so meet,\n'
#  '\tThe bitter past, more welcome is the sweet.')
# -------------------------
# ====================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================

# %% [markdown]
# ### Handle special case for the play shakespeare-comedy-7.txt

# %%
for line in lines_without_play_name[1]:
    if line.startswith("ANTIPHOLUS\t"):
        pprint(line)
        print("-"*25)
# Out:
# "ANTIPHOLUS\tDo you hear, you minion? you'll let us in, I hope?\nOF EPHESUS"
# -------------------------
# "ANTIPHOLUS\tWhat woman's man? and how besides thyself? besides thyself?"
# -------------------------
# 'ANTIPHOLUS\tThou art sensible in nothing but blows, and so is an\n\tass.'
# -------------------------
# 'ANTIPHOLUS\tI never saw you in my life till now.'
# -------------------------

# %%
lines_without_play_name[1] = [
    line for line in lines_without_play_name[1]
    if not line.startswith("ANTIPHOLUS\t")
]

# %% [markdown]
# ### Verify that the special case lines have been removed

# %%
for line in lines_without_play_name[1]:
    if line.startswith("ANTIPHOLUS\t"):
        pprint(line)
        print("-"*25)

# %% [markdown]
# # Logic to parse dialogues

# %%
character_dialogue_info_in_plays = {}

for play_idx, play_lines in enumerate(lines_without_play_name):
    character_dialogue_info_in_plays[play_idx] = {}
    char_name = None

    for line in play_lines:
        if line[0].isalpha():
            tab_pos = line.find('\t')
            char_name = " ".join(line[:tab_pos].split())
            char_words = line[tab_pos+1:].rstrip()
            
            # TODO: Use collections.defaultdict
            if char_name not in character_dialogue_info_in_plays[play_idx]:
                character_dialogue_info_in_plays[play_idx][char_name] = []
                character_dialogue_info_in_plays[play_idx][char_name].append(char_words)
            else:
                character_dialogue_info_in_plays[play_idx][char_name].append(char_words)
            
        else:
            # Printing separate chunks of dialogue with character names
            # to verify that we are these chunks with the correct
            # character
            print(char_name, "=>")
            pprint(line)
            character_dialogue_info_in_plays[play_idx][char_name].append(line.strip())
# Out:
# PHILO =>
# ('\t\t  Look, where they come:\n'
#  '\tTake but good note, and you shall see in him.\n'
#  "\tThe triple pillar of the world transform'd\n"
#  "\tInto a strumpet's fool: behold and see.")
# MARK ANTONY =>
# ("\tAnd such a twain can do't, in which I bind,\n"
#  '\tOn pain of punishment, the world to weet\n'
#  '\tWe stand up peerless.')
# MARK ANTONY =>
# '\t\t    What are you?'
# MARK ANTONY =>
# ("\tThere's a great spirit gone! Thus did I desire it:\n"
#  '\tWhat our contempt doth often hurl from us,\n'
#  '\tWe wish it ours again; the present pleasure,\n'
#  '\tBy revolution lowering, does become\n'
#  "\tThe opposite of itself: she's good, being gone;\n"
#  '\tThe hand could pluck her back that shoved her on.\n'
#  '\tI must from this enchanting queen break off:\n'
#  '\tTen thousand harms, more than the ills I know,\n'
#  '\tMy idleness doth hatch. How now! Enobarbus!')
# POMPEY =>
# '\t\t       How now, Varrius!'
# MARK ANTONY =>
# ('\tHe shall to Parthia. Be it art or hap,\n'
#  '\tHe hath spoken true: the very dice obey him;\n'
#  '\tAnd in our sports my better cunning faints\n'
#  '\tUnder his chance: if we draw lots, he speeds;\n'
#  '\tHis cocks do win the battle still of mine,\n'
#  '\tWhen it is all to nought; and his quails ever\n'
#  "\tBeat mine, inhoop'd, at odds. I will to Egypt:\n"
#  '\tAnd though I make this marriage for my peace,\n'
#  "\tI' the east my pleasure lies.")
# MARK ANTONY =>
# ('\t\t        O, come, Ventidius,\n'
#  "\tYou must to Parthia: your commission's ready;\n"
#  "\tFollow me, and receive't.")
# CLEOPATRA =>
# ('\t\t      O, from Italy\n'
#  '\tRam thou thy fruitful tidings in mine ears,\n'
#  '\tThat long time have been barren.')
# CLEOPATRA =>
# ("\tHorrible villain! or I'll spurn thine eyes\n"
#  "\tLike balls before me; I'll unhair thy head:")
# CLEOPATRA =>
# ("\tThou shalt be whipp'd with wire, and stew'd in brine,\n"
#  '\tSmarting in lingering pickle.')
# CLEOPATRA =>
# ('\tThese hands do lack nobility, that they strike\n'
#  '\tA meaner than myself; since I myself\n'
#  '\tHave given myself the cause.')
# CLEOPATRA =>
# ('\t\t       Come hither, sir.\n'
#  '\tThough it be honest, it is never good\n'
#  '\tTo bring bad news: give to a gracious message.\n'
#  '\tAn host of tongues; but let ill tidings tell\n'
#  '\tThemselves when they be felt.')
# CLEOPATRA =>
# ('\tLet him for ever go:--let him not--Charmian,\n'
#  '\tThough he be painted one way like a Gorgon,\n'
#  "\tThe other way's a Mars. Bid you Alexas")
# CLEOPATRA =>
# ('\tBring me word how tall she is. Pity me, Charmian,\n'
#  '\tBut do not speak to me. Lead me to my chamber.')
# DOMITIUS ENOBARBUS =>
# '\tShall we dance now the Egyptian Bacchanals,\n\tAnd celebrate our drink?'
# DOMITIUS ENOBARBUS =>
# ('\tCome, thou monarch of the vine,\n'
#  '\tPlumpy Bacchus with pink eyne!\n'
#  "\tIn thy fats our cares be drown'd,\n"
#  "\tWith thy grapes our hairs be crown'd:\n"
#  '\tCup us, till the world go round,\n'
#  '\tCup us, till the world go round!')
# DOMITIUS ENOBARBUS =>
# "\tMenas, I'll not on shore."
# DOMITIUS ENOBARBUS =>
# '\t\n\t\t\tSo;\n\tThis is to horse. Adieu, noble Agrippa.'
# CLEOPATRA =>
# '\tCome hither, sir.'
# MARK ANTONY =>
# '\t\t    Thy business?'
# MARK ANTONY =>
# '\tHow now, worthy soldier?'
# OCTAVIUS CAESAR =>
# ("\t  To try eloquence, now 'tis time: dispatch;\n"
#  '\tFrom Antony win Cleopatra: promise,\n'
#  '\tAnd in our name, what she requires; add more,\n'
#  '\tFrom thine invention, offers: women are not\n'
#  '\tIn their best fortunes strong; but want will perjure\n'
#  "\tThe ne'er touch'd vestal: try thy cunning, Thyreus;\n"
#  '\tMake thine own edict for thy pains, which we\n'
#  '\tWill answer as a law.')
# MARK ANTONY =>
# '\tTake hence this Jack, and whip him.'
# MARK ANTONY =>
# ('\tYou were half blasted ere I knew you: ha!\n'
#  "\tHave I my pillow left unpress'd in Rome,\n"
#  '\tForborne the getting of a lawful race,\n'
#  '\tAnd by a gem of women, to be abused\n'
#  '\tBy one that looks on feeders?')
# MARK ANTONY =>
# "\t\t    Is he whipp'd?"
# MARK ANTONY =>
# ('\t\t    Give me thy hand,\n'
#  '\tThou hast been rightly honest;--so hast thou;--\n'
#  '\tThou,--and thou,--and thou:--you have served me well,\n'
#  '\tAnd kings have been your fellows.')
# MARK ANTONY =>
# ('\tCome good fellow, put mine iron on:\n'
#  '\tIf fortune be not ours to-day, it is\n'
#  '\tBecause we brave her: come.')
# MARK ANTONY =>
# ('\tGood morrow to thee; welcome:\n'
#  "\tThou look'st like him that knows a warlike charge:\n"
#  '\tTo business that we love we rise betime,\n'
#  "\tAnd go to't with delight.")
# MARK ANTONY =>
# ('\tAnd worthy shameful cheque it were, to stand\n'
#  "\tOn more mechanic compliment; I'll leave thee\n"
#  '\tNow, like a man of steel. You that will fight,\n'
#  "\tFollow me close; I'll bring you to't. Adieu.")
# MARK ANTONY =>
# '\t\t    Give me thy hand'
# MARK ANTONY =>
# "\tTo this great fairy I'll commend thy acts,\n\tMake her thanks bless thee."
# MARK ANTONY =>
# ("\t\t      O thou day o' the world,\n"
#  "\tChain mine arm'd neck; leap thou, attire and all,\n"
#  '\tThrough proof of harness to my heart, and there\n'
#  '\tRide on the pants triumphing!')
# First Soldier =>
# ('\t\t                  Hark! the drums\n'
#  '\tDemurely wake the sleepers. Let us bear him\n'
#  '\tTo the court of guard; he is of note: our hour\n'
#  '\tIs fully out.')
# MARK ANTONY =>
# ('\tO sun, thy uprise shall I see no more:\n'
#  '\tFortune and Antony part here; even here\n'
#  '\tDo we shake hands. All come to this? The hearts\n'
#  "\tThat spaniel'd me at heels, to whom I gave\n"
#  '\tTheir wishes, do discandy, melt their sweets\n'
#  "\tOn blossoming Caesar; and this pine is bark'd,\n"
#  "\tThat overtopp'd them all. Betray'd I am:\n"
#  '\tO this false soul of Egypt! this grave charm,--\n'
#  "\tWhose eye beck'd forth my wars, and call'd them home;\n"
#  '\tWhose bosom was my crownet, my chief end,--\n'
#  '\tLike a right gipsy, hath, at fast and loose,\n'
#  '\tBeguiled me to the very heart of loss.\n'
#  '\tWhat, Eros, Eros!')
# MARK ANTONY =>
# '\tAh, thou spell! Avaunt!'
# MARK ANTONY =>
# ("\t\t'Tis well thou'rt gone,\n"
#  "\tIf it be well to live; but better 'twere\n"
#  "\tThou fell'st into my fury, for one death\n"
#  '\tMight have prevented many. Eros, ho!\n'
#  '\tThe shirt of Nessus is upon me: teach me,\n'
#  '\tAlcides, thou mine ancestor, thy rage:\n'
#  "\tLet me lodge Lichas on the horns o' the moon;\n"
#  "\tAnd with those hands, that grasp'd the heaviest club,\n"
#  '\tSubdue my worthiest self. The witch shall die:\n'
#  '\tTo the young Roman boy she hath sold me, and I fall\n'
#  "\tUnder this plot; she dies for't. Eros, ho!")
# MARK ANTONY =>
# "\t\t      O! thy vile lady!\n\tShe has robb'd me of my sword."
# MARK ANTONY =>
# "\tThat thou depart'st hence safe,\n\tDoes pay thy labour richly; go."
# MARK ANTONY =>
# ('\t\t         Off, pluck off:\n'
#  '\tThe seven-fold shield of Ajax cannot keep\n'
#  '\tThe battery from my heart. O, cleave, my sides!\n'
#  '\tHeart, once be stronger than thy continent,\n'
#  '\tCrack thy frail case! Apace, Eros, apace.\n'
#  '\tNo more a soldier: bruised pieces, go;\n'
#  '\tYou have been nobly borne. From me awhile.')
# MARK ANTONY =>
# ("\tI will o'ertake thee, Cleopatra, and\n"
#  '\tWeep for my pardon. So it must be, for now\n'
#  '\tAll length is torture: since the torch is out,\n'
#  '\tLie down, and stray no farther: now all labour\n'
#  '\tMars what it does; yea, very force entangles\n'
#  '\tItself with strength: seal then, and all is done.\n'
#  '\tEros!--I come, my queen:--Eros!--Stay for me:\n'
#  "\tWhere souls do couch on flowers, we'll hand in hand,\n"
#  '\tAnd with our sprightly port make the ghosts gaze:\n'
#  '\tDido and her AEneas shall want troops,\n'
#  '\tAnd all the haunt be ours. Come, Eros, Eros!')
# MARK ANTONY =>
# ("\tI learn'd of thee. How! not dead? not dead?\n"
#  '\tThe guard, ho! O, dispatch me!')
# CLEOPATRA =>
# '\t\t  How now! is he dead?'
# CLEOPATRA =>
# ('\tAnd welcome, welcome! die where thou hast lived:\n'
#  '\tQuicken with kissing: had my lips that power,\n'
#  '\tThus would I wear them out.')
# CLEOPATRA =>
# ("\tThe crown o' the earth doth melt. My lord!\n"
#  "\tO, wither'd is the garland of the war,\n"
#  "\tThe soldier's pole is fall'n: young boys and girls\n"
#  '\tAre level now with men; the odds is gone,\n'
#  '\tAnd there is nothing left remarkable\n'
#  '\tBeneath the visiting moon.')
# OCTAVIUS CAESAR =>
# ('\tThe business of this man looks out of him;\n'
#  "\tWe'll hear him what he says. Whence are you?")
# OCTAVIUS CAESAR =>
# "\t\tWhere's Dolabella,\n\tTo second Proculeius?"
# GALLUS =>
# '\tGuard her till Caesar come.'
# PROCULEIUS =>
# "\tDo not yourself such wrong, who are in this\n\tRelieved, but not betray'd."
# PROCULEIUS =>
# "\tTo Caesar I will speak what you shall please,\n\tIf you'll employ me to him."
# CLEOPATRA =>
# ('\t\t   Prithee, go hence;\n'
#  '\tOr I shall show the cinders of my spirits\n'
#  '\tThrough the ashes of my chance: wert thou a man,\n'
#  '\tThou wouldst have mercy on me.')
# CLEOPATRA =>
# ("\t\tNow, Iras, what think'st thou?\n"
#  '\tThou, an Egyptian puppet, shalt be shown\n'
#  '\tIn Rome, as well as I\tmechanic slaves\n'
#  '\tWith greasy aprons, rules, and hammers, shall\n'
#  '\tUplift us to the view; in their thick breaths,\n'
#  '\tRank of gross diet, shall be enclouded,\n'
#  '\tAnd forced to drink their vapour.')
# CLEOPATRA =>
# ('\t\t     Now, Charmian!\n'
#  '\tShow me, my women, like a queen: go fetch\n'
#  '\tMy best attires: I am again for Cydnus,\n'
#  '\tTo meet Mark Antony: sirrah Iras, go.\n'
#  "\tNow, noble Charmian, we'll dispatch indeed;\n"
#  "\tAnd, when thou hast done this chare, I'll give thee leave\n"
#  '\tTo play till doomsday. Bring our crown and all.\n'
#  "\tWherefore's this noise?")
# CLEOPATRA =>
# ('\tWhat poor an instrument\n'
#  '\tMay do a noble deed! he brings me liberty.\n'
#  "\tMy resolution's placed, and I have nothing\n"
#  '\tOf woman in me: now from head to foot\n'
#  '\tI am marble-constant; now the fleeting moon\n'
#  '\tNo planet is of mine.')
# CLEOPATRA =>
# '\tHast thou the pretty worm of Nilus there,\n\tThat kills and pains not?'
# CLEOPATRA =>
# ('\tHave I the aspic in my lips? Dost fall?\n'
#  '\tIf thou and nature can so gently part,\n'
#  "\tThe stroke of death is as a lover's pinch,\n"
#  '\tWhich hurts, and is desired. Dost thou lie still?\n'
#  "\tIf thus thou vanishest, thou tell'st the world\n"
#  '\tIt is not worth leave-taking.')
# CLEOPATRA =>
# ('\tWith thy sharp teeth this knot intrinsicate\n'
#  '\tOf life at once untie: poor venomous fool\n'
#  '\tBe angry, and dispatch. O, couldst thou speak,\n'
#  '\tThat I might hear thee call great Caesar ass\n'
#  '\tUnpolicied!')
# CLEOPATRA =>
# '\tWhat should I stay--'
# CHARMIAN =>
# '\tO, come apace, dispatch! I partly feel thee.'
# ANTIPHOLUS OF SYRACUSE =>
# ('\tHere comes the almanac of my true date.\n'
#  "\tWhat now? how chance thou art return'd so soon?")
# ANTIPHOLUS OF SYRACUSE =>
# ("\tHow now sir! is your merry humour alter'd?\n"
#  '\tAs you love strokes, so jest with me again.\n'
#  '\tYou know no Centaur? you received no gold?\n'
#  '\tYour mistress sent to have me home to dinner?\n'
#  '\tMy house was at the Phoenix? Wast thou mad,\n'
#  '\tThat thus so madly thou didst answer me?')
# ANTIPHOLUS OF EPHESUS =>
# ('\t\t    Get you home\n'
#  "\tAnd fetch the chain; by this I know 'tis made:\n"
#  '\tBring it, I pray you, to the Porpentine;\n'
#  "\tFor there's the house: that chain will I bestow--\n"
#  '\tBe it for nothing but to spite my wife--\n'
#  '\tUpon mine hostess there: good sir, make haste.\n'
#  '\tSince mine own doors refuse to entertain me,\n'
#  "\tI'll knock elsewhere, to see if they'll disdain me.")
# ADRIANA =>
# ('\t\tThis I wonder at,\n'
#  '\tThat he, unknown to me, should be in debt.\n'
#  '\tTell me, was he arrested on a band?')
# ANTIPHOLUS OF EPHESUS =>
# ('\tHere comes my man; I think he brings the money.\n'
#  '\tHow now, sir! have you that I sent you for?')
# ADRIANA =>
# '\tSay now, whose suit is he arrested at?'
# Servant =>
# '\tHark, hark! I hear him, mistress. fly, be gone!'
# ANTIPHOLUS OF SYRACUSE =>
# ('\t\tWhat I told you then,\n'
#  '\tI hope I shall have leisure to make good;\n'
#  '\tIf this be not a dream I see and hear.')
# OLIVER =>
# "\t'Twill be a good way; and to-morrow the wrestling is."
# OLIVER =>
# ('\tNow will I stir this gamester: I hope I shall see\n'
#  '\tan end of him; for my soul, yet I know not why,\n'
#  "\thates nothing more than he. Yet he's gentle, never\n"
#  '\tschooled and yet learned, full of noble device, of\n'
#  '\tall sorts enchantingly beloved, and indeed so much\n'
#  '\tin the heart of the world, and especially of my own\n'
#  '\tpeople, who best know him, that I am altogether\n'
#  '\tmisprised: but it shall not be so long; this\n'
#  '\twrestler shall clear all: nothing remains but that\n'
#  "\tI kindle the boy thither; which now I'll go about.")
# CELIA =>
# "\tBon jour, Monsieur Le Beau: what's the news?"
# ROSALIND =>
# ('\tWear this for me, one out of suits with fortune,\n'
#  '\tThat could give more, but that her hand lacks means.\n'
#  '\tShall we go, coz?')
# ORLANDO =>
# ('\tThus must I from the smoke into the smother;\n'
#  '\tFrom tyrant duke unto a tyrant brother:\n'
#  '\tBut heavenly Rosalind!')
# ROSALIND =>
# '\tLook you, who comes here; a young man and an old in\n\tsolemn talk.'
# CORIN =>
# ('\t\n'
#  '\t\n'
#  '\tSONG.\n'
#  'AMIENS\tUnder the greenwood tree\n'
#  '\tWho loves to lie with me,\n'
#  '\tAnd turn his merry note\n'
#  "\tUnto the sweet bird's throat,\n"
#  '\tCome hither, come hither, come hither:\n'
#  '\tHere shall he see No enemy\n'
#  '\tBut winter and rough weather.')
# JAQUES =>
# ("\tAnd loves to live i' the sun,\n"
#  '\tSeeking the food he eats\n'
#  '\tAnd pleased with what he gets,\n'
#  '\tCome hither, come hither, come hither:\n'
#  '\tHere shall he see No enemy\n'
#  '\tBut winter and rough weather.')
# JAQUES =>
# ('\tIf it do come to pass\n'
#  '\tThat any man turn ass,\n'
#  '\tLeaving his wealth and ease,\n'
#  '\tA stubborn will to please,\n'
#  '\tDucdame, ducdame, ducdame:\n'
#  '\tHere shall he see\n'
#  '\tGross fools as he,\n'
#  '\tAn if he will come to me.')
# CELIA =>
# ('\tWhy should this a desert be?\n'
#  '\tFor it is unpeopled? No:\n'
#  "\tTongues I'll hang on every tree,\n"
#  '\tThat shall civil sayings show:\n'
#  '\tSome, how brief the life of man\n'
#  '\tRuns his erring pilgrimage,\n'
#  '\tThat the stretching of a span\n'
#  '\tBuckles in his sum of age;\n'
#  '\tSome, of violated vows\n'
#  "\t'Twixt the souls of friend and friend:\n"
#  '\tBut upon the fairest boughs,\n'
#  '\tOr at every sentence end,\n'
#  '\tWill I Rosalinda write,\n'
#  '\tTeaching all that read to know\n'
#  '\tThe quintessence of every sprite\n'
#  '\tHeaven would in little show.\n'
#  '\tTherefore Heaven Nature charged\n'
#  "\tThat one body should be fill'd\n"
#  '\tWith all graces wide-enlarged:\n'
#  "\tNature presently distill'd\n"
#  "\tHelen's cheek, but not her heart,\n"
#  "\tCleopatra's majesty,\n"
#  "\tAtalanta's better part,\n"
#  "\tSad Lucretia's modesty.\n"
#  '\tThus Rosalind of many parts\n'
#  '\tBy heavenly synod was devised,\n'
#  '\tOf many faces, eyes and hearts,\n'
#  '\tTo have the touches dearest prized.\n'
#  '\tHeaven would that she these gifts should have,\n'
#  '\tAnd I to live and die her slave.')
# TOUCHSTONE =>
# ('\tSir Oliver Martext, you are well met: will you\n'
#  '\tdispatch us here under this tree, or shall we go\n'
#  '\twith you to your chapel?')
# JAQUES =>
# "\tProceed, proceed\tI'll give her."
# JAQUES =>
# ('\tTake thou no scorn to wear the horn;\n'
#  '\tIt was a crest ere thou wast born:\n'
#  "\tThy father's father wore it,\n"
#  '\tAnd thy father bore it:\n'
#  '\tThe horn, the horn, the lusty horn\n'
#  '\tIs not a thing to laugh to scorn.')
# ROSALIND =>
# ("\tArt thou god to shepherd turn'd,\n"
#  "\tThat a maiden's heart hath burn'd?\n"
#  '\tCan a woman rail thus?')
# ROSALIND =>
# ('\tWhy, thy godhead laid apart,\n'
#  "\tWarr'st thou with a woman's heart?\n"
#  '\tDid you ever hear such railing?\n'
#  '\tWhiles the eye of man did woo me,\n'
#  '\tThat could do no vengeance to me.\n'
#  '\tMeaning me a beast.\n'
#  '\tIf the scorn of your bright eyne\n'
#  '\tHave power to raise such love in mine,\n'
#  '\tAlack, in me what strange effect\n'
#  '\tWould they work in mild aspect!\n'
#  '\tWhiles you chid me, I did love;\n'
#  '\tHow then might your prayers move!\n'
#  '\tHe that brings this love to thee\n'
#  '\tLittle knows this love in me:\n'
#  '\tAnd by him seal up thy mind;\n'
#  '\tWhether that thy youth and kind\n'
#  '\tWill the faithful offer take\n'
#  '\tOf me and all that I can make;\n'
#  '\tOr else by him my love deny,\n'
#  "\tAnd then I'll study how to die.")
# ROSALIND =>
# '\tLook, here comes a lover of mine and a lover of hers.'
# ROSALIND =>
# '\tI will help you, if I can:'
# ROSALIND =>
# '\tI would love you, if I could. To-morrow meet me all together.'
# ROSALIND =>
# "\tI will marry you, if ever I marry woman, and I'll be\n\tmarried to-morrow:"
# ROSALIND =>
# ('\tI will satisfy you, if ever I satisfied man, and you\n'
#  '\tshall be married to-morrow:')
# ROSALIND =>
# ('\tI will content you, if what pleases you contents\n'
#  '\tyou, and you shall be married to-morrow.')
# ROSALIND =>
# '\tAs you love Rosalind, meet:'
# ROSALIND =>
# ('\tas you love Phebe, meet: and as I love no woman,\n'
#  "\tI'll meet. So fare you well: I have left you commands.")
# Second Page =>
# ('\tBetween the acres of the rye,\n'
#  '\tWith a hey, and a ho, and a hey nonino\n'
#  '\tThese pretty country folks would lie,\n'
#  '\tIn spring time, &c.')
# Second Page =>
# ('\tThis carol they began that hour,\n'
#  '\tWith a hey, and a ho, and a hey nonino,\n'
#  '\tHow that a life was but a flower\n'
#  '\tIn spring time, &c.')
# Second Page =>
# ('\tAnd therefore take the present time,\n'
#  '\tWith a hey, and a ho, and a hey nonino;\n'
#  '\tFor love is crowned with the prime\n'
#  '\tIn spring time, &c.')
# ROSALIND =>
# '\tTo you I give myself, for I am yours.'
# JAQUES =>
# ('\tYou to your former honour I bequeath;\n'
#  '\tYour patience and your virtue well deserves it:')
# JAQUES =>
# '\tYou to a love that your true faith doth merit:'
# JAQUES =>
# '\tYou to your land and love and great allies:'
# JAQUES =>
# '\tYou to a long and well-deserved bed:'
# JAQUES =>
# ('\tAnd you to wrangling; for thy loving voyage\n'
#  "\tIs but for two months victuall'd. So, to your pleasures:\n"
#  '\tI am for other than for dancing measures.')
# First Citizen =>
# ("\tWhat shouts are these? The other side o' the city\n"
#  '\tis risen: why stay we prating here? to the Capitol!')
# MENENIUS =>
# '\t\t       Hail, noble Marcius!'
# TITUS =>
# '\t  Follow Cominius; we must follow you;\n\tRight worthy you priority.'
# AUFIDIUS =>
# ("\t'They have press'd a power, but it is not known\n"
#  '\tWhether for east or west: the dearth is great;\n'
#  "\tThe people mutinous; and it is rumour'd,\n"
#  '\tCominius, Marcius your old enemy,\n'
#  '\tWho is of Rome worse hated than of you,\n'
#  '\tAnd Titus Lartius, a most valiant Roman,\n'
#  '\tThese three lead on this preparation\n'
#  "\tWhither 'tis bent: most likely 'tis for you:\n"
#  "\tConsider of it.'")
# MARCIUS =>
# '\tTutus Aufidius, is he within your walls?'
# First Senator =>
# ('\t\t       Hark! our drums\n'
#  "\tAre bringing forth our youth. We'll break our walls,\n"
#  '\tRather than they shall pound us up: our gates,\n'
#  "\tWhich yet seem shut, we, have but pinn'd with rushes;\n"
#  "\tThey'll open of themselves.")
# First Senator =>
# ('\t\t      Hark you. far off!\n'
#  '\tThere is Aufidius; list, what work he makes\n'
#  '\tAmongst your cloven army.')
# MARCIUS =>
# ('\tSo, now the gates are ope: now prove good seconds:\n'
#  "\t'Tis for the followers fortune widens them,\n"
#  '\tNot for the fliers: mark me, and do the like.')
# LARTIUS =>
# ('\tGo, sound thy trumpet in the market-place;\n'
#  "\tCall thither all the officers o' the town,\n"
#  '\tWhere they shall know our mind: away!')
# COMINIUS =>
# '\t\t                  Thy news?'
# MARCIUS =>
# ('\tO, me alone! make you a sword of me?\n'
#  '\tIf these shows be not outward, which of you\n'
#  '\tBut is four Volsces? none of you but is\n'
#  '\tAble to bear against the great Aufidius\n'
#  '\tA shield as hard as his. A certain number,\n'
#  '\tThough thanks to all, must I select\n'
#  '\tfrom all: the rest\n'
#  '\tShall bear the business in some other fight,\n'
#  "\tAs cause will be obey'd. Please you to march;\n"
#  '\tAnd four shall quickly draw out my command,\n'
#  '\tWhich men are best inclined.')
# AUFIDIUS =>
# '\tOfficious, and not valiant, you have shamed me\n\tIn your condemned seconds.'
# First Soldier =>
# '\t[Enter MENENIUS with the two Tribunes of the people,\n\tSICINIUS and BRUTUS.'
# MENENIUS =>
# ('\tHow now, my as fair as noble ladies,--and the moon,\n'
#  '\twere she earthly, no nobler,--whither do you follow\n'
#  '\tyour eyes so fast?')
# MENENIUS =>
# ('\tGod save your good worships! Marcius is coming\n'
#  '\thome: he has more cause to be proud. Where is he wounded?')
# MENENIUS =>
# '\tHark! the trumpets.'
# CORIOLANUS =>
# '\t\n\tO my sweet lady, pardon.'
# First Senator =>
# ("\t\t     Masters o' the people,\n"
#  '\tWe do request your kindest ears, and after,\n'
#  '\tYour loving motion toward the common body,\n'
#  '\tTo yield what passes here.')
# MENENIUS =>
# '\t\t  Nay, keep your place.'
# Third Citizen =>
# ('\tHere he comes, and in the gown of humility: mark his\n'
#  '\tbehavior. We are not to stay all together, but to\n'
#  '\tcome by him where he stands, by ones, by twos, and\n'
#  "\tby threes. He's to make his requests by\n"
#  '\tparticulars; wherein every one of us has a single\n'
#  '\thonour, in giving him our own voices with our own\n'
#  '\ttongues: therefore follow me, and I direct you how\n'
#  '\tyou shall go by him.')
# CORIOLANUS =>
# '\t\t      So, here comes a brace.'
# CORIOLANUS =>
# '\tYou know the cause, air, of my standing here.'
# CORIOLANUS =>
# ('\tHere come more voices.\n'
#  '\tYour voices: for your voices I have fought;\n'
#  "\tWatch'd for your voices; for Your voices bear\n"
#  '\tOf wounds two dozen odd; battles thrice six\n'
#  '\tI have seen and heard of; for your voices have\n'
#  '\tDone many things, some less, some more your voices:\n'
#  '\tIndeed I would be consul.')
# SICINIUS =>
# "\tHe has it now, and by his looks methink\n\t'Tis warm at 's heart."
# CORIOLANUS =>
# ('\tBehold, these are the tribunes of the people,\n'
#  "\tThe tongues o' the common mouth: I do despise them;\n"
#  '\tFor they do prank them in authority,\n'
#  '\tAgainst all noble sufferance.')
# BRUTUS =>
# '\tLet him be apprehended.'
# SICINIUS =>
# ('\t\tin whose name myself\n'
#  '\tAttach thee as a traitorous innovator,\n'
#  '\tA foe to the public weal: obey, I charge thee,\n'
#  '\tAnd follow to thine answer.')
# Senators, &C =>
# ("\t'Tribunes!' 'Patricians!' 'Citizens!' 'What, ho!'\n"
#  "\t'Sicinius!' 'Brutus!' 'Coriolanus!' 'Citizens!'\n"
#  "\t'Peace, peace, peace!' 'Stay, hold, peace!'")
# CORIOLANUS =>
# ("\tThere's some among you have beheld me fighting:\n"
#  '\tCome, try upon yourselves what you have seen me.')
# MENENIUS =>
# "\t\t      Here's goodly work!"
# MENENIUS =>
# '\tLet me desire your company: he must come,\n\tOr what is worst will follow.'
# CORIOLANUS =>
# ('\t\t    I talk of you:\n'
#  '\tWhy did you wish me milder? would you have me\n'
#  '\tFalse to my nature? Rather say I play\n'
#  '\tThe man I am.')
# BRUTUS =>
# '\tWhat, will he come?'
# BRUTUS =>
# ('\tPut him to choler straight: he hath been used\n'
#  '\tEver to conquer, and to have his worth\n'
#  '\tOf contradiction: being once chafed, he cannot\n'
#  "\tBe rein'd again to temperance; then he speaks\n"
#  "\tWhat's in his heart; and that is there which looks\n"
#  '\tWith us to break his neck.')
# BRUTUS =>
# '\tHere comes his mother.'
# VOLUMNIA =>
# '\t\t        Will you be gone?'
# VOLUMNIA =>
# ('\tI would the gods had nothing else to do\n'
#  "\tBut to confirm my curses! Could I meet 'em\n"
#  '\tBut once a-day, it would unclog my heart\n'
#  "\tOf what lies heavy to't.")
# CORIOLANUS =>
# '\t\t  Save you, sir.'
# CORIOLANUS =>
# ('\tO world, thy slippery turns! Friends now fast sworn,\n'
#  '\tWhose double bosoms seem to wear one heart,\n'
#  '\tWhose house, whose bed, whose meal, and exercise,\n'
#  "\tAre still together, who twin, as 'twere, in love\n"
#  '\tUnseparable, shall within this hour,\n'
#  '\tOn a dissension of a doit, break out\n'
#  '\tTo bitterest enmity: so, fellest foes,\n'
#  '\tWhose passions and whose plots have broke their sleep,\n'
#  '\tTo take the one the other, by some chance,\n'
#  '\tSome trick not worth an egg, shall grow dear friends\n'
#  '\tAnd interjoin their issues. So with me:\n'
#  "\tMy birth-place hate I, and my love's upon\n"
#  "\tThis enemy town. I'll enter: if he slay me,\n"
#  '\tHe does fair justice; if he give me way,\n'
#  "\tI'll do his country service.")
# CORIOLANUS =>
# ('\tNot yet thou knowest me, and, seeing me, dost not\n'
#  '\tThink me for the man I am, necessity\n'
#  '\tCommands me name myself.')
# BRUTUS =>
# '\t\t      Is this Menenius?'
# MENENIUS =>
# ('\tThe glorious gods sit in hourly synod about thy\n'
#  '\tparticular prosperity, and love thee no worse than\n'
#  '\tthy old father Menenius does! O my son, my son!\n'
#  "\tthou art preparing fire for us; look thee, here's\n"
#  '\twater to quench it. I was hardly moved to come to\n'
#  '\tthee; but being assured none but myself could move\n'
#  '\tthee, I have been blown out of your gates with\n'
#  '\tsighs; and conjure thee to pardon Rome, and thy\n'
#  '\tpetitionary countrymen. The good gods assuage thy\n'
#  '\twrath, and turn the dregs of it upon this varlet\n'
#  '\there,--this, who, like a block, hath denied my\n'
#  '\taccess to thee.')
# CORIOLANUS =>
# ('\tAnd would have rent it. Another word, Menenius,\n'
#  '\tI will not hear thee speak. This man, Aufidius,\n'
#  "\tWas my beloved in Rome: yet thou behold'st!")
# CORIOLANUS =>
# ('\tShall I be tempted to infringe my vow\n'
#  "\tIn the same time 'tis made? I will not.")
# CORIOLANUS =>
# ("\tMy wife comes foremost; then the honour'd mould\n"
#  '\tWherein this trunk was framed, and in her hand\n'
#  '\tThe grandchild to her blood. But, out, affection!\n'
#  '\tAll bond and privilege of nature, break!\n'
#  '\tLet it be virtuous to be obstinate.\n'
#  "\tWhat is that curt'sy worth? or those doves' eyes,\n"
#  '\tWhich can make gods forsworn? I melt, and am not\n'
#  '\tOf stronger earth than others. My mother bows;\n'
#  '\tAs if Olympus to a molehill should\n'
#  '\tIn supplication nod: and my young boy\n'
#  '\tHath an aspect of intercession, which\n'
#  "\tGreat nature cries 'Deny not.' let the Volsces\n"
#  "\tPlough Rome and harrow Italy: I'll never\n"
#  '\tBe such a gosling to obey instinct, but stand,\n'
#  '\tAs if a man were author of himself\n'
#  '\tAnd knew no other kin.')
# CORIOLANUS =>
# '\tOf thy deep duty more impression show\n\tThan that of common sons.'
# CORIOLANUS =>
# ('\tBut we will drink together; and you shall bear\n'
#  '\tA better witness back than words, which we,\n'
#  "\tOn like conditions, will have counter-seal'd.\n"
#  '\tCome, enter with us. Ladies, you deserve\n'
#  '\tTo have a temple built you: all the swords\n'
#  '\tIn Italy, and her confederate arms,\n'
#  '\tCould not have made this peace.')
# Second Messenger =>
# ('\tThe trumpets, sackbuts, psalteries and fifes,\n'
#  '\tTabours and cymbals and the shouting Romans,\n'
#  '\tMake the sun dance. Hark you!')
# AUFIDIUS =>
# '\tMost welcome!'
# HELENA =>
# ('\tOne that goes with him: I love him for his sake;\n'
#  '\tAnd yet I know him a notorious liar,\n'
#  '\tThink him a great way fool, solely a coward;\n'
#  '\tYet these fixed evils sit so fit in him,\n'
#  "\tThat they take place, when virtue's steely bones\n"
#  "\tLook bleak i' the cold wind: withal, full oft we see\n"
#  '\tCold wisdom waiting on superfluous folly.')
# COUNTESS =>
# ('\tEven so it was with me when I was young:\n'
#  "\tIf ever we are nature's, these are ours; this thorn\n"
#  '\tDoth to our rose of youth rightly belong;\n'
#  '\tOur blood to us, this to our blood is born;\n'
#  "\tIt is the show and seal of nature's truth,\n"
#  "\tWhere love's strong passion is impress'd in youth:\n"
#  '\tBy our remembrances of days foregone,\n'
#  '\tSuch were our faults, or then we thought them none.\n'
#  "\tHer eye is sick on't: I observe her now.")
# LAFEU =>
# ('\tand debile minister, great power, great\n'
#  '\ttranscendence: which should, indeed, give us a\n'
#  '\tfurther use to be made than alone the recovery of\n'
#  '\tthe king, as to be--')
# LAFEU =>
# '\tgenerally thankful.'
# KING =>
# ('\tFair maid, send forth thine eye: this youthful parcel\n'
#  '\tOf noble bachelors stand at my bestowing,\n'
#  "\tO'er whom both sovereign power and father's voice\n"
#  '\tI have to use: thy frank election make;\n'
#  '\tThou hast power to choose, and they none to forsake.')
# HELENA =>
# '\tCome, sirrah.'
# BERTRAM =>
# "\t'Twill be two days ere I shall see you, so\n\tI leave you to your wisdom."
# BERTRAM =>
# ('\tGo thou toward home; where I will never come\n'
#  '\tWhilst I can shake my sword or hear the drum.\n'
#  '\tAway, and for our flight.')
# PAROLLES =>
# ('\t[Flourish. Enter the DUKE of Florence attended;\n'
#  '\tthe two Frenchmen, with a troop of soldiers.')
# HELENA =>
# ('\tWhen thou canst get the ring upon my finger which\n'
#  '\tnever shall come off, and show me a child begotten\n'
#  '\tof thy body that I am father to, then call me\n'
#  "\thusband: but in such a 'then' I write a 'never.'\n"
#  '\tThis is a dreadful sentence.')
# Steward =>
# ("\tI am Saint Jaques' pilgrim, thither gone:\n"
#  '\tAmbitious love hath so in me offended,\n'
#  '\tThat barefoot plod I the cold ground upon,\n'
#  '\tWith sainted vow my faults to have amended.\n'
#  '\tWrite, write, that from the bloody course of war\n'
#  '\tMy dearest master, your dear son, may hie:\n'
#  '\tBless him at home in peace, whilst I from far\n'
#  '\tHis name with zealous fervor sanctify:\n'
#  '\tHis taken labours bid him me forgive;\n'
#  '\tI, his despiteful Juno, sent him forth\n'
#  '\tFrom courtly friends, with camping foes to live,\n'
#  '\tWhere death and danger dogs the heels of worth:\n'
#  '\tHe is too good and fair for death and me:\n'
#  '\tWhom I myself embrace, to set him free.')
# Widow =>
# ('\tWe have lost our labour; they are gone a contrary\n'
#  '\tway: hark! you may know by their trumpets.')
# Widow =>
# ('\tLook, here comes a pilgrim: I know she will lie at\n'
#  "\tmy house; thither they send one another: I'll\n"
#  '\tquestion her. God save you, pilgrim! whither are you bound?')
# Widow =>
# ('\tHark you! they come this way.\n'
#  '\tIf you will tarry, holy pilgrim,\n'
#  '\tBut till the troops come by,\n'
#  '\tI will conduct you where you shall be lodged;\n'
#  '\tThe rather, for I think I know your hostess\n'
#  '\tAs ample as myself.')
# Widow =>
# "\tThat is Antonio, the duke's eldest son;\n\tThat, Escalus."
# First Lord =>
# "\tHow now! where's your master?"
# First Lord =>
# "\tHow now, my lord! is't not after midnight?"
# First Soldier =>
# ("\t'You shall demand of him, whether one Captain Dumain\n"
#  "\tbe i' the camp, a Frenchman; what his reputation is\n"
#  '\twith the duke; what his valour, honesty, and\n'
#  '\texpertness in wars; or whether he thinks it were not\n'
#  '\tpossible, with well-weighing sums of gold, to\n'
#  "\tcorrupt him to revolt.' What say you to this? what\n"
#  '\tdo you know of it?')
# First Lord =>
# '\tSo, look about you: know you any here?'
# HELENA =>
# ("\tThis man may help me to his majesty's ear,\n"
#  '\tIf he would spend his power. God save you, sir.')
# Clown =>
# ("\tHere is a purr of fortune's, sir, or of fortune's\n"
#  '\tcat,--but not a musk-cat,--that has fallen into the\n'
#  '\tunclean fishpond of her displeasure, and, as he\n'
#  '\tsays, is muddied withal: pray you, sir, use the\n'
#  '\tcarp as you may; for he looks like a poor, decayed,\n'
#  '\tingenious, foolish, rascally knave. I do pity his\n'
#  '\tdistress in my similes of comfort and leave him to\n'
#  '\tyour lordship.')
# LAFEU =>
# ("\tThe king's coming; I know by his trumpets. Sirrah,\n"
#  '\tinquire further after me; I had talk of you last\n'
#  '\tnight: though you are a fool and a knave, you shall\n'
#  '\teat; go to, follow.')
# LAFEU =>
# ('\t\t     By my old beard,\n'
#  "\tAnd every hair that's on't, Helen, that's dead,\n"
#  '\tWas a sweet creature: such a ring as this,\n'
#  "\tThe last that e'er I took her at court,\n"
#  '\tI saw upon her finger.')
# KING =>
# ("\tMy fore-past proofs, howe'er the matter fall,\n"
#  '\tShall tax my fears of little vanity,\n'
#  "\tHaving vainly fear'd too little. Away with him!\n"
#  "\tWe'll sift this matter further.")
# KING =>
# "\t\t   What woman's that?"
# DIANA =>
# ('\tThe jeweller that owes the ring is sent for,\n'
#  '\tAnd he shall surety me. But for this lord,\n'
#  '\tWho hath abused me, as he knows himself,\n'
#  "\tThough yet he never harm'd me, here I quit him:\n"
#  '\tHe knows himself my bed he hath defiled;\n'
#  '\tAnd at that time he got his wife with child:\n'
#  '\tDead though she be, she feels her young one kick:\n'
#  "\tSo there's my riddle: one that's dead is quick:\n"
#  '\tAnd now behold the meaning.')
# LAFEU =>
# ('\tGood Tom Drum, lend me a handkercher: so,\n'
#  "\tI thank thee: wait on me home, I'll make sport with thee:\n"
#  '\tLet thy courtesies alone, they are scurvy ones.')
# KING =>
# ("\tIf thou be'st yet a fresh uncropped flower,\n"
#  "\tChoose thou thy husband, and I'll pay thy dower;\n"
#  '\tFor I can guess that by thy honest aid\n'
#  "\tThou keep'st a wife herself, thyself a maid.\n"
#  '\tOf that and all the progress, more or less,\n'
#  '\tResolvedly more leisure shall express:\n'
#  '\tAll yet seems well; and if it end so meet,\n'
#  '\tThe bitter past, more welcome is the sweet.')

# %% [markdown]
# ### Join list with chunks of dialogues in a single string for each character

# %%
character_cleaned_dialogue_info_in_plays = {}

for play_idx in character_dialogue_info_in_plays:
    character_cleaned_dialogue_info_in_plays[play_idx] = {}
    for character in character_dialogue_info_in_plays[play_idx]:
        character_cleaned_dialogue_info_in_plays[play_idx][character] = \
            " ".join(character_dialogue_info_in_plays[play_idx][character])

# %%
pprint(character_cleaned_dialogue_info_in_plays[0])
# Out:
# {'AGRIPPA': "Give me leave, Caesar,-- Thou hast a sister by the mother's "
#             'side,\n'
#             '\tAdmired Octavia: great Mark Antony\n'
#             '\tIs now a widower. To hold you in perpetual amity,\n'
#             '\tTo make you brothers, and to knit your hearts\n'
#             '\tWith an unslipping knot, take Antony\n'
#             '\tOctavia to his wife; whose beauty claims\n'
#             '\tNo worse a husband than the best of men;\n'
#             '\tWhose virtue and whose general graces speak\n'
#             '\tThat which none else can utter. By this marriage,\n'
#             '\tAll little jealousies, which now seem great,\n'
#             '\tAnd all great fears, which now import their dangers,\n'
#             '\tWould then be nothing: truths would be tales,\n'
#             '\tWhere now half tales be truths: her love to both\n'
#             '\tWould, each to other and all loves to both,\n'
#             '\tDraw after her. Pardon what I have spoke;\n'
#             "\tFor 'tis a studied, not a present thought,\n"
#             '\tBy duty ruminated. Good Enobarbus! There she appeared indeed; '
#             'or my reporter devised\n'
#             '\twell for her. O, rare for Antony! Rare Egyptian! Royal wench!\n'
#             '\tShe made great Caesar lay his sword to bed:\n'
#             "\tHe plough'd her, and she cropp'd. Let us go.\n"
#             '\tGood Enobarbus, make yourself my guest\n'
#             '\tWhilst you abide here. Sir, Mark Antony\n'
#             "\tWill e'en but kiss Octavia, and we'll follow. What, are the "
#             "brothers parted? 'Tis a noble Lepidus. Nay, but how dearly he "
#             "adores Mark Antony! What's Antony? The god of Jupiter. O Antony! "
#             'O thou Arabian bird! Indeed, he plied them both with excellent '
#             'praises. Both he loves. Good fortune, worthy soldier; and '
#             "farewell.   He has a cloud in 's face.   Why, Enobarbus,\n"
#             '\tWhen Antony found Julius Caesar dead,\n'
#             '\tHe cried almost to roaring; and he wept\n'
#             '\tWhen at Philippi he found Brutus slain. Who, queasy with his '
#             'insolence\n'
#             '\tAlready, will their good thoughts call from '
#             'him.                   Who does he accuse?                   Sir, '
#             "this should be answer'd. Welcome, lady. Caesar, I shall. Retire, "
#             'we have engaged ourselves too far:\n'
#             '\tCaesar himself has work, and our oppression\n'
#             '\tExceeds what we expected. And strange it is,\n'
#             '\tThat nature must compel us to lament\n'
#             '\tOur most persisted deeds. A rarer spirit never\n'
#             '\tDid steer humanity: but you, gods, will give us\n'
#             "\tSome faults to make us men. Caesar is touch'd.",
#  'ALEXAS': 'Soothsayer! Show him your hand. Vex not his prescience; be '
#            'attentive. Nay, hear him. You think none but your sheets are privy '
#            "to your wishes. We'll know all our fortunes. Lo, now, if it lay in "
#            'their hands to make me a\n'
#            '\tcuckold, they would make themselves whores, but\n'
#            "\tthey'ld do't! Here, at your service. My lord approaches. "
#            'Sovereign of Egypt, hail! Last thing he did, dear queen,\n'
#            "\tHe kiss'd,--the last of many doubled kisses,--\n"
#            "\tThis orient pearl. His speech sticks in my heart. 'Good friend,' "
#            'quoth he,\n'
#            "\t'Say, the firm Roman to great Egypt sends\n"
#            '\tThis treasure of an oyster; at whose foot,\n'
#            '\tTo mend the petty present, I will piece\n'
#            '\tHer opulent throne with kingdoms; all the east,\n'
#            "\tSay thou, shall call her mistress.' So he nodded,\n"
#            '\tAnd soberly did mount an arm-gaunt steed,\n'
#            "\tWho neigh'd so high, that what I would have spoke\n"
#            "\tWas beastly dumb'd by him. Like to the time o' the year between "
#            'the extremes\n'
#            '\tOf hot and cold, he was nor sad nor merry. Ay, madam, twenty '
#            'several messengers:\n'
#            '\tWhy do you send so thick? Half afeard to come. Good majesty,\n'
#            '\tHerod of Jewry dare not look upon you\n'
#            '\tBut when you are well pleased.',
#  'All': 'Fly! not we. The gods forbid!   How now!\n'
#         "\tHow now! do you hear this? Content. 'Tis strange. Good morrow, "
#         'general. Alas, and woe! Most heavy day! A heavy sight! Dolabella!',
#  'Attendant': 'News, my good lord, from Rome.                   A messenger '
#               'from CAESAR.',
#  'Attendants': 'The music, ho!',
#  'CANIDIUS': 'Why will my lord do so? Ay, and to wage this battle at '
#              'Pharsalia.\n'
#              '\tWhere Caesar fought with Pompey: but these offers,\n'
#              '\tWhich serve not for his vantage, be shakes off;\n'
#              '\tAnd so should you. Soldier, thou art: but his whole action '
#              'grows\n'
#              "\tNot in the power on't: so our leader's led,\n"
#              "\tAnd we are women's men. Marcus Octavius, Marcus Justeius,\n"
#              '\tPublicola, and Caelius, are for sea:\n'
#              "\tBut we keep whole by land. This speed of Caesar's\n"
#              "\tCarries beyond belief. Who's his lieutenant, hear you? Well I "
#              "know the man. With news the time's with labour, and throes "
#              'forth,\n'
#              '\tEach minute, some. Our fortune on the sea is out of breath,\n'
#              '\tAnd sinks most lamentably. Had our general\n'
#              '\tBeen what he knew himself, it had gone well:\n'
#              '\tO, he has given example for our flight,\n'
#              '\tMost grossly, by his own! Toward Peloponnesus are they fled. '
#              'To Caesar will I render\n'
#              '\tMy legions and my horse: six kings already\n'
#              '\tShow me the way of yielding.',
#  'CHARMIAN': 'Lord Alexas, sweet Alexas, most any thing Alexas,\n'
#              "\talmost most absolute Alexas, where's the soothsayer\n"
#              '\tthat you praised so to the queen? O, that I knew\n'
#              '\tthis husband, which, you say, must charge his horns\n'
#              "\twith garlands! Is this the man? Is't you, sir, that know "
#              'things? Good sir, give me good fortune. Pray, then, foresee me '
#              'one. He means in flesh. Wrinkles forbid! Hush! I had rather heat '
#              'my liver with drinking. Good now, some excellent fortune! Let me '
#              'be married\n'
#              '\tto three kings in a forenoon, and widow them all:\n'
#              '\tlet me have a child at fifty, to whom Herod of Jewry\n'
#              '\tmay do homage: find me to marry me with Octavius\n'
#              '\tCaesar, and companion me with my mistress. O excellent! I love '
#              'long life better than figs. Then belike my children shall have '
#              'no names:\n'
#              '\tprithee, how many boys and wenches must I have? Out, fool! I '
#              "forgive thee for a witch. Nay, come, tell Iras hers. E'en as the "
#              "o'erflowing Nilus presageth famine. Nay, if an oily palm be not "
#              'a fruitful\n'
#              '\tprognostication, I cannot scratch mine ear. Prithee,\n'
#              '\ttell her but a worky-day fortune. Well, if you were but an '
#              'inch of fortune better than\n'
#              '\tI, where would you choose it? Our worser thoughts heavens '
#              'mend! Alexas,--come,\n'
#              '\this fortune, his fortune! O, let him marry a woman\n'
#              '\tthat cannot go, sweet Isis, I beseech thee! and let\n'
#              '\ther die too, and give him a worse! and let worst\n'
#              '\tfollow worse, till the worst of all follow him\n'
#              '\tlaughing to his grave, fifty-fold a cuckold! Good\n'
#              '\tIsis, hear me this prayer, though thou deny me a\n'
#              '\tmatter of more weight; good Isis, I beseech thee! Amen. Not '
#              'he; the queen. No, madam.                   I did not see him '
#              'since. Madam, methinks, if you did love him dearly,\n'
#              '\tYou do not hold the method to enforce\n'
#              '\tThe like from him. In each thing give him way, cross him '
#              'nothing. Tempt him not so too far; I wish, forbear:\n'
#              '\tIn time we hate that which we often fear.\n'
#              '\tBut here comes Antony. Madam? Why, madam?                   '
#              'You think of him too much.                   Madam, I trust, not '
#              'so. O that brave Caesar! The valiant Caesar!                   '
#              'By your most gracious pardon,\n'
#              '\tI sing but after you. My arm is sore; best play with Mardian. '
#              "'Twas merry when\n"
#              "\tYou wager'd on your angling; when your diver\n"
#              '\tDid hang a salt-fish on his hook, which he\n'
#              '\tWith fervency drew up. Good madam, keep yourself within '
#              'yourself:\n'
#              '\tThe man is innocent. He is afeard to come. Good your highness, '
#              "patience. Many times, madam. Like her! O Isis! 'tis impossible. "
#              'Three in Egypt\n'
#              '\tCannot make better note. Excellent. A proper man. Nothing, '
#              'madam. Hath he seen majesty? Isis else defend,\n'
#              '\tAnd serving you so long! I warrant you, madam. Do! why: what '
#              'else? Madam! Please you, retire to your chamber. To the '
#              'monument!\n'
#              '\tThere lock yourself, and send him word you are dead.\n'
#              '\tThe soul and body rive not more in parting\n'
#              '\tThan greatness going off. Be comforted, dear madam. O, '
#              'quietness, lady! Lady! O madam, madam, madam! Peace, peace, '
#              'Iras! O Cleopatra! thou art taken, queen: Madam, I will. Behold, '
#              'sir. Dissolve, thick cloud, and rain; that I may say,\n'
#              '\tThe gods themselves do weep!           O eastern star! O, '
#              'break! O, break! In this vile world? So, fare thee well.\n'
#              '\tNow boast thee, death, in thy possession lies\n'
#              "\tA lass unparallel'd. Downy windows, close;\n"
#              '\tAnd golden Phoebus never be beheld\n'
#              "\tOf eyes again so royal! Your crown's awry;\n"
#              "\tI'll mend it, and then play. Speak softly, wake her "
#              'not.                   Too slow a messenger. O, come apace, '
#              'dispatch! I partly feel thee. It is well done, and fitting for a '
#              'princess\n'
#              '\tDescended of so many royal kings.\n'
#              '\tAh, soldier!',
#  'CLEOPATRA': "If it be love indeed, tell me how much. I'll set a bourn how "
#               'far to be beloved. Nay, hear them, Antony:\n'
#               '\tFulvia perchance is angry; or, who knows\n'
#               '\tIf the scarce-bearded Caesar have not sent\n'
#               "\tHis powerful mandate to you, 'Do this, or this;\n"
#               '\tTake in that kingdom, and enfranchise that;\n'
#               "\tPerform 't, or else we damn thee.' Perchance! nay, and most "
#               'like:\n'
#               '\tYou must not stay here longer, your dismission\n'
#               '\tIs come from Caesar; therefore hear it, Antony.\n'
#               "\tWhere's Fulvia's process? Caesar's I would say? both?\n"
#               "\tCall in the messengers. As I am Egypt's queen,\n"
#               '\tThou blushest, Antony; and that blood of thine\n'
#               "\tIs Caesar's homager: else so thy cheek pays shame\n"
#               '\tWhen shrill-tongued Fulvia scolds. The messengers! Excellent '
#               'falsehood!\n'
#               '\tWhy did he marry Fulvia, and not love her?\n'
#               "\tI'll seem the fool I am not; Antony\n"
#               '\tWill be himself. Hear the ambassadors. Saw you my lord? Was '
#               'he not here? He was disposed to mirth; but on the sudden\n'
#               '\tA Roman thought hath struck him. Enobarbus! Seek him, and '
#               'bring him hither.\n'
#               "\tWhere's Alexas? We will not look upon him: go with us. Where "
#               "is he? See where he is, who's with him, what he does:\n"
#               '\tI did not send you: if you find him sad,\n'
#               '\tSay I am dancing; if in mirth, report\n'
#               '\tThat I am sudden sick: quick, and return.                   '
#               'What should I do, I do not? Thou teachest like a fool; the way '
#               'to lose him. I am sick and sullen. Help me away, dear Charmian; '
#               'I shall fall:\n'
#               '\tIt cannot be thus long, the sides of nature\n'
#               '\tWill not sustain it. Pray you, stand further from me. I know, '
#               "by that same eye, there's some good news.\n"
#               '\tWhat says the married woman? You may go:\n'
#               '\tWould she had never given you leave to come!\n'
#               "\tLet her not say 'tis I that keep you here:\n"
#               '\tI have no power upon you; hers you are. O, never was there '
#               'queen\n'
#               "\tSo mightily betray'd! yet at the first\n"
#               '\tI saw the treasons planted. Why should I think you can be '
#               'mine and true,\n'
#               '\tThough you in swearing shake the throned gods,\n'
#               '\tWho have been false to Fulvia? Riotous madness,\n'
#               '\tTo be entangled with those mouth-made vows,\n'
#               '\tWhich break themselves in swearing! Nay, pray you, seek no '
#               'colour for your going,\n'
#               '\tBut bid farewell, and go: when you sued staying,\n'
#               '\tThen was the time for words: no going then;\n'
#               '\tEternity was in our lips and eyes,\n'
#               "\tBliss in our brows' bent; none our parts so poor,\n"
#               '\tBut was a race of heaven: they are so still,\n'
#               '\tOr thou, the greatest soldier of the world,\n'
#               "\tArt turn'd the greatest liar. I would I had thy inches; thou "
#               'shouldst know\n'
#               '\tThere were a heart in Egypt. Though age from folly could not '
#               'give me freedom,\n'
#               '\tIt does from childishness: can Fulvia die? O most false '
#               'love!\n'
#               '\tWhere be the sacred vials thou shouldst fill\n'
#               '\tWith sorrowful water? Now I see, I see,\n'
#               "\tIn Fulvia's death, how mine received shall "
#               'be.                   Cut my lace, Charmian, come;\n'
#               '\tBut let it be: I am quickly ill, and well,\n'
#               '\tSo Antony loves. So Fulvia told me.\n'
#               '\tI prithee, turn aside and weep for her,\n'
#               '\tThen bid adieu to me, and say the tears\n'
#               '\tBelong to Egypt: good now, play one scene\n'
#               '\tOf excellent dissembling; and let it look\n'
#               '\tLife perfect honour. You can do better yet; but this is '
#               'meetly. And target. Still he mends;\n'
#               '\tBut this is not the best. Look, prithee, Charmian,\n'
#               '\tHow this Herculean Roman does become\n'
#               '\tThe carriage of his chafe. Courteous lord, one word.\n'
#               "\tSir, you and I must part, but that's not it:\n"
#               "\tSir, you and I have loved, but there's not it;\n"
#               '\tThat you know well: something it is I would,\n'
#               '\tO, my oblivion is a very Antony,\n'
#               "\tAnd I am all forgotten. 'Tis sweating labour\n"
#               '\tTo bear such idleness so near the heart\n'
#               '\tAs Cleopatra this. But, sir, forgive me;\n'
#               '\tSince my becomings kill me, when they do not\n'
#               '\tEye well to you: your honour calls you hence;\n'
#               '\tTherefore be deaf to my unpitied folly.\n'
#               '\tAnd all the gods go with you! upon your sword\n'
#               '\tSit laurel victory! and smooth success\n'
#               "\tBe strew'd before your feet! Charmian! Ha, ha!\n"
#               '\tGive me to drink mandragora. That I might sleep out this '
#               'great gap of time\n'
#               "\tMy Antony is away. O, 'tis treason! Thou, eunuch Mardian! Not "
#               'now to hear thee sing; I take no pleasure\n'
#               "\tIn aught an eunuch has: 'tis well for thee,\n"
#               "\tThat, being unseminar'd, thy freer thoughts\n"
#               '\tMay not fly forth of Egypt. Hast thou affections? Indeed! O '
#               'Charmian,\n'
#               "\tWhere think'st thou he is now? Stands he, or sits he?\n"
#               '\tOr does he walk? or is he on his horse?\n'
#               '\tO happy horse, to bear the weight of Antony!\n'
#               "\tDo bravely, horse! for wot'st thou whom thou movest?\n"
#               '\tThe demi-Atlas of this earth, the arm\n'
#               "\tAnd burgonet of men. He's speaking now,\n"
#               "\tOr murmuring 'Where's my serpent of old Nile?'\n"
#               '\tFor so he calls me: now I feed myself\n'
#               '\tWith most delicious poison. Think on me,\n'
#               "\tThat am with Phoebus' amorous pinches black,\n"
#               '\tAnd wrinkled deep in time? Broad-fronted Caesar,\n'
#               '\tWhen thou wast here above the ground, I was\n'
#               '\tA morsel for a monarch: and great Pompey\n'
#               '\tWould stand and make his eyes grow in my brow;\n'
#               '\tThere would he anchor his aspect and die\n'
#               '\tWith looking on his life. How much unlike art thou Mark '
#               'Antony!\n'
#               '\tYet, coming from him, that great medicine hath\n'
#               '\tWith his tinct gilded thee.\n'
#               '\tHow goes it with my brave Mark Antony? Mine ear must pluck it '
#               'thence. What, was he sad or merry? O well-divided disposition! '
#               'Note him,\n'
#               "\tNote him good Charmian, 'tis the man; but note him:\n"
#               '\tHe was not sad, for he would shine on those\n'
#               '\tThat make their looks by his; he was not merry,\n'
#               "\tWhich seem'd to tell them his remembrance lay\n"
#               '\tIn Egypt with his joy; but between both:\n'
#               "\tO heavenly mingle! Be'st thou sad or merry,\n"
#               '\tThe violence of either thee becomes,\n'
#               "\tSo does it no man else. Met'st thou my posts? Who's born that "
#               'day\n'
#               '\tWhen I forget to send to Antony,\n'
#               '\tShall die a beggar. Ink and paper, Charmian.\n'
#               '\tWelcome, my good Alexas. Did I, Charmian,\n'
#               '\tEver love Caesar so? Be choked with such another emphasis!\n'
#               '\tSay, the brave Antony. By Isis, I will give thee bloody '
#               'teeth,\n'
#               '\tIf thou with Caesar paragon again\n'
#               '\tMy man of men. My salad days,\n'
#               '\tWhen I was green in judgment: cold in blood,\n'
#               '\tTo say as I said then! But, come, away;\n'
#               '\tGet me ink and paper:\n'
#               '\tHe shall have every day a several greeting,\n'
#               "\tOr I'll unpeople Egypt. Give me some music; music, moody "
#               'food\n'
#               "\tOf us that trade in love. Let it alone; let's to billiards: "
#               "come, Charmian. As well a woman with an eunuch play'd\n"
#               "\tAs with a woman. Come, you'll play with me, sir? And when "
#               "good will is show'd, though't come\n"
#               '\ttoo short,\n'
#               "\tThe actor may plead pardon. I'll none now:\n"
#               "\tGive me mine angle; we'll to the river: there,\n"
#               '\tMy music playing far off, I will betray\n'
#               "\tTawny-finn'd fishes; my bended hook shall pierce\n"
#               '\tTheir slimy jaws; and, as I draw them up,\n'
#               "\tI'll think them every one an Antony,\n"
#               "\tAnd say 'Ah, ha! you're caught.' That time,--O times!--\n"
#               "\tI laugh'd him out of patience; and that night\n"
#               "\tI laugh'd him into patience; and next morn,\n"
#               '\tEre the ninth hour, I drunk him to his bed;\n'
#               '\tThen put my tires and mantles on him, whilst\n'
#               '\tI wore his sword Philippan. O, from Italy\n'
#               '\tRam thou thy fruitful tidings in mine ears,\n'
#               '\tThat long time have been barren. Antonius dead!--If thou say '
#               'so, villain,\n'
#               "\tThou kill'st thy mistress: but well and free,\n"
#               '\tIf thou so yield him, there is gold, and here\n'
#               '\tMy bluest veins to kiss; a hand that kings\n'
#               "\tHave lipp'd, and trembled kissing. Why, there's more gold.\n"
#               '\tBut, sirrah, mark, we use\n'
#               '\tTo say the dead are well: bring it to that,\n'
#               '\tThe gold I give thee will I melt and pour\n'
#               '\tDown thy ill-uttering throat. Well, go to, I will;\n'
#               "\tBut there's no goodness in thy face: if Antony\n"
#               '\tBe free and healthful,--so tart a favour\n'
#               '\tTo trumpet such good tidings! If not well,\n'
#               "\tThou shouldst come like a Fury crown'd with snakes,\n"
#               '\tNot like a formal man. I have a mind to strike thee ere thou '
#               "speak'st:\n"
#               '\tYet if thou say Antony lives, is well,\n'
#               '\tOr friends with Caesar, or not captive to him,\n'
#               "\tI'll set thee in a shower of gold, and hail\n"
#               "\tRich pearls upon thee. Well said. Thou'rt an honest man. Make "
#               "thee a fortune from me. I do not like 'But yet,' it does allay\n"
#               "\tThe good precedence; fie upon 'But yet'!\n"
#               "\t'But yet' is as a gaoler to bring forth\n"
#               '\tSome monstrous malefactor. Prithee, friend,\n'
#               '\tPour out the pack of matter to mine ear,\n'
#               "\tThe good and bad together: he's friends with Caesar:\n"
#               "\tIn state of health thou say'st; and thou say'st free. For "
#               'what good turn? I am pale, Charmian. The most infectious '
#               'pestilence upon thee! What say you? Hence, Horrible villain! or '
#               "I'll spurn thine eyes\n"
#               "\tLike balls before me; I'll unhair thy head: Thou shalt be "
#               "whipp'd with wire, and stew'd in brine,\n"
#               "\tSmarting in lingering pickle. Say 'tis not so, a province I "
#               'will give thee,\n'
#               '\tAnd make thy fortunes proud: the blow thou hadst\n'
#               '\tShall make thy peace for moving me to rage;\n'
#               '\tAnd I will boot thee with what gift beside\n'
#               '\tThy modesty can beg. Rogue, thou hast lived too long. Some '
#               "innocents 'scape not the thunderbolt.\n"
#               '\tMelt Egypt into Nile! and kindly creatures\n'
#               '\tTurn all to serpents! Call the slave again:\n'
#               '\tThough I am mad, I will not bite him: call. I will not hurt '
#               'him. These hands do lack nobility, that they strike\n'
#               '\tA meaner than myself; since I myself\n'
#               '\tHave given myself the cause. Come hither, sir.\n'
#               '\tThough it be honest, it is never good\n'
#               '\tTo bring bad news: give to a gracious message.\n'
#               '\tAn host of tongues; but let ill tidings tell\n'
#               '\tThemselves when they be felt. Is he married?\n'
#               '\tI cannot hate thee worser than I do,\n'
#               "\tIf thou again say 'Yes.' The gods confound thee! dost thou "
#               'hold there still? O, I would thou didst,\n'
#               '\tSo half my Egypt were submerged and made\n'
#               '\tA cistern for scaled snakes! Go, get thee hence:\n'
#               '\tHadst thou Narcissus in thy face, to me\n'
#               '\tThou wouldst appear most ugly. He is married? He is married? '
#               'O, that his fault should make a knave of thee,\n'
#               "\tThat art not what thou'rt sure of! Get thee hence:\n"
#               '\tThe merchandise which thou hast brought from Rome\n'
#               '\tAre all too dear for me: lie they upon thy hand,\n'
#               "\tAnd be undone by 'em! In praising Antony, I have dispraised "
#               "Caesar.                   I am paid for't now.\n"
#               '\tLead me from hence:\n'
#               "\tI faint: O Iras, Charmian! 'tis no matter.\n"
#               '\tGo to the fellow, good Alexas; bid him\n'
#               '\tReport the feature of Octavia, her years,\n'
#               '\tHer inclination, let him not leave out\n'
#               '\tThe colour of her hair: bring me word quickly. Let him for '
#               'ever go:--let him not--Charmian,\n'
#               '\tThough he be painted one way like a Gorgon,\n'
#               "\tThe other way's a Mars. Bid you Alexas Bring me word how tall "
#               'she is. Pity me, Charmian,\n'
#               '\tBut do not speak to me. Lead me to my chamber. Where is the '
#               "fellow? Go to, go to. Come hither, sir. That Herod's head\n"
#               "\tI'll have: but how, when Antony is gone\n"
#               '\tThrough whom I might command it? Come thou near. Didst thou '
#               'behold Octavia? Where? Is she as tall as me? Didst hear her '
#               "speak? is she shrill-tongued or low? That's not so good: he "
#               'cannot like her long. I think so, Charmian: dull of tongue, and '
#               'dwarfish!\n'
#               '\tWhat majesty is in her gait? Remember,\n'
#               "\tIf e'er thou look'dst on majesty. Is this certain? He's very "
#               'knowing;\n'
#               "\tI do perceive't: there's nothing in her yet:\n"
#               '\tThe fellow has good judgment. Guess at her years, I '
#               "prithee.                   Widow! Charmian, hark. Bear'st thou "
#               "her face in mind? is't long or round? For the most part, too, "
#               'they are foolish that are so.\n'
#               "\tHer hair, what colour? There's gold for thee.\n"
#               '\tThou must not take my former sharpness ill:\n'
#               '\tI will employ thee back again; I find thee\n'
#               '\tMost fit for business: go make thee ready;\n'
#               '\tOur letters are prepared. Indeed, he is so: I repent me much\n'
#               '\tThat so I harried him. Why, methinks, by him,\n'
#               "\tThis creature's no such thing. The man hath seen some "
#               'majesty, and should know. I have one thing more to ask him yet, '
#               'good Charmian:\n'
#               "\tBut 'tis no matter; thou shalt bring him to me\n"
#               '\tWhere I will write. All may be well enough. I will be even '
#               'with thee, doubt it not. Thou hast forspoke my being in these '
#               'wars,\n'
#               "\tAnd say'st it is not fit. If not denounced against us, why "
#               'should not we\n'
#               "\tBe there in person? What is't you say?                   Sink "
#               'Rome, and their tongues rot\n'
#               "\tThat speak against us! A charge we bear i' the war,\n"
#               '\tAnd, as the president of my kingdom, will\n'
#               '\tAppear there for a man. Speak not against it:\n'
#               '\tI will not stay behind. Celerity is never more admired\n'
#               '\tThan by the negligent. By sea! what else? I have sixty sails, '
#               'Caesar none better. Let me sit down. O Juno! Ah, stand by. Well '
#               'then, sustain him: O! O my lord, my lord,\n'
#               '\tForgive my fearful sails! I little thought\n'
#               "\tYou would have follow'd.           O, my pardon! Pardon, "
#               'pardon! What shall we do, Enobarbus? Is Antony or we in fault '
#               'for this? Prithee, peace. That head, my lord? What, no more '
#               'ceremony? See, my women!\n'
#               '\tAgainst the blown rose may they stop their nose\n'
#               "\tThat kneel'd unto the buds. Admit him, sir. Caesar's "
#               'will?                   None but friends: say boldly. Go on: '
#               'right royal. O!                   He is a god, and knows\n'
#               '\tWhat is most right: mine honour was not yielded,\n'
#               "\tBut conquer'd merely. What's your name? Most kind messenger,\n"
#               '\tSay to great Caesar this: in deputation\n'
#               '\tI kiss his conquering hand: tell him, I am prompt\n'
#               "\tTo lay my crown at 's feet, and there to kneel:\n"
#               '\tTell him from his all-obeying breath I hear\n'
#               "\tThe doom of Egypt. Your Caesar's father oft,\n"
#               '\tWhen he hath mused of taking kingdoms in,\n'
#               "\tBestow'd his lips on that unworthy place,\n"
#               "\tAs it rain'd kisses. Good my lord,--                   O, "
#               "is't come to this? Wherefore is this? Have you done yet? I must "
#               'stay his time. Not know me yet? Ah, dear, if I be so,\n'
#               '\tFrom my cold heart let heaven engender hail,\n'
#               '\tAnd poison it in the source; and the first stone\n'
#               '\tDrop in my neck: as it determines, so\n'
#               '\tDissolve my life! The next Caesarion smite!\n'
#               '\tTill by degrees the memory of my womb,\n'
#               '\tTogether with my brave Egyptians all,\n'
#               '\tBy the discandying of this pelleted storm,\n'
#               '\tLie graveless, till the flies and gnats of Nile\n'
#               "\tHave buried them for prey! That's my brave lord! It is my "
#               'birth-day:\n'
#               '\tI had thought to have held it poor: but, since my lord\n'
#               '\tIs Antony again, I will be Cleopatra. Call all his noble '
#               'captains to my lord.   What means this?   What does he mean? '
#               "Sleep a little. Nay, I'll help too.\n"
#               "\tWhat's this for? Sooth, la, I'll help: thus it must be. Is "
#               'not this buckled well? Lead me.\n'
#               '\tHe goes forth gallantly. That he and Caesar might\n'
#               '\tDetermine this great war in single fight!\n'
#               '\tThen Antony,--but now--Well, on. Lord of lords!\n'
#               '\tO infinite virtue, comest thou smiling from\n'
#               "\tThe world's great snare uncaught? I'll give thee, friend,\n"
#               "\tAn armour all of gold; it was a king's. Why is my lord "
#               'enraged against his love? Help me, my women! O, he is more mad\n'
#               '\tThan Telamon for his shield; the boar of Thessaly\n'
#               "\tWas never so emboss'd. To the monument!\n"
#               '\tMardian, go tell him I have slain myself;\n'
#               "\tSay, that the last I spoke was 'Antony,'\n"
#               '\tAnd word it, prithee, piteously: hence, Mardian,\n'
#               '\tAnd bring me how he takes my death.\n'
#               '\tTo the monument! O Charmian, I will never go from hence. No, '
#               'I will not:\n'
#               '\tAll strange and terrible events are welcome,\n'
#               '\tBut comforts we despise; our size of sorrow,\n'
#               "\tProportion'd to our cause, must be as great\n"
#               '\tAs that which makes it. How now! is he dead? O sun,\n'
#               '\tBurn the great sphere thou movest in!\n'
#               '\tdarkling stand\n'
#               "\tThe varying shore o' the world. O Antony,\n"
#               '\tAntony, Antony! Help, Charmian, help, Iras, help;\n'
#               "\tHelp, friends below; let's draw him hither. So it should be, "
#               'that none but Antony\n'
#               "\tShould conquer Antony; but woe 'tis so!                   I "
#               'dare not, dear,--\n'
#               '\tDear my lord, pardon,--I dare not,\n'
#               '\tLest I be taken: not the imperious show\n'
#               '\tOf the full-fortuned Caesar ever shall\n'
#               "\tBe brooch'd with me; if knife, drugs,\n"
#               '\tserpents, have\n'
#               '\tEdge, sting, or operation, I am safe:\n'
#               '\tYour wife Octavia, with her modest eyes\n'
#               '\tAnd still conclusion, shall acquire no honour\n'
#               '\tDemuring upon me. But come, come, Antony,--\n'
#               '\tHelp me, my women,--we must draw thee up:\n'
#               "\tAssist, good friends. Here's sport indeed! How heavy weighs "
#               'my lord!\n'
#               '\tOur strength is all gone into heaviness,\n'
#               "\tThat makes the weight: had I great Juno's power,\n"
#               "\tThe strong-wing'd Mercury should fetch thee up,\n"
#               "\tAnd set thee by Jove's side. Yet come a little,--\n"
#               '\tWishes were ever fools,--O, come, come, come; And welcome, '
#               'welcome! die where thou hast lived:\n'
#               '\tQuicken with kissing: had my lips that power,\n'
#               '\tThus would I wear them out. No, let me speak; and let me rail '
#               'so high,\n'
#               '\tThat the false housewife Fortune break her wheel,\n'
#               '\tProvoked by my offence. They do not go together. My '
#               "resolution and my hands I'll trust;\n"
#               "\tNone about Caesar.                   Noblest of men, woo't "
#               'die?\n'
#               '\tHast thou no care of me? shall I abide\n'
#               '\tIn this dull world, which in thy absence is\n'
#               "\tNo better than a sty? O, see, my women, The crown o' the "
#               'earth doth melt. My lord!\n'
#               "\tO, wither'd is the garland of the war,\n"
#               "\tThe soldier's pole is fall'n: young boys and girls\n"
#               '\tAre level now with men; the odds is gone,\n'
#               '\tAnd there is nothing left remarkable\n'
#               "\tBeneath the visiting moon. No more, but e'en a woman, and "
#               'commanded\n'
#               '\tBy such poor passion as the maid that milks\n'
#               '\tAnd does the meanest chares. It were for me\n'
#               '\tTo throw my sceptre at the injurious gods;\n'
#               '\tTo tell them that this world did equal theirs\n'
#               "\tTill they had stol'n our jewel. All's but naught;\n"
#               '\tPatience is scottish, and impatience does\n'
#               "\tBecome a dog that's mad: then is it sin\n"
#               '\tTo rush into the secret house of death,\n'
#               '\tEre death dare come to us? How do you, women?\n'
#               '\tWhat, what! good cheer! Why, how now, Charmian!\n'
#               '\tMy noble girls! Ah, women, women, look,\n'
#               "\tOur lamp is spent, it's out! Good sirs, take heart:\n"
#               "\tWe'll bury him; and then, what's brave,\n"
#               "\twhat's noble,\n"
#               "\tLet's do it after the high Roman fashion,\n"
#               '\tAnd make death proud to take us. Come, away:\n'
#               '\tThis case of that huge spirit now is cold:\n'
#               '\tAh, women, women! come; we have no friend\n'
#               '\tBut resolution, and the briefest end. My desolation does '
#               'begin to make\n'
#               "\tA better life. 'Tis paltry to be Caesar;\n"
#               "\tNot being Fortune, he's but Fortune's knave,\n"
#               '\tA minister of her will: and it is great\n'
#               '\tTo do that thing that ends all other deeds;\n'
#               '\tWhich shackles accidents and bolts up change;\n'
#               '\tWhich sleeps, and never palates more the dug,\n'
#               "\tThe beggar's nurse and Caesar's. What's thy name? Antony\n"
#               '\tDid tell me of you, bade me trust you; but\n'
#               '\tI do not greatly care to be deceived,\n'
#               '\tThat have no use for trusting. If your master\n'
#               '\tWould have a queen his beggar, you must tell him,\n'
#               '\tThat majesty, to keep decorum, must\n'
#               '\tNo less beg than a kingdom: if he please\n'
#               "\tTo give me conquer'd Egypt for my son,\n"
#               '\tHe gives me so much of mine own, as I\n'
#               '\tWill kneel to him with thanks. Pray you, tell him\n'
#               "\tI am his fortune's vassal, and I send him\n"
#               '\tThe greatness he has got. I hourly learn\n'
#               '\tA doctrine of obedience; and would gladly\n'
#               "\tLook him i' the face. Quick, quick, good hands. What, of "
#               'death too,\n'
#               '\tThat rids our dogs of languish? Where art thou, death?\n'
#               '\tCome hither, come! come, come, and take a queen\n'
#               "\tWorthy many babes and beggars! Sir, I will eat no meat, I'll "
#               'not drink, sir;\n'
#               '\tIf idle talk will once be necessary,\n'
#               "\tI'll not sleep neither: this mortal house I'll ruin,\n"
#               '\tDo Caesar what he can. Know, sir, that I\n'
#               "\tWill not wait pinion'd at your master's court;\n"
#               '\tNor once be chastised with the sober eye\n'
#               '\tOf dull Octavia. Shall they hoist me up\n'
#               '\tAnd show me to the shouting varletry\n'
#               '\tOf censuring Rome? Rather a ditch in Egypt\n'
#               "\tBe gentle grave unto me! rather on Nilus' mud\n"
#               '\tLay me stark naked, and let the water-flies\n'
#               '\tBlow me into abhorring! rather make\n'
#               "\tMy country's high pyramides my gibbet,\n"
#               '\tAnd hang me up in chains! Say, I would die. I cannot tell. No '
#               'matter, sir, what I have heard or known.\n'
#               '\tYou laugh when boys or women tell their dreams;\n'
#               "\tIs't not your trick? I dream'd there was an Emperor Antony:\n"
#               '\tO, such another sleep, that I might see\n'
#               '\tBut such another man! His face was as the heavens; and '
#               'therein stuck\n'
#               '\tA sun and moon, which kept their course,\n'
#               '\tand lighted\n'
#               '\tThe little O, the earth. His legs bestrid the ocean: his '
#               "rear'd arm\n"
#               '\tCrested the world: his voice was propertied\n'
#               '\tAs all the tuned spheres, and that to friends;\n'
#               '\tBut when he meant to quail and shake the orb,\n'
#               '\tHe was as rattling thunder. For his bounty,\n'
#               "\tThere was no winter in't; an autumn 'twas\n"
#               '\tThat grew the more by reaping: his delights\n'
#               "\tWere dolphin-like; they show'd his back above\n"
#               '\tThe element they lived in: in his livery\n'
#               "\tWalk'd crowns and crownets; realms and islands were\n"
#               "\tAs plates dropp'd from his pocket. Think you there was, or "
#               'might be, such a man\n'
#               "\tAs this I dream'd of? You lie, up to the hearing of the "
#               'gods.\n'
#               '\tBut, if there be, or ever were, one such,\n'
#               "\tIt's past the size of dreaming: nature wants stuff\n"
#               '\tTo vie strange forms with fancy; yet, to imagine\n'
#               "\tAnd Antony, were nature's piece 'gainst fancy,\n"
#               '\tCondemning shadows quite. I thank you, sir,\n'
#               '\tKnow you what Caesar means to do with me? Nay, pray you, '
#               "sir,-- He'll lead me, then, in triumph? Sir, the gods\n"
#               '\tWill have it thus; my master and my lord\n'
#               "\tI must obey. Sole sir o' the world,\n"
#               '\tI cannot project mine own cause so well\n'
#               '\tTo make it clear; but do confess I have\n'
#               '\tBeen laden with like frailties which before\n'
#               '\tHave often shamed our sex. And may, through all the world: '
#               "'tis yours; and we,\n"
#               '\tYour scutcheons and your signs of conquest, shall\n'
#               '\tHang in what place you please. Here, my good lord. This is '
#               'the brief of money, plate, and jewels,\n'
#               "\tI am possess'd of: 'tis exactly valued;\n"
#               "\tNot petty things admitted. Where's Seleucus? This is my "
#               'treasurer: let him speak, my lord,\n'
#               '\tUpon his peril, that I have reserved\n'
#               '\tTo myself nothing. Speak the truth, Seleucus. What have I '
#               'kept back? See, Caesar! O, behold,\n'
#               "\tHow pomp is follow'd! mine will now be yours;\n"
#               '\tAnd, should we shift estates, yours would be mine.\n'
#               '\tThe ingratitude of this Seleucus does\n'
#               '\tEven make me wild: O slave, of no more trust\n'
#               "\tThan love that's hired! What, goest thou back? thou shalt\n"
#               "\tGo back, I warrant thee; but I'll catch thine eyes,\n"
#               '\tThough they had wings: slave, soulless villain, dog!\n'
#               '\tO rarely base! O Caesar, what a wounding shame is this,\n'
#               '\tThat thou, vouchsafing here to visit me,\n'
#               '\tDoing the honour of thy lordliness\n'
#               '\tTo one so meek, that mine own servant should\n'
#               '\tParcel the sum of my disgraces by\n'
#               '\tAddition of his envy! Say, good Caesar,\n'
#               '\tThat I some lady trifles have reserved,\n'
#               '\tImmoment toys, things of such dignity\n'
#               '\tAs we greet modern friends withal; and say,\n'
#               '\tSome nobler token I have kept apart\n'
#               '\tFor Livia and Octavia, to induce\n'
#               '\tTheir mediation; must I be unfolded\n'
#               '\tWith one that I have bred? The gods! it smites me\n'
#               '\tBeneath the fall I have. Prithee, go hence;\n'
#               '\tOr I shall show the cinders of my spirits\n'
#               '\tThrough the ashes of my chance: wert thou a man,\n'
#               '\tThou wouldst have mercy on me. Be it known, that we, the '
#               'greatest, are misthought\n'
#               '\tFor things that others do; and, when we fall,\n'
#               "\tWe answer others' merits in our name,\n"
#               '\tAre therefore to be pitied. My master, and my lord! He words '
#               'me, girls, he words me, that I should not\n'
#               '\tBe noble to myself: but, hark thee, Charmian. Hie thee '
#               'again:\n'
#               '\tI have spoke already, and it is provided;\n'
#               '\tGo put it to the haste. Dolabella! Dolabella,\n'
#               '\tI shall remain your debtor. Farewell, and thanks. Now, Iras, '
#               "what think'st thou?\n"
#               '\tThou, an Egyptian puppet, shalt be shown\n'
#               '\tIn Rome, as well as I\tmechanic slaves\n'
#               '\tWith greasy aprons, rules, and hammers, shall\n'
#               '\tUplift us to the view; in their thick breaths,\n'
#               '\tRank of gross diet, shall be enclouded,\n'
#               "\tAnd forced to drink their vapour. Nay, 'tis most certain, "
#               'Iras: saucy lictors\n'
#               '\tWill catch at us, like strumpets; and scald rhymers\n'
#               "\tBallad us out o' tune: the quick comedians\n"
#               '\tExtemporally will stage us, and present\n'
#               '\tOur Alexandrian revels; Antony\n'
#               '\tShall be brought drunken forth, and I shall see\n'
#               '\tSome squeaking Cleopatra boy my greatness\n'
#               "\tI' the posture of a whore. Nay, that's certain. Why, that's "
#               'the way\n'
#               '\tTo fool their preparation, and to conquer\n'
#               '\tTheir most absurd intents. Now, Charmian!\n'
#               '\tShow me, my women, like a queen: go fetch\n'
#               '\tMy best attires: I am again for Cydnus,\n'
#               '\tTo meet Mark Antony: sirrah Iras, go.\n'
#               "\tNow, noble Charmian, we'll dispatch indeed;\n"
#               "\tAnd, when thou hast done this chare, I'll give thee leave\n"
#               '\tTo play till doomsday. Bring our crown and all.\n'
#               "\tWherefore's this noise? Let him come in. What poor an "
#               'instrument\n'
#               '\tMay do a noble deed! he brings me liberty.\n'
#               "\tMy resolution's placed, and I have nothing\n"
#               '\tOf woman in me: now from head to foot\n'
#               '\tI am marble-constant; now the fleeting moon\n'
#               '\tNo planet is of mine. Avoid, and leave him. Hast thou the '
#               'pretty worm of Nilus there,\n'
#               '\tThat kills and pains not? Rememberest thou any that have died '
#               "on't? Get thee hence; farewell. Farewell. Ay, ay; farewell. "
#               'Take thou no care; it shall be heeded. Will it eat me? Well, '
#               'get thee gone; farewell. Give me my robe, put on my crown; I '
#               'have\n'
#               '\tImmortal longings in me: now no more\n'
#               "\tThe juice of Egypt's grape shall moist this lip:\n"
#               '\tYare, yare, good Iras; quick. Methinks I hear\n'
#               '\tAntony call; I see him rouse himself\n'
#               '\tTo praise my noble act; I hear him mock\n'
#               '\tThe luck of Caesar, which the gods give men\n'
#               '\tTo excuse their after wrath: husband, I come:\n'
#               '\tNow to that name my courage prove my title!\n'
#               '\tI am fire and air; my other elements\n'
#               '\tI give to baser life. So; have you done?\n'
#               '\tCome then, and take the last warmth of my lips.\n'
#               '\tFarewell, kind Charmian; Iras, long farewell. Have I the '
#               'aspic in my lips? Dost fall?\n'
#               '\tIf thou and nature can so gently part,\n'
#               "\tThe stroke of death is as a lover's pinch,\n"
#               '\tWhich hurts, and is desired. Dost thou lie still?\n'
#               "\tIf thus thou vanishest, thou tell'st the world\n"
#               '\tIt is not worth leave-taking. This proves me base:\n'
#               '\tIf she first meet the curled Antony,\n'
#               "\tHe'll make demand of her, and spend that kiss\n"
#               '\tWhich is my heaven to have. Come, thou\n'
#               '\tmortal wretch, With thy sharp teeth this knot intrinsicate\n'
#               '\tOf life at once untie: poor venomous fool\n'
#               '\tBe angry, and dispatch. O, couldst thou speak,\n'
#               '\tThat I might hear thee call great Caesar ass\n'
#               '\tUnpolicied! Peace, peace!\n'
#               '\tDost thou not see my baby at my breast,\n'
#               '\tThat sucks the nurse asleep? As sweet as balm, as soft as '
#               'air, as gentle,--\n'
#               '\tO Antony!--Nay, I will take thee too. What should I stay--',
#  'Captain': 'The morn is fair. Good morrow, general.',
#  'Clown': 'Truly, I have him: but I would not be the party\n'
#           '\tthat should desire you to touch him, for his biting\n'
#           '\tis immortal; those that do die of it do seldom or\n'
#           '\tnever recover. Very many, men and women too. I heard of one of\n'
#           '\tthem no longer than yesterday: a very honest woman,\n'
#           '\tbut something given to lie; as a woman should not\n'
#           '\tdo, but in the way of honesty: how she died of the\n'
#           '\tbiting of it, what pain she felt: truly, she makes\n'
#           "\ta very good report o' the worm; but he that will\n"
#           '\tbelieve all that they say, shall never be saved by\n'
#           '\thalf that they do: but this is most fallible, the\n'
#           "\tworm's an odd worm. I wish you all joy of the worm. You must "
#           'think this, look you, that the worm will\n'
#           '\tdo his kind. Look you, the worm is not to be trusted but in the\n'
#           '\tkeeping of wise people; for, indeed, there is no\n'
# ...
#            '\tI came before you here a man prepared\n'
#            '\tTo take this offer: but Mark Antony\n'
#            '\tPut me to some impatience: though I lose\n'
#            '\tThe praise of it by telling, you must know,\n'
#            '\tWhen Caesar and your brother were at blows,\n'
#            '\tYour mother came to Sicily and did find\n'
#            '\tHer welcome friendly. Let me have your hand:\n'
#            '\tI did not think, sir, to have met you here. Well, I know not\n'
#            '\tWhat counts harsh fortune casts upon my face;\n'
#            '\tBut in my bosom shall she never come,\n'
#            '\tTo make my heart her vassal. I hope so, Lepidus. Thus we are '
#            'agreed:\n'
#            '\tI crave our composition may be written,\n'
#            "\tAnd seal'd between us. We'll feast each other ere we part; and "
#            "let's\n"
#            '\tDraw lots who shall begin. No, Antony, take the lot: but, first\n'
#            '\tOr last, your fine Egyptian cookery\n'
#            '\tShall have the fame. I have heard that Julius Caesar\n'
#            '\tGrew fat with feasting there. I have fair meanings, sir. Then so '
#            'much have I heard:\n'
#            '\tAnd I have heard, Apollodorus carried-- What, I pray you? I know '
#            'thee now: how farest thou, soldier? Let me shake thy hand;\n'
#            '\tI never hated thee: I have seen thee fight,\n'
#            '\tWhen I have envied thy behavior. Enjoy thy plainness,\n'
#            '\tIt nothing ill becomes thee.\n'
#            '\tAboard my galley I invite you all:\n'
#            '\tWill you lead, lords? Come. Sit,--and some wine! A health to '
#            'Lepidus!                  Say in mine ear:\n'
#            "\twhat is't?   Forbear me till anon.\n"
#            '\tThis wine for Lepidus!   Go hang, sir, hang! Tell me of\n'
#            '\tthat? away!\n'
#            "\tDo as I bid you. Where's this cup I call'd for?   I think "
#            "thou'rt mad.\n"
#            "\tThe matter? Thou hast served me with much faith. What's else to "
#            'say?\n'
#            "\tBe jolly, lords. What say'st thou? How should that be? Hast thou "
#            'drunk well? Show me which way. Ah, this thou shouldst have done,\n'
#            "\tAnd not have spoke on't! In me 'tis villany;\n"
#            "\tIn thee't had been good service. Thou must know,\n"
#            "\t'Tis not my profit that does lead mine honour;\n"
#            "\tMine honour, it. Repent that e'er thy tongue\n"
#            "\tHath so betray'd thine act: being done unknown,\n"
#            '\tI should have found it afterwards well done;\n'
#            '\tBut must condemn it now. Desist, and drink. This health to '
#            'Lepidus! Fill till the cup be hid. This is not yet an Alexandrian '
#            "feast. Let's ha't, good soldier. I'll try you on the shore. O "
#            'Antony,\n'
#            "\tYou have my father's house,--But, what? we are friends.\n"
#            '\tCome, down into the boat.',
#  'PROCULEIUS': 'Caesar, I shall. Caesar sends greeting to the Queen of Egypt;\n'
#                '\tAnd bids thee study on what fair demands\n'
#                "\tThou mean'st to have him grant thee. My name is Proculeius. "
#                'Be of good cheer;\n'
#                "\tYou're fall'n into a princely hand, fear nothing:\n"
#                '\tMake your full reference freely to my lord,\n'
#                '\tWho is so full of grace, that it flows over\n'
#                '\tOn all that need: let me report to him\n'
#                '\tYour sweet dependency; and you shall find\n'
#                '\tA conqueror that will pray in aid for kindness,\n'
#                "\tWhere he for grace is kneel'd to. This I'll report, dear "
#                'lady.\n'
#                '\tHave comfort, for I know your plight is pitied\n'
#                '\tOf him that caused it. Hold, worthy lady, hold: Do not '
#                'yourself such wrong, who are in this\n'
#                "\tRelieved, but not betray'd. Cleopatra,\n"
#                "\tDo not abuse my master's bounty by\n"
#                '\tThe undoing of yourself: let the world see\n'
#                '\tHis nobleness well acted, which your death\n'
#                '\tWill never let come forth. O, temperance, lady! You do '
#                'extend\n'
#                '\tThese thoughts of horror further than you shall\n'
#                '\tFind cause in Caesar. So, Dolabella,\n'
#                '\tIt shall content me best: be gentle to her. To Caesar I will '
#                'speak what you shall please,\n'
#                "\tIf you'll employ me to him.",
#  'SCARUS': 'Gods and goddesses,\n'
#            '\tAll the whole synod of them! The greater cantle of the world is '
#            'lost\n'
#            "\tWith very ignorance; we have kiss'd away\n"
#            "\tKingdoms and provinces. On our side like the token'd "
#            'pestilence,\n'
#            '\tWhere death is sure. Yon ribaudred nag of Egypt,--\n'
#            "\tWhom leprosy o'ertake!--i' the midst o' the fight,\n"
#            "\tWhen vantage like a pair of twins appear'd,\n"
#            '\tBoth as the same, or rather ours the elder,\n'
#            '\tThe breese upon her, like a cow in June,\n'
#            "\tHoists sails and flies. She once being loof'd,\n"
#            '\tThe noble ruin of her magic, Antony,\n'
#            '\tClaps on his sea-wing, and, like a doting mallard,\n'
#            '\tLeaving the fight in height, flies after her:\n'
#            '\tI never saw an action of such shame;\n'
#            "\tExperience, manhood, honour, ne'er before\n"
#            "\tDid violate so itself. 'Tis easy to't; and there I will attend\n"
#            '\tWhat further comes. O my brave emperor, this is fought indeed!\n'
#            '\tHad we done so at first, we had droven them home\n'
#            '\tWith clouts about their heads. I had a wound here that was like '
#            'a T,\n'
#            "\tBut now 'tis made an H. We'll beat 'em into bench-holes: I have "
#            'yet\n'
#            '\tRoom for six scotches more. Let us score their backs,\n'
#            "\tAnd snatch 'em up, as we take hares, behind:\n"
#            "\t'Tis sport to maul a runner. I'll halt after. For both, my lord. "
#            'Swallows have built\n'
#            "\tIn Cleopatra's sails their nests: the augurers\n"
#            '\tSay they know not, they cannot tell; look grimly,\n'
#            '\tAnd dare not speak their knowledge. Antony\n'
#            '\tIs valiant, and dejected; and, by starts,\n'
#            '\tHis fretted fortunes give him hope, and fear,\n'
#            '\tOf what he has, and has not.',
#  'SELEUCUS': 'Here, madam. Madam,\n'
#              '\tI had rather seal my lips, than, to my peril,\n'
#              '\tSpeak that which is not. Enough to purchase what you have made '
#              'known.',
#  'SILIUS': 'Noble Ventidius,\n'
#            '\tWhilst yet with Parthian blood thy sword is warm,\n'
#            '\tThe fugitive Parthians follow; spur through Media,\n'
#            '\tMesopotamia, and the shelters whither\n'
#            '\tThe routed fly: so thy grand captain Antony\n'
#            '\tShall set thee on triumphant chariots and\n'
#            '\tPut garlands on thy head. Thou hast, Ventidius,\n'
#            '\tthat\n'
#            '\tWithout the which a soldier, and his sword,\n'
#            '\tGrants scarce distinction. Thou wilt write to Antony! Where is '
#            'he now?',
#  'Second Attendant': 'He stays upon your will.',
#  'Second Guard': "The star is fall'n. Nor I. There's Dolabella sent from "
#                  'Caesar; call him.                   All dead.',
#  'Second Messenger': 'Fulvia thy wife is dead. In Sicyon:\n'
#                      '\tHer length of sickness, with what else more serious\n'
#                      '\tImporteth thee to know, this bears.',
#  'Second Servant': 'Lepidus is high-coloured. As they pinch one another by the '
#                    'disposition, he\n'
#                    "\tcries out 'No more;' reconciles them to his\n"
#                    '\tentreaty, and himself to the drink. Why, this is to have '
#                    "a name in great men's\n"
#                    '\tfellowship: I had as lief have a reed that will do\n'
#                    '\tme no service as a partisan I could not heave.',
#  'Second Soldier': 'It will determine one way: fare you well.\n'
#                    '\tHeard you of nothing strange about the streets? Belike '
#                    "'tis but a rumour. Good night to you. Soldiers, have "
#                    "careful watch. Hark! 'Tis the god Hercules, whom Antony "
#                    'loved,\n'
#                    '\tNow leaves him. How now, masters! This last day was\n'
#                    "\tA shrewd one to's.                   Stand close, and "
#                    "list him. Let's speak To him. Go we to him. Hear you, sir?",
#  'Soldier': 'O noble emperor, do not fight by sea;\n'
#             '\tTrust not to rotten planks: do you misdoubt\n'
#             '\tThis sword and these my wounds? Let the Egyptians\n'
#             '\tAnd the Phoenicians go a-ducking; we\n'
#             '\tHave used to conquer, standing on the earth,\n'
#             "\tAnd fighting foot to foot. By Hercules, I think I am i' the "
#             'right. You keep by land\n'
#             '\tThe legions and the horse whole, do you not? While he was yet '
#             'in Rome,\n'
#             '\tHis power went out in such distractions as\n'
#             '\tBeguiled all spies. They say, one Taurus. A thousand, sir,\n'
#             "\tEarly though't be, have on their riveted trim,\n"
#             '\tAnd at the port expect you. The gods make this a happy day to '
#             'Antony! Hadst thou done so,\n'
#             '\tThe kings that have revolted, and the soldier\n'
#             '\tThat has this morning left thee, would have still\n'
#             "\tFollow'd thy heels. Who!\n"
#             '\tOne ever near thee: call for Enobarbus,\n'
#             "\tHe shall not hear thee; or from Caesar's camp\n"
#             "\tSay 'I am none of thine.' Sir,\n"
#             '\tHe is with Caesar. Most certain. Enobarbus, Antony\n'
#             '\tHath after thee sent all thy treasure, with\n'
#             '\tHis bounty overplus: the messenger\n'
#             '\tCame on my guard; and at thy tent is now\n'
#             '\tUnloading of his mules. Mock not, Enobarbus.\n'
#             '\tI tell you true: best you safed the bringer\n'
#             '\tOut of the host; I must attend mine office,\n'
#             "\tOr would have done't myself. Your emperor\n"
#             '\tContinues still a Jove.',
#  'Soothsayer': "Your will? In nature's infinite book of secrecy\n"
#                '\tA little I can read. I make not, but foresee. You shall be '
#                'yet far fairer than you are. You shall be more beloving than '
#                'beloved. You shall outlive the lady whom you serve. You have '
#                'seen and proved a fairer former fortune\n'
#                '\tThan that which is to approach. If every of your wishes had '
#                'a womb.\n'
#                '\tAnd fertile every wish, a million. Your fortunes are alike. '
#                'I have said. Would I had never come from thence, nor you '
#                'Thither! I see it in\n'
#                '\tMy motion, have it not in my tongue: but yet\n'
#                "\tHie you to Egypt again. Caesar's.\n"
#                '\tTherefore, O Antony, stay not by his side:\n'
#                "\tThy demon, that's thy spirit which keeps thee, is\n"
#                '\tNoble, courageous high, unmatchable,\n'
#                "\tWhere Caesar's is not; but, near him, thy angel\n"
#                "\tBecomes a fear, as being o'erpower'd: therefore\n"
#                '\tMake space enough between you. To none but thee; no more, '
#                'but when to thee.\n'
#                '\tIf thou dost play with him at any game,\n'
#                '\tThou art sure to lose; and, of that natural luck,\n'
#                "\tHe beats thee 'gainst the odds: thy lustre thickens,\n"
#                '\tWhen he shines by: I say again, thy spirit\n'
#                '\tIs all afraid to govern thee near him;\n'
#                "\tBut, he away, 'tis noble.",
#  'TAURUS': 'My lord?',
#  'THYREUS': 'Caesar, I go. Caesar, I shall. Hear it apart. So, haply, are they '
#             'friends to Antony. So.\n'
#             "\tThus then, thou most renown'd: Caesar entreats,\n"
#             "\tNot to consider in what case thou stand'st,\n"
#             '\tFurther than he is Caesar. He knows that you embrace not '
#             'Antony\n'
#             "\tAs you did love, but as you fear'd him. The scars upon your "
#             'honour, therefore, he\n'
#             '\tDoes pity, as constrained blemishes,\n'
#             '\tNot as deserved. Shall I say to Caesar\n'
#             '\tWhat you require of him? for he partly begs\n'
#             '\tTo be desired to give. It much would please him,\n'
#             '\tThat of his fortunes you should make a staff\n'
#             '\tTo lean upon: but it would warm his spirits,\n'
#             '\tTo hear from me you had left Antony,\n'
#             '\tAnd put yourself under his shrowd,\n'
#             "\tThe universal landlord. My name is Thyreus. 'Tis your noblest "
#             'course.\n'
#             '\tWisdom and fortune combating together,\n'
#             '\tIf that the former dare but what it can,\n'
#             '\tNo chance may shake it. Give me grace to lay\n'
#             '\tMy duty on your hand. One that but performs\n'
#             '\tThe bidding of the fullest man, and worthiest\n'
#             "\tTo have command obey'd. Mark Antony!",
#  'Third Guard': 'Nor any one.',
#  'Third Soldier': "And you. Good night, good night. 'Tis a brave army,\n"
#                   '\tAnd full of purpose. Under the earth. No. Do you hear, '
#                   'masters? do you hear? What man is this? Peace!\n'
#                   "\tHark further. Let's do so. But he sleeps. Awake, sir, "
#                   'awake; speak to us. Come on, then;\n'
#                   '\tHe may recover yet.',
#  'VARRIUS': 'This is most certain that I shall deliver:\n'
#             '\tMark Antony is every hour in Rome\n'
#             "\tExpected: since he went from Egypt 'tis\n"
#             '\tA space for further travel.',
#  'VENTIDIUS': 'Now, darting Parthia, art thou struck; and now\n'
#               "\tPleased fortune does of Marcus Crassus' death\n"
#               "\tMake me revenger. Bear the king's son's body\n"
#               '\tBefore our army. Thy Pacorus, Orodes,\n'
#               '\tPays this for Marcus Crassus. O Silius, Silius,\n'
#               '\tI have done enough; a lower place, note well,\n'
#               '\tMay make too great an act: for learn this, Silius;\n'
#               '\tBetter to leave undone, than by our deed\n'
#               "\tAcquire too high a fame when him we serve's away.\n"
#               '\tCaesar and Antony have ever won\n'
#               '\tMore in their officer than person: Sossius,\n'
#               '\tOne of my place in Syria, his lieutenant,\n'
#               '\tFor quick accumulation of renown,\n'
#               '\tWhich he achieved by the minute, lost his favour.\n'
#               "\tWho does i' the wars more than his captain can\n"
#               "\tBecomes his captain's captain: and ambition,\n"
#               "\tThe soldier's virtue, rather makes choice of loss,\n"
#               '\tThan gain which darkens him.\n'
#               '\tI could do more to do Antonius good,\n'
#               "\tBut 'twould offend him; and in his offence\n"
#               "\tShould my performance perish. I'll humbly signify what in his "
#               'name,\n'
#               '\tThat magical word of war, we have effected;\n'
#               '\tHow, with his banners and his well-paid ranks,\n'
#               "\tThe ne'er-yet-beaten horse of Parthia\n"
#               "\tWe have jaded out o' the field. He purposeth to Athens: "
#               'whither, with what haste\n'
#               "\tThe weight we must convey with's will permit,\n"
#               '\tWe shall appear before him. On there; pass along!'}

# %% [markdown]
# ### Split text into token

# %%
character_tokens_in_plays = {}

for play_idx in character_cleaned_dialogue_info_in_plays:
    character_tokens_in_plays[play_idx] = {}
    for character in character_cleaned_dialogue_info_in_plays[play_idx]:
        character_tokens_in_plays[play_idx][character] = \
            character_cleaned_dialogue_info_in_plays[play_idx][character].split()

# %% [markdown]
# ### Print list of extracted characters for each play to verify against the text file

# %%
for play_idx in character_tokens_in_plays:
    pprint(sorted(character_dialogue_info_in_plays[play_idx].keys()))
    print("="*100)
# Out:
# ['AGRIPPA',
#  'ALEXAS',
#  'All',
#  'Attendant',
#  'Attendants',
#  'CANIDIUS',
#  'CHARMIAN',
#  'CLEOPATRA',
#  'Captain',
#  'Clown',
#  'DEMETRIUS',
#  'DERCETAS',
#  'DIOMEDES',
#  'DOLABELLA',
#  'DOMITIUS ENOBARBUS',
#  'EROS',
#  'EUPHRONIUS',
#  'Egyptian',
#  'First Attendant',
#  'First Guard',
#  'First Servant',
#  'First Soldier',
#  'Fourth Soldier',
#  'GALLUS',
#  'Guard',
#  'IRAS',
#  'LEPIDUS',
#  'MARDIAN',
#  'MARK ANTONY',
#  'MECAENAS',
#  'MENAS',
#  'MENECRATES',
#  'Messenger',
#  'OCTAVIA',
#  'OCTAVIUS CAESAR',
#  'PHILO',
#  'POMPEY',
#  'PROCULEIUS',
#  'SCARUS',
#  'SELEUCUS',
#  'SILIUS',
#  'Second Attendant',
#  'Second Guard',
#  'Second Messenger',
#  'Second Servant',
#  'Second Soldier',
#  'Soldier',
#  'Soothsayer',
#  'TAURUS',
#  'THYREUS',
#  'Third Guard',
#  'Third Soldier',
#  'VARRIUS',
#  'VENTIDIUS']
# ====================================================================================================
# ['ADRIANA',
#  'AEGEON',
#  'AEMELIA',
#  'ANGELO',
#  'ANTIPHOLUS OF EPHESUS',
#  'ANTIPHOLUS OF SYRACUSE',
#  'BALTHAZAR',
#  'Courtezan',
#  'DROMIO OF EPHESUS',
#  'DROMIO OF SYRACUSE',
#  'DUKE SOLINUS',
#  'First Merchant',
#  'Gaoler',
#  'LUCE',
#  'LUCIANA',
#  'Officer',
#  'PINCH',
#  'Second Merchant',
#  'Servant']
# ====================================================================================================
# ['A Lord',
#  'ADAM',
#  'AMIENS',
#  'AUDREY',
#  'CELIA',
#  'CHARLES',
#  'CORIN',
#  'DENNIS',
#  'DUKE FREDERICK',
#  'DUKE SENIOR',
#  'First Lord',
#  'First Page',
#  'Forester',
#  'HYMEN',
#  'JAQUES',
#  'JAQUES DE BOYS',
#  'LE BEAU',
#  'OLIVER',
#  'ORLANDO',
#  'PHEBE',
#  'ROSALIND',
#  'SILVIUS',
#  'SIR OLIVER MARTEXT',
#  'Second Lord',
#  'Second Page',
#  'TOUCHSTONE',
#  'WILLIAM']
# ====================================================================================================
# ['A Patrician',
#  'AEdile',
#  'AUFIDIUS',
#  'All',
#  'All Citizens',
#  'All Conspirators',
#  'All The Lords',
#  'All The People',
#  'BRUTUS',
#  'Both',
#  'Both Citizens',
#  'Both Tribunes',
#  'COMINIUS',
#  'CORIOLANUS',
#  'Citizen',
#  'Citizens',
#  'Fifth Citizen',
#  'First Citizen',
#  'First Conspirator',
#  'First Lord',
#  'First Officer',
#  'First Roman',
#  'First Senator',
#  'First Servingman',
#  'First Soldier',
#  'Fourth Citizen',
#  'Gentlewoman',
#  'Herald',
#  'LARTIUS',
#  'Lieutenant',
#  'Lords',
#  'MARCIUS',
#  'MENENIUS',
#  'Messenger',
#  'Officer',
#  'Roman',
#  'SICINIUS',
#  'Second Citizen',
#  'Second Conspirator',
#  'Second Lord',
#  'Second Messenger',
#  'Second Officer',
#  'Second Patrician',
#  'Second Roman',
#  'Second Senator',
#  'Second Servingman',
#  'Second Soldier',
#  'Senators',
#  'Senators, &C',
#  'Seventh Citizen',
#  'Sixth Citizen',
#  'TITUS',
#  'Third Citizen',
#  'Third Conspirator',
#  'Third Lord',
#  'Third Roman',
#  'Third Servingman',
#  'VALERIA',
#  'VIRGILIA',
#  'VOLUMNIA',
#  'Volsce',
#  'Young MARCIUS']
# ====================================================================================================
# ['All',
#  'BERTRAM',
#  'BOTH',
#  'Both',
#  'COUNTESS',
#  'Clown',
#  'DIANA',
#  'DUKE',
#  'First Gentleman',
#  'First Lord',
#  'First Soldier',
#  'Fourth Lord',
#  'Gentleman',
#  'HELENA',
#  'KING',
#  'LAFEU',
#  'MARIANA',
#  'PAROLLES',
#  'Page',
#  'Second Gentleman',
#  'Second Lord',
#  'Second Soldier',
#  'Servant',
#  'Steward',
#  'Widow']
# ====================================================================================================

# %% [markdown]
# ## TODO
#
# 1. Use defaultdict to remove if for checking presence of character name in the dictionary
# 2. When adding character, convert to lower case to remove duplicates like Both, BOTH, etc.
# 3. Remove character names like All, All officers, Both, Both Citizens, etc
# 4. Token cleanup -> lowercase, remove punctuation from end, (optionally) remove stopwords
# 5. Use collections.Counter() to solve Q5.

# %% [markdown]
# ### Bonus: Demo to show usage of str.rstrip() to remove punctuation symbols at the end of tokens

# %%
import string

# %%
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
"clay:?!!".rstrip(string.punctuation)
# Out:
# 'clay'
